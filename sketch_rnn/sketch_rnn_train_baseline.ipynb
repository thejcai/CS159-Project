# %%
# Copyright 2019 The Magenta Authors.
#

"""SketchRNN training."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import json
import os
import time
import zipfile

# from magenta.models.sketch_rnn import model as sketch_rnn_model
# from magenta.models.sketch_rnn import utils
import model as sketch_rnn_model
import utils

# !pip install numpy==1.16.2
import numpy as np
import requests
import six
from six.moves.urllib.request import urlretrieve
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

FLAGS = tf.app.flags.FLAGS

tf.app.flags.DEFINE_string(
    'data_dir',
    'https://github.com/hardmaru/sketch-rnn-datasets/raw/master/aaron_sheep',
    'The directory in which to find the dataset specified in model hparams. '
    'If data_dir starts with "http://" or "https://", the file will be fetched '
    'remotely.')
tf.app.flags.DEFINE_string(
    'log_root', 'log/initialp25/', # '/tmp/sketch_rnn/models/default',
    'Directory to store model checkpoints, tensorboard.')
tf.app.flags.DEFINE_boolean(
    'resume_training', True,
    'Set to true to load previous checkpoint')
tf.app.flags.DEFINE_string(
    'hparams', '',
    'Pass in comma-separated key=value pairs such as '
    '\'save_every=40,decay_rate=0.99\' '
    '(no whitespace) to be read into the HParams object defined in model.py')

PRETRAINED_MODELS_URL = ('http://download.magenta.tensorflow.org/models/'
                         'sketch_rnn.zip')


def reset_graph():
    """Closes the current default session and resets the graph."""
    sess = tf.get_default_session()
    if sess:
        sess.close()
    tf.reset_default_graph()


def load_env(data_dir, model_dir):
    """Loads environment for inference mode, used in jupyter notebook."""
    model_params = sketch_rnn_model.get_default_hparams()
    with tf.gfile.Open(os.path.join(model_dir, 'model_config.json'), 'r') as f:
        model_params.parse_json(f.read())
    return load_dataset(data_dir, model_params, inference_mode=True)


def load_model(model_dir):
    """Loads model for inference mode, used in jupyter notebook."""
    model_params = sketch_rnn_model.get_default_hparams()
    with tf.gfile.Open(os.path.join(model_dir, 'model_config.json'), 'r') as f:
        model_params.parse_json(f.read())

    model_params.batch_size = 1  # only sample one at a time
    eval_model_params = sketch_rnn_model.copy_hparams(model_params)
    eval_model_params.use_input_dropout = 0
    eval_model_params.use_recurrent_dropout = 0
    eval_model_params.use_output_dropout = 0
    eval_model_params.is_training = 0
    sample_model_params = sketch_rnn_model.copy_hparams(eval_model_params)
    sample_model_params.max_seq_len = 1  # sample one point at a time
    return [model_params, eval_model_params, sample_model_params]


def download_pretrained_models(
    models_root_dir='/tmp/sketch_rnn/models',
    pretrained_models_url=PRETRAINED_MODELS_URL):
    """Download pretrained models to a temporary directory."""
    tf.gfile.MakeDirs(models_root_dir)
    zip_path = os.path.join(
        models_root_dir, os.path.basename(pretrained_models_url))
    if os.path.isfile(zip_path):
        tf.logging.info('%s already exists, using cached copy', zip_path)
    else:
        tf.logging.info('Downloading pretrained models from %s...',
                        pretrained_models_url)
        urlretrieve(pretrained_models_url, zip_path)
        tf.logging.info('Download complete.')
    tf.logging.info('Unzipping %s...', zip_path)
    with zipfile.ZipFile(zip_path) as models_zip:
        models_zip.extractall(models_root_dir)
    tf.logging.info('Unzipping complete.')


def load_dataset(data_dir, model_params, inference_mode=False):
    """Loads the .npz file, and splits the set into train/valid/test."""

    # normalizes the x and y columns using the training set.
    # applies same scaling factor to valid and test set.

    if isinstance(model_params.data_set, list):
        datasets = model_params.data_set
    else:
        datasets = [model_params.data_set]

    train_strokes = None
    valid_strokes = None
    test_strokes = None

    for dataset in datasets:
        if data_dir.startswith('http://') or data_dir.startswith('https://'):
            data_filepath = '/'.join([data_dir, dataset])
            tf.logging.info('Downloading %s', data_filepath)
            response = requests.get(data_filepath)
            data = np.load(six.BytesIO(response.content), allow_pickle=True, encoding='latin1')
        else:
            data_filepath = os.path.join(data_dir, dataset)
            if six.PY3:
                data = np.load(data_filepath, allow_pickle=True, encoding='latin1')
            else:
                data = np.load(data_filepath, allow_pickle=True)
        tf.logging.info('Loaded {}/{}/{} from {}'.format(
            len(data['train']), len(data['valid']), len(data['test']),
            dataset))
        if train_strokes is None:
            train_strokes = data['train']
            valid_strokes = data['valid']
            test_strokes = data['test']
        else:
            train_strokes = np.concatenate((train_strokes, data['train']))
            valid_strokes = np.concatenate((valid_strokes, data['valid']))
            test_strokes = np.concatenate((test_strokes, data['test']))

    all_strokes = np.concatenate((train_strokes, valid_strokes, test_strokes))
    num_points = 0
    for stroke in all_strokes:
        num_points += len(stroke)
    avg_len = num_points / len(all_strokes)
    tf.logging.info('Dataset combined: {} ({}/{}/{}), avg len {}'.format(
        len(all_strokes), len(train_strokes), len(valid_strokes),
        len(test_strokes), int(avg_len)))

    # calculate the max strokes we need.
    max_seq_len = utils.get_max_len(all_strokes)
    # overwrite the hps with this calculation.
    model_params.max_seq_len = max_seq_len

    tf.logging.info('model_params.max_seq_len %i.', model_params.max_seq_len)

    eval_model_params = sketch_rnn_model.copy_hparams(model_params)

    eval_model_params.use_input_dropout = 0
    eval_model_params.use_recurrent_dropout = 0
    eval_model_params.use_output_dropout = 0
    eval_model_params.is_training = 1

    if inference_mode:
        eval_model_params.batch_size = 1
        eval_model_params.is_training = 0

    sample_model_params = sketch_rnn_model.copy_hparams(eval_model_params)
    sample_model_params.batch_size = 1  # only sample one at a time
    sample_model_params.max_seq_len = 1  # sample one point at a time

    train_set = utils.DataLoader(
        train_strokes,
        model_params.batch_size,
        max_seq_length=model_params.max_seq_len,
        random_scale_factor=model_params.random_scale_factor,
        augment_stroke_prob=model_params.augment_stroke_prob)

    normalizing_scale_factor = train_set.calculate_normalizing_scale_factor()
    train_set.normalize(normalizing_scale_factor)

    valid_set = utils.DataLoader(
        valid_strokes,
        eval_model_params.batch_size,
        max_seq_length=eval_model_params.max_seq_len,
        random_scale_factor=0.0,
        augment_stroke_prob=0.0)
    valid_set.normalize(normalizing_scale_factor)

    test_set = utils.DataLoader(
        test_strokes,
        eval_model_params.batch_size,
        max_seq_length=eval_model_params.max_seq_len,
        random_scale_factor=0.0,
        augment_stroke_prob=0.0)
    test_set.normalize(normalizing_scale_factor)

    tf.logging.info('normalizing_scale_factor %4.4f.', normalizing_scale_factor)

    result = [
        train_set, valid_set, test_set, model_params, eval_model_params,
        sample_model_params
    ]
    return result


def evaluate_model(sess, model, data_set):
    """Returns the average weighted cost, reconstruction cost and KL cost."""
    total_cost = 0.0
    total_r_cost = 0.0
    total_kl_cost = 0.0
    for batch in range(data_set.num_batches):
        unused_orig_x, x, s = data_set.get_batch(batch)
        feed = {model.input_data: x, model.sequence_lengths: s}
        (cost, r_cost,
         kl_cost) = sess.run([model.cost, model.r_cost, model.kl_cost], feed)
        total_cost += cost
        total_r_cost += r_cost
        total_kl_cost += kl_cost

    total_cost /= (data_set.num_batches)
    total_r_cost /= (data_set.num_batches)
    total_kl_cost /= (data_set.num_batches)
    return (total_cost, total_r_cost, total_kl_cost)


def load_checkpoint(sess, checkpoint_path):
    saver = tf.train.Saver(tf.global_variables())
    ckpt = tf.train.get_checkpoint_state(checkpoint_path)
    tf.logging.info('Loading model %s.', ckpt.model_checkpoint_path)
    saver.restore(sess, ckpt.model_checkpoint_path)


def save_model(sess, model_save_path, global_step):
    saver = tf.train.Saver(tf.global_variables())
    checkpoint_path = os.path.join(model_save_path, 'vector')
    tf.logging.info('saving model %s.', checkpoint_path)
    tf.logging.info('global_step %i.', global_step)
    saver.save(sess, checkpoint_path, global_step=global_step)


def train(sess, model, eval_model, train_set, valid_set, test_set):
    """Train a sketch-rnn model."""
    # Setup summary writer.
    summary_writer = tf.summary.FileWriter(FLAGS.log_root)

    # Calculate trainable params.
    t_vars = tf.trainable_variables()
    count_t_vars = 0
    for var in t_vars:
        num_param = np.prod(var.get_shape().as_list())
        count_t_vars += num_param
        tf.logging.info('%s %s %i', var.name, str(var.get_shape()), num_param)
    tf.logging.info('Total trainable variables %i.', count_t_vars)
    model_summ = tf.summary.Summary()
    model_summ.value.add(
          tag='Num_Trainable_Params', simple_value=float(count_t_vars))
    summary_writer.add_summary(model_summ, 0)
    summary_writer.flush()

    # setup eval stats
    best_valid_cost = 100000000.0  # set a large init value
    valid_cost = 0.0

    # main train loop

    hps = model.hps
    start = time.time()

    for _ in range(hps.num_steps):

        step = sess.run(model.global_step)

        curr_learning_rate = ((hps.learning_rate - hps.min_learning_rate) *
                              (hps.decay_rate)**step + hps.min_learning_rate)
        curr_kl_weight = (hps.kl_weight - (hps.kl_weight - hps.kl_weight_start) *
                          (hps.kl_decay_rate)**step)

        _, x, s = train_set.random_batch()
        feed = {
            model.input_data: x,
            model.sequence_lengths: s,
            model.lr: curr_learning_rate,
            model.kl_weight: curr_kl_weight
        }

        (train_cost, r_cost, kl_cost, _, train_step, _) = sess.run([
            model.cost, model.r_cost, model.kl_cost, model.final_state,
            model.global_step, model.train_op
        ], feed)

        if step % 20 == 0 and step > 0:

            end = time.time()
            time_taken = end - start

            cost_summ = tf.summary.Summary()
            cost_summ.value.add(tag='Train_Cost', simple_value=float(train_cost))
            reconstr_summ = tf.summary.Summary()
            reconstr_summ.value.add(
                tag='Train_Reconstr_Cost', simple_value=float(r_cost))
            kl_summ = tf.summary.Summary()
            kl_summ.value.add(tag='Train_KL_Cost', simple_value=float(kl_cost))
            lr_summ = tf.summary.Summary()
            lr_summ.value.add(
                tag='Learning_Rate', simple_value=float(curr_learning_rate))
            kl_weight_summ = tf.summary.Summary()
            kl_weight_summ.value.add(
                tag='KL_Weight', simple_value=float(curr_kl_weight))
            time_summ = tf.summary.Summary()
            time_summ.value.add(
                tag='Time_Taken_Train', simple_value=float(time_taken))

            output_format = ('step: %d, lr: %.6f, klw: %0.4f, cost: %.4f, '
                             'recon: %.4f, kl: %.4f, train_time_taken: %.4f')
            output_values = (step, curr_learning_rate, curr_kl_weight, train_cost,
                             r_cost, kl_cost, time_taken)
            output_log = output_format % output_values

            tf.logging.info(output_log)

            summary_writer.add_summary(cost_summ, train_step)
            summary_writer.add_summary(reconstr_summ, train_step)
            summary_writer.add_summary(kl_summ, train_step)
            summary_writer.add_summary(lr_summ, train_step)
            summary_writer.add_summary(kl_weight_summ, train_step)
            summary_writer.add_summary(time_summ, train_step)
            summary_writer.flush()
            start = time.time()

        if step % hps.save_every == 0 and step > 0:

            (valid_cost, valid_r_cost, valid_kl_cost) = evaluate_model(
                sess, eval_model, valid_set)

            end = time.time()
            time_taken_valid = end - start
            start = time.time()

            valid_cost_summ = tf.summary.Summary()
            valid_cost_summ.value.add(
                tag='Valid_Cost', simple_value=float(valid_cost))
            valid_reconstr_summ = tf.summary.Summary()
            valid_reconstr_summ.value.add(
                tag='Valid_Reconstr_Cost', simple_value=float(valid_r_cost))
            valid_kl_summ = tf.summary.Summary()
            valid_kl_summ.value.add(
                tag='Valid_KL_Cost', simple_value=float(valid_kl_cost))
            valid_time_summ = tf.summary.Summary()
            valid_time_summ.value.add(
                tag='Time_Taken_Valid', simple_value=float(time_taken_valid))

            output_format = ('best_valid_cost: %0.4f, valid_cost: %.4f, valid_recon: '
                             '%.4f, valid_kl: %.4f, valid_time_taken: %.4f')
            output_values = (min(best_valid_cost, valid_cost), valid_cost,
                             valid_r_cost, valid_kl_cost, time_taken_valid)
            output_log = output_format % output_values

            tf.logging.info(output_log)

            summary_writer.add_summary(valid_cost_summ, train_step)
            summary_writer.add_summary(valid_reconstr_summ, train_step)
            summary_writer.add_summary(valid_kl_summ, train_step)
            summary_writer.add_summary(valid_time_summ, train_step)
            summary_writer.flush()

            if valid_cost < best_valid_cost:
                best_valid_cost = valid_cost

                save_model(sess, FLAGS.log_root, step)

                end = time.time()
                time_taken_save = end - start
                start = time.time()

                tf.logging.info('time_taken_save %4.4f.', time_taken_save)

                best_valid_cost_summ = tf.summary.Summary()
                best_valid_cost_summ.value.add(
                    tag='Best_Valid_Cost', simple_value=float(best_valid_cost))

                summary_writer.add_summary(best_valid_cost_summ, train_step)
                summary_writer.flush()

                (eval_cost, eval_r_cost, eval_kl_cost) = evaluate_model(
                    sess, eval_model, test_set)

                end = time.time()
                time_taken_eval = end - start
                start = time.time()

                eval_cost_summ = tf.summary.Summary()
                eval_cost_summ.value.add(tag='Eval_Cost', simple_value=float(eval_cost))
                eval_reconstr_summ = tf.summary.Summary()
                eval_reconstr_summ.value.add(
                    tag='Eval_Reconstr_Cost', simple_value=float(eval_r_cost))
                eval_kl_summ = tf.summary.Summary()
                eval_kl_summ.value.add(
                    tag='Eval_KL_Cost', simple_value=float(eval_kl_cost))
                eval_time_summ = tf.summary.Summary()
                eval_time_summ.value.add(
                    tag='Time_Taken_Eval', simple_value=float(time_taken_eval))

                output_format = ('eval_cost: %.4f, eval_recon: %.4f, '
                                 'eval_kl: %.4f, eval_time_taken: %.4f')
                output_values = (eval_cost, eval_r_cost, eval_kl_cost, time_taken_eval)
                output_log = output_format % output_values

                tf.logging.info(output_log)

                summary_writer.add_summary(eval_cost_summ, train_step)
                summary_writer.add_summary(eval_reconstr_summ, train_step)
                summary_writer.add_summary(eval_kl_summ, train_step)
                summary_writer.add_summary(eval_time_summ, train_step)
                summary_writer.flush()


def trainer(model_params):
    """Train a sketch-rnn model."""
    np.set_printoptions(precision=8, edgeitems=6, linewidth=200, suppress=True)

    tf.logging.info('sketch-rnn')
    tf.logging.info('Hyperparams:')
    for key, val in six.iteritems(model_params.values()):
        tf.logging.info('%s = %s', key, str(val))
    tf.logging.info('Loading data files.')
    datasets = load_dataset(FLAGS.data_dir, model_params)

    train_set = datasets[0]
    valid_set = datasets[1]
    test_set = datasets[2]
    model_params = datasets[3]
    eval_model_params = datasets[4]

    reset_graph()
    model = sketch_rnn_model.Model(model_params)
    eval_model = sketch_rnn_model.Model(eval_model_params, reuse=True)

    sess = tf.InteractiveSession()
    sess.run(tf.global_variables_initializer())

    if FLAGS.resume_training:
        load_checkpoint(sess, FLAGS.log_root)

    # Write config file to json file.
    tf.gfile.MakeDirs(FLAGS.log_root)
    with tf.gfile.Open(
          os.path.join(FLAGS.log_root, 'model_config.json'), 'w') as f:
        json.dump(model_params.values(), f, indent=True)

    train(sess, model, eval_model, train_set, valid_set, test_set)


def main(unused_argv):
    """Load model params, save config file and start trainer."""
    model_params = sketch_rnn_model.get_default_hparams()
    if FLAGS.hparams:
        model_params.parse(FLAGS.hparams)
    trainer(model_params)


def console_entry_point():
    tf.app.run(main)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Collecting numpy==1.16.2
#   Using cached https://files.pythonhosted.org/packages/c4/33/8ec8dcdb4ede5d453047bbdbd01916dbaccdb63e98bba60989718f5f0876/numpy-1.16.2-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: numpy
# Successfully installed numpy-1.16.2

# %%
def get_evaluation():
    # Load model parameters
    model_params = sketch_rnn_model.get_default_hparams()
    if FLAGS.hparams:
        model_params = sketch_rnn_model.get_default_hparams()
    
    # Load dataset
    datasets = load_dataset(FLAGS.data_dir, model_params)
    train_set = datasets[0]
    valid_set = datasets[1]
    test_set = datasets[2]
    model_params = datasets[3]
    eval_model_params = datasets[4]
    
    # Construct the model
    reset_graph()
    model = sketch_rnn_model.Model(model_params)
    eval_model = sketch_rnn_model.Model(eval_model_params, reuse=True)

    sess = tf.InteractiveSession()
    sess.run(tf.global_variables_initializer())

    if FLAGS.resume_training:
        load_checkpoint(sess, FLAGS.log_root)

    # Evaluate against train, val, test
    (train_cost, train_r_cost, train_kl_cost) = evaluate_model(
                sess, eval_model, train_set)
    (valid_cost, valid_r_cost, valid_kl_cost) = evaluate_model(
                sess, eval_model, valid_set)
    (test_cost, test_r_cost, test_kl_cost) = evaluate_model(
                sess, eval_model, test_set)
    output_format = 'eval_cost: %.4f, eval_recon: %.4f, eval_kl: %.4f'
    print(output_format % (train_cost, train_r_cost, train_kl_cost))
    print(output_format % (valid_cost, valid_r_cost, valid_kl_cost))
    print(output_format % (test_cost, test_r_cost, test_kl_cost))

# %%
get_evaluation()
# Out:
# INFO:tensorflow:Downloading https://github.com/hardmaru/sketch-rnn-datasets/raw/master/aaron_sheep/aaron_sheep.npz
# INFO:tensorflow:Loaded 7400/300/300 from aaron_sheep.npz
# INFO:tensorflow:Dataset combined: 8000 (7400/300/300), avg len 125
# INFO:tensorflow:model_params.max_seq_len 250.
# total images <= max_seq_len is 7400
# total images <= max_seq_len is 300
# total images <= max_seq_len is 300
# INFO:tensorflow:normalizing_scale_factor 18.5198.
# INFO:tensorflow:Model using gpu.
# INFO:tensorflow:Input dropout mode = False.
# INFO:tensorflow:Output dropout mode = False.
# INFO:tensorflow:Recurrent dropout mode = True.
# INFO:tensorflow:Model using gpu.
# INFO:tensorflow:Input dropout mode = 0.
# INFO:tensorflow:Output dropout mode = 0.
# INFO:tensorflow:Recurrent dropout mode = 0.
# INFO:tensorflow:Loading model log/initialp25/vector-65500.
# INFO:tensorflow:Restoring parameters from log/initialp25/vector-65500
# eval_cost: -0.4185, eval_recon: -0.4211, eval_kl: 0.2592
# eval_cost: -0.3319, eval_recon: -0.3346, eval_kl: 0.2624
# eval_cost: -0.3342, eval_recon: -0.3368, eval_kl: 0.2626

# %%
console_entry_point()
# Out:
# INFO:tensorflow:sketch-rnn
# INFO:tensorflow:Hyperparams:
# INFO:tensorflow:augment_stroke_prob = 0.1
# INFO:tensorflow:kl_weight_start = 0.01
# INFO:tensorflow:kl_decay_rate = 0.99995
# INFO:tensorflow:is_training = True
# INFO:tensorflow:dec_model = layer_norm
# INFO:tensorflow:save_every = 500
# INFO:tensorflow:decay_rate = 0.9999
# INFO:tensorflow:learning_rate = 0.001
# INFO:tensorflow:use_recurrent_dropout = True
# INFO:tensorflow:num_steps = 25000
# INFO:tensorflow:recurrent_dropout_prob = 0.9
# INFO:tensorflow:random_scale_factor = 0.15
# INFO:tensorflow:use_output_dropout = False
# INFO:tensorflow:output_dropout_prob = 0.9
# INFO:tensorflow:input_dropout_prob = 0.9
# INFO:tensorflow:kl_weight = 0.25
# INFO:tensorflow:batch_size = 100
# INFO:tensorflow:min_learning_rate = 1e-05
# INFO:tensorflow:data_set = ['aaron_sheep.npz']
# INFO:tensorflow:z_size = 128
# INFO:tensorflow:use_input_dropout = False
# INFO:tensorflow:grad_clip = 1.0
# INFO:tensorflow:enc_rnn_size = 256
# INFO:tensorflow:max_seq_len = 250
# INFO:tensorflow:num_mixture = 20
# INFO:tensorflow:conditional = True
# INFO:tensorflow:kl_tolerance = 0.2
# INFO:tensorflow:dec_rnn_size = 512
# INFO:tensorflow:enc_model = layer_norm
# INFO:tensorflow:Loading data files.
# INFO:tensorflow:Downloading https://github.com/hardmaru/sketch-rnn-datasets/raw/master/aaron_sheep/aaron_sheep.npz
# INFO:tensorflow:Loaded 7400/300/300 from aaron_sheep.npz
# INFO:tensorflow:Dataset combined: 8000 (7400/300/300), avg len 125
# INFO:tensorflow:model_params.max_seq_len 250.
# total images <= max_seq_len is 7400
# total images <= max_seq_len is 300
# total images <= max_seq_len is 300
# INFO:tensorflow:normalizing_scale_factor 18.5198.
# INFO:tensorflow:Model using gpu.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Input dropout mode = False.
# INFO:tensorflow:Output dropout mode = False.
# INFO:tensorflow:Recurrent dropout mode = True.
# WARNING:tensorflow:From /home/jupyter/model.py:90: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/jupyter/rnn.py:288: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/jupyter/model.py:323: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/jupyter/model.py:342: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/jupyter/model.py:352: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# INFO:tensorflow:Model using gpu.
# INFO:tensorflow:Input dropout mode = 0.
# INFO:tensorflow:Output dropout mode = 0.
# INFO:tensorflow:Recurrent dropout mode = 0.
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/linear/super_linear_w:0 (128, 1024) 131072
# INFO:tensorflow:vector_rnn/linear/super_linear_b:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/RNN/output_w:0 (512, 123) 62976
# INFO:tensorflow:vector_rnn/RNN/output_b:0 (123,) 123
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_xh:0 (133, 2048) 272384
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_hh:0 (512, 2048) 1048576
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_gamma:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_beta:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_gamma:0 (512,) 512
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_beta:0 (512,) 512
# INFO:tensorflow:Total trainable variables 2192251.
# INFO:tensorflow:step: 20, lr: 0.000998, klw: 0.0102, cost: 1.1868, recon: 1.1847, kl: 0.2000, train_time_taken: 127.9846
# INFO:tensorflow:step: 40, lr: 0.000996, klw: 0.0105, cost: 1.0724, recon: 1.0682, kl: 0.3957, train_time_taken: 118.6233
# INFO:tensorflow:step: 60, lr: 0.000994, klw: 0.0107, cost: 1.0339, recon: 1.0295, kl: 0.4121, train_time_taken: 117.9029
# INFO:tensorflow:step: 80, lr: 0.000992, klw: 0.0110, cost: 0.9965, recon: 0.9913, kl: 0.4779, train_time_taken: 119.2695
# INFO:tensorflow:step: 100, lr: 0.000990, klw: 0.0112, cost: 0.9470, recon: 0.9407, kl: 0.5640, train_time_taken: 118.1826
# INFO:tensorflow:step: 120, lr: 0.000988, klw: 0.0114, cost: 0.8559, recon: 0.8483, kl: 0.6703, train_time_taken: 117.7225
# INFO:tensorflow:step: 140, lr: 0.000986, klw: 0.0117, cost: 0.9156, recon: 0.9063, kl: 0.7934, train_time_taken: 117.7063
# INFO:tensorflow:step: 160, lr: 0.000984, klw: 0.0119, cost: 0.8193, recon: 0.8087, kl: 0.8933, train_time_taken: 118.0644
# INFO:tensorflow:step: 180, lr: 0.000982, klw: 0.0122, cost: 0.8034, recon: 0.7917, kl: 0.9661, train_time_taken: 118.8894
# INFO:tensorflow:step: 200, lr: 0.000980, klw: 0.0124, cost: 0.8426, recon: 0.8299, kl: 1.0265, train_time_taken: 118.8112
# INFO:tensorflow:step: 220, lr: 0.000978, klw: 0.0126, cost: 0.7327, recon: 0.7189, kl: 1.0934, train_time_taken: 117.8489
# INFO:tensorflow:step: 240, lr: 0.000977, klw: 0.0129, cost: 0.7540, recon: 0.7395, kl: 1.1308, train_time_taken: 117.8552
# INFO:tensorflow:step: 260, lr: 0.000975, klw: 0.0131, cost: 0.7767, recon: 0.7613, kl: 1.1791, train_time_taken: 119.1758
# INFO:tensorflow:step: 280, lr: 0.000973, klw: 0.0133, cost: 0.7590, recon: 0.7430, kl: 1.1991, train_time_taken: 118.7833
# INFO:tensorflow:step: 300, lr: 0.000971, klw: 0.0136, cost: 0.8080, recon: 0.7914, kl: 1.2273, train_time_taken: 118.9921
# INFO:tensorflow:step: 320, lr: 0.000969, klw: 0.0138, cost: 0.6973, recon: 0.6800, kl: 1.2514, train_time_taken: 118.5621
# INFO:tensorflow:step: 340, lr: 0.000967, klw: 0.0140, cost: 0.6914, recon: 0.6735, kl: 1.2711, train_time_taken: 118.9548
# INFO:tensorflow:step: 360, lr: 0.000965, klw: 0.0143, cost: 0.6880, recon: 0.6696, kl: 1.2894, train_time_taken: 118.3751
# INFO:tensorflow:step: 380, lr: 0.000963, klw: 0.0145, cost: 0.7087, recon: 0.6897, kl: 1.3051, train_time_taken: 117.8433
# INFO:tensorflow:step: 400, lr: 0.000961, klw: 0.0148, cost: 0.6627, recon: 0.6434, kl: 1.3071, train_time_taken: 117.2305
# INFO:tensorflow:step: 420, lr: 0.000959, klw: 0.0150, cost: 0.6906, recon: 0.6708, kl: 1.3188, train_time_taken: 118.3055
# INFO:tensorflow:step: 440, lr: 0.000957, klw: 0.0152, cost: 0.7344, recon: 0.7143, kl: 1.3220, train_time_taken: 118.3703
# INFO:tensorflow:step: 460, lr: 0.000955, klw: 0.0155, cost: 0.6826, recon: 0.6621, kl: 1.3305, train_time_taken: 117.4128
# INFO:tensorflow:step: 480, lr: 0.000954, klw: 0.0157, cost: 0.6741, recon: 0.6531, kl: 1.3356, train_time_taken: 117.5914
# INFO:tensorflow:step: 500, lr: 0.000952, klw: 0.0159, cost: 0.6406, recon: 0.6192, kl: 1.3440, train_time_taken: 118.9618
# INFO:tensorflow:best_valid_cost: 0.6371, valid_cost: 0.6371, valid_recon: 0.6235, valid_kl: 1.3555, valid_time_taken: 5.3390
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 500.
# INFO:tensorflow:time_taken_save 0.6495.
# INFO:tensorflow:eval_cost: 0.6120, eval_recon: 0.5984, eval_kl: 1.3534, eval_time_taken: 4.7359
# INFO:tensorflow:step: 520, lr: 0.000950, klw: 0.0162, cost: 0.6747, recon: 0.6530, kl: 1.3419, train_time_taken: 119.4005
# INFO:tensorflow:step: 540, lr: 0.000948, klw: 0.0164, cost: 0.6491, recon: 0.6269, kl: 1.3552, train_time_taken: 119.1627
# INFO:tensorflow:step: 560, lr: 0.000946, klw: 0.0166, cost: 0.6041, recon: 0.5816, kl: 1.3531, train_time_taken: 118.7573
# INFO:tensorflow:step: 580, lr: 0.000944, klw: 0.0169, cost: 0.6539, recon: 0.6308, kl: 1.3655, train_time_taken: 118.7810
# INFO:tensorflow:step: 600, lr: 0.000942, klw: 0.0171, cost: 0.6113, recon: 0.5882, kl: 1.3517, train_time_taken: 118.7897
# INFO:tensorflow:step: 620, lr: 0.000940, klw: 0.0173, cost: 0.5353, recon: 0.5120, kl: 1.3440, train_time_taken: 119.6842
# INFO:tensorflow:step: 640, lr: 0.000939, klw: 0.0176, cost: 0.6031, recon: 0.5797, kl: 1.3311, train_time_taken: 119.1500
# INFO:tensorflow:step: 660, lr: 0.000937, klw: 0.0178, cost: 0.6788, recon: 0.6551, kl: 1.3358, train_time_taken: 118.2230
# INFO:tensorflow:step: 680, lr: 0.000935, klw: 0.0180, cost: 0.6570, recon: 0.6333, kl: 1.3139, train_time_taken: 117.6154
# INFO:tensorflow:step: 700, lr: 0.000933, klw: 0.0183, cost: 0.6217, recon: 0.5980, kl: 1.3035, train_time_taken: 117.2042
# INFO:tensorflow:step: 720, lr: 0.000931, klw: 0.0185, cost: 0.5539, recon: 0.5301, kl: 1.2892, train_time_taken: 118.6582
# INFO:tensorflow:step: 740, lr: 0.000929, klw: 0.0187, cost: 0.5946, recon: 0.5704, kl: 1.2914, train_time_taken: 118.4208
# INFO:tensorflow:step: 760, lr: 0.000928, klw: 0.0189, cost: 0.7052, recon: 0.6809, kl: 1.2818, train_time_taken: 117.4416
# INFO:tensorflow:step: 780, lr: 0.000926, klw: 0.0192, cost: 0.6424, recon: 0.6180, kl: 1.2691, train_time_taken: 118.3433
# INFO:tensorflow:step: 800, lr: 0.000924, klw: 0.0194, cost: 0.6280, recon: 0.6032, kl: 1.2743, train_time_taken: 118.8666
# INFO:tensorflow:step: 820, lr: 0.000922, klw: 0.0196, cost: 0.5490, recon: 0.5246, kl: 1.2420, train_time_taken: 118.3069
# INFO:tensorflow:step: 840, lr: 0.000920, klw: 0.0199, cost: 0.5875, recon: 0.5626, kl: 1.2534, train_time_taken: 117.8044
# INFO:tensorflow:step: 860, lr: 0.000918, klw: 0.0201, cost: 0.5862, recon: 0.5613, kl: 1.2408, train_time_taken: 119.4761
# INFO:tensorflow:step: 880, lr: 0.000917, klw: 0.0203, cost: 0.5182, recon: 0.4933, kl: 1.2278, train_time_taken: 118.0585
# INFO:tensorflow:step: 900, lr: 0.000915, klw: 0.0206, cost: 0.5834, recon: 0.5583, kl: 1.2203, train_time_taken: 119.2033
# INFO:tensorflow:step: 920, lr: 0.000913, klw: 0.0208, cost: 0.5889, recon: 0.5637, kl: 1.2119, train_time_taken: 118.3429
# INFO:tensorflow:step: 940, lr: 0.000911, klw: 0.0210, cost: 0.5585, recon: 0.5335, kl: 1.1888, train_time_taken: 118.3225
# INFO:tensorflow:step: 960, lr: 0.000909, klw: 0.0212, cost: 0.5757, recon: 0.5499, kl: 1.2105, train_time_taken: 116.7519
# INFO:tensorflow:step: 980, lr: 0.000908, klw: 0.0215, cost: 0.5428, recon: 0.5174, kl: 1.1813, train_time_taken: 117.1095
# INFO:tensorflow:step: 1000, lr: 0.000906, klw: 0.0217, cost: 0.5694, recon: 0.5444, kl: 1.1549, train_time_taken: 118.3642
# INFO:tensorflow:best_valid_cost: 0.5283, valid_cost: 0.5283, valid_recon: 0.5164, valid_kl: 1.1893, valid_time_taken: 4.6620
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 1000.
# INFO:tensorflow:time_taken_save 0.6228.
# INFO:tensorflow:eval_cost: 0.5000, eval_recon: 0.4882, eval_kl: 1.1874, eval_time_taken: 4.6769
# INFO:tensorflow:step: 1020, lr: 0.000904, klw: 0.0219, cost: 0.5458, recon: 0.5206, kl: 1.1488, train_time_taken: 117.9323
# INFO:tensorflow:step: 1040, lr: 0.000902, klw: 0.0222, cost: 0.5874, recon: 0.5619, kl: 1.1515, train_time_taken: 118.2778
# INFO:tensorflow:step: 1060, lr: 0.000900, klw: 0.0224, cost: 0.5199, recon: 0.4942, kl: 1.1500, train_time_taken: 117.4486
# INFO:tensorflow:step: 1080, lr: 0.000899, klw: 0.0226, cost: 0.5453, recon: 0.5198, kl: 1.1268, train_time_taken: 117.2299
# INFO:tensorflow:step: 1100, lr: 0.000897, klw: 0.0228, cost: 0.5419, recon: 0.5161, kl: 1.1286, train_time_taken: 117.1686
# INFO:tensorflow:step: 1120, lr: 0.000895, klw: 0.0231, cost: 0.5579, recon: 0.5323, kl: 1.1082, train_time_taken: 117.7242
# INFO:tensorflow:step: 1140, lr: 0.000893, klw: 0.0233, cost: 0.5363, recon: 0.5109, kl: 1.0894, train_time_taken: 118.8629
# INFO:tensorflow:step: 1160, lr: 0.000892, klw: 0.0235, cost: 0.5372, recon: 0.5112, kl: 1.1048, train_time_taken: 118.0200
# INFO:tensorflow:step: 1180, lr: 0.000890, klw: 0.0238, cost: 0.5596, recon: 0.5337, kl: 1.0880, train_time_taken: 117.5638
# INFO:tensorflow:step: 1200, lr: 0.000888, klw: 0.0240, cost: 0.5219, recon: 0.4966, kl: 1.0544, train_time_taken: 119.0724
# INFO:tensorflow:step: 1220, lr: 0.000886, klw: 0.0242, cost: 0.5266, recon: 0.5004, kl: 1.0818, train_time_taken: 117.5956
# INFO:tensorflow:step: 1240, lr: 0.000885, klw: 0.0244, cost: 0.5359, recon: 0.5104, kl: 1.0426, train_time_taken: 118.8533
# INFO:tensorflow:step: 1260, lr: 0.000883, klw: 0.0247, cost: 0.5127, recon: 0.4866, kl: 1.0572, train_time_taken: 117.7402
# INFO:tensorflow:step: 1280, lr: 0.000881, klw: 0.0249, cost: 0.5755, recon: 0.5492, kl: 1.0569, train_time_taken: 118.7926
# INFO:tensorflow:step: 1300, lr: 0.000879, klw: 0.0251, cost: 0.5502, recon: 0.5251, kl: 1.0013, train_time_taken: 116.9229
# INFO:tensorflow:step: 1320, lr: 0.000878, klw: 0.0253, cost: 0.5512, recon: 0.5254, kl: 1.0185, train_time_taken: 118.2879
# INFO:tensorflow:step: 1340, lr: 0.000876, klw: 0.0256, cost: 0.5062, recon: 0.4808, kl: 0.9954, train_time_taken: 118.9484
# INFO:tensorflow:step: 1360, lr: 0.000874, klw: 0.0258, cost: 0.4864, recon: 0.4613, kl: 0.9735, train_time_taken: 117.9971
# INFO:tensorflow:step: 1380, lr: 0.000872, klw: 0.0260, cost: 0.4910, recon: 0.4657, kl: 0.9728, train_time_taken: 117.3704
# INFO:tensorflow:step: 1400, lr: 0.000871, klw: 0.0262, cost: 0.5175, recon: 0.4914, kl: 0.9945, train_time_taken: 118.0749
# INFO:tensorflow:step: 1420, lr: 0.000869, klw: 0.0264, cost: 0.5088, recon: 0.4837, kl: 0.9464, train_time_taken: 118.7636
# INFO:tensorflow:step: 1440, lr: 0.000867, klw: 0.0267, cost: 0.5316, recon: 0.5054, kl: 0.9824, train_time_taken: 117.5368
# INFO:tensorflow:step: 1460, lr: 0.000866, klw: 0.0269, cost: 0.4222, recon: 0.3971, kl: 0.9318, train_time_taken: 118.3895
# INFO:tensorflow:step: 1480, lr: 0.000864, klw: 0.0271, cost: 0.5254, recon: 0.5000, kl: 0.9371, train_time_taken: 117.6209
# INFO:tensorflow:step: 1500, lr: 0.000862, klw: 0.0273, cost: 0.4811, recon: 0.4552, kl: 0.9456, train_time_taken: 118.8006
# INFO:tensorflow:best_valid_cost: 0.4791, valid_cost: 0.4791, valid_recon: 0.4695, valid_kl: 0.9633, valid_time_taken: 4.8746
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 1500.
# INFO:tensorflow:time_taken_save 0.6095.
# INFO:tensorflow:eval_cost: 0.4473, eval_recon: 0.4377, eval_kl: 0.9604, eval_time_taken: 4.7651
# INFO:tensorflow:step: 1520, lr: 0.000860, klw: 0.0276, cost: 0.5495, recon: 0.5244, kl: 0.9109, train_time_taken: 117.5866
# INFO:tensorflow:step: 1540, lr: 0.000859, klw: 0.0278, cost: 0.5339, recon: 0.5084, kl: 0.9195, train_time_taken: 118.2507
# INFO:tensorflow:step: 1560, lr: 0.000857, klw: 0.0280, cost: 0.4832, recon: 0.4585, kl: 0.8837, train_time_taken: 118.4698
# INFO:tensorflow:step: 1580, lr: 0.000855, klw: 0.0282, cost: 0.4907, recon: 0.4656, kl: 0.8873, train_time_taken: 118.5343
# INFO:tensorflow:step: 1600, lr: 0.000854, klw: 0.0285, cost: 0.5900, recon: 0.5647, kl: 0.8896, train_time_taken: 117.9543
# INFO:tensorflow:step: 1620, lr: 0.000852, klw: 0.0287, cost: 0.4645, recon: 0.4385, kl: 0.9075, train_time_taken: 117.9887
# INFO:tensorflow:step: 1640, lr: 0.000850, klw: 0.0289, cost: 0.5141, recon: 0.4891, kl: 0.8673, train_time_taken: 117.3590
# INFO:tensorflow:step: 1660, lr: 0.000849, klw: 0.0291, cost: 0.4786, recon: 0.4535, kl: 0.8600, train_time_taken: 118.7591
# INFO:tensorflow:step: 1680, lr: 0.000847, klw: 0.0293, cost: 0.4942, recon: 0.4700, kl: 0.8242, train_time_taken: 118.6878
# INFO:tensorflow:step: 1700, lr: 0.000845, klw: 0.0296, cost: 0.4532, recon: 0.4285, kl: 0.8350, train_time_taken: 118.5997
# INFO:tensorflow:step: 1720, lr: 0.000844, klw: 0.0298, cost: 0.4581, recon: 0.4323, kl: 0.8667, train_time_taken: 118.7692
# INFO:tensorflow:step: 1740, lr: 0.000842, klw: 0.0300, cost: 0.5596, recon: 0.5343, kl: 0.8412, train_time_taken: 118.3331
# INFO:tensorflow:step: 1760, lr: 0.000840, klw: 0.0302, cost: 0.4889, recon: 0.4630, kl: 0.8577, train_time_taken: 117.6156
# INFO:tensorflow:step: 1780, lr: 0.000839, klw: 0.0304, cost: 0.5512, recon: 0.5264, kl: 0.8150, train_time_taken: 118.8505
# INFO:tensorflow:step: 1800, lr: 0.000837, klw: 0.0307, cost: 0.5025, recon: 0.4774, kl: 0.8181, train_time_taken: 116.6030
# INFO:tensorflow:step: 1820, lr: 0.000835, klw: 0.0309, cost: 0.4473, recon: 0.4222, kl: 0.8126, train_time_taken: 117.7012
# INFO:tensorflow:step: 1840, lr: 0.000834, klw: 0.0311, cost: 0.4539, recon: 0.4288, kl: 0.8061, train_time_taken: 117.5899
# INFO:tensorflow:step: 1860, lr: 0.000832, klw: 0.0313, cost: 0.4423, recon: 0.4181, kl: 0.7728, train_time_taken: 119.1890
# INFO:tensorflow:step: 1880, lr: 0.000830, klw: 0.0315, cost: 0.4379, recon: 0.4136, kl: 0.7710, train_time_taken: 118.1700
# INFO:tensorflow:step: 1900, lr: 0.000829, klw: 0.0318, cost: 0.5074, recon: 0.4826, kl: 0.7820, train_time_taken: 118.0429
# INFO:tensorflow:step: 1920, lr: 0.000827, klw: 0.0320, cost: 0.5133, recon: 0.4892, kl: 0.7547, train_time_taken: 117.9461
# INFO:tensorflow:step: 1940, lr: 0.000825, klw: 0.0322, cost: 0.5020, recon: 0.4772, kl: 0.7690, train_time_taken: 117.9533
# INFO:tensorflow:step: 1960, lr: 0.000824, klw: 0.0324, cost: 0.4338, recon: 0.4094, kl: 0.7526, train_time_taken: 118.3276
# INFO:tensorflow:step: 1980, lr: 0.000822, klw: 0.0326, cost: 0.4365, recon: 0.4119, kl: 0.7528, train_time_taken: 118.7590
# INFO:tensorflow:step: 2000, lr: 0.000821, klw: 0.0328, cost: 0.4453, recon: 0.4211, kl: 0.7362, train_time_taken: 117.1869
# INFO:tensorflow:best_valid_cost: 0.4398, valid_cost: 0.4398, valid_recon: 0.4320, valid_kl: 0.7759, valid_time_taken: 4.7708
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 2000.
# INFO:tensorflow:time_taken_save 0.6451.
# INFO:tensorflow:eval_cost: 0.4100, eval_recon: 0.4023, eval_kl: 0.7721, eval_time_taken: 4.8744
# INFO:tensorflow:step: 2020, lr: 0.000819, klw: 0.0331, cost: 0.4859, recon: 0.4621, kl: 0.7194, train_time_taken: 117.8841
# INFO:tensorflow:step: 2040, lr: 0.000817, klw: 0.0333, cost: 0.4921, recon: 0.4672, kl: 0.7486, train_time_taken: 118.8579
# INFO:tensorflow:step: 2060, lr: 0.000816, klw: 0.0335, cost: 0.5013, recon: 0.4767, kl: 0.7344, train_time_taken: 118.6811
# INFO:tensorflow:step: 2080, lr: 0.000814, klw: 0.0337, cost: 0.4396, recon: 0.4157, kl: 0.7077, train_time_taken: 118.4474
# INFO:tensorflow:step: 2100, lr: 0.000812, klw: 0.0339, cost: 0.5000, recon: 0.4756, kl: 0.7194, train_time_taken: 118.4367
# INFO:tensorflow:step: 2120, lr: 0.000811, klw: 0.0341, cost: 0.4818, recon: 0.4583, kl: 0.6881, train_time_taken: 118.2581
# INFO:tensorflow:step: 2140, lr: 0.000809, klw: 0.0344, cost: 0.4762, recon: 0.4513, kl: 0.7254, train_time_taken: 118.8096
# INFO:tensorflow:step: 2160, lr: 0.000808, klw: 0.0346, cost: 0.5011, recon: 0.4766, kl: 0.7065, train_time_taken: 118.0016
# INFO:tensorflow:step: 2180, lr: 0.000806, klw: 0.0348, cost: 0.4841, recon: 0.4594, kl: 0.7090, train_time_taken: 118.0612
# INFO:tensorflow:step: 2200, lr: 0.000804, klw: 0.0350, cost: 0.4586, recon: 0.4344, kl: 0.6914, train_time_taken: 118.6170
# INFO:tensorflow:step: 2220, lr: 0.000803, klw: 0.0352, cost: 0.4741, recon: 0.4491, kl: 0.7105, train_time_taken: 117.4409
# INFO:tensorflow:step: 2240, lr: 0.000801, klw: 0.0354, cost: 0.4769, recon: 0.4523, kl: 0.6957, train_time_taken: 119.1639
# INFO:tensorflow:step: 2260, lr: 0.000800, klw: 0.0356, cost: 0.3956, recon: 0.3720, kl: 0.6615, train_time_taken: 117.8583
# INFO:tensorflow:step: 2280, lr: 0.000798, klw: 0.0359, cost: 0.4499, recon: 0.4245, kl: 0.7077, train_time_taken: 118.5736
# INFO:tensorflow:step: 2300, lr: 0.000797, klw: 0.0361, cost: 0.4242, recon: 0.4004, kl: 0.6608, train_time_taken: 119.6951
# INFO:tensorflow:step: 2320, lr: 0.000795, klw: 0.0363, cost: 0.4983, recon: 0.4732, kl: 0.6931, train_time_taken: 118.4288
# INFO:tensorflow:step: 2340, lr: 0.000793, klw: 0.0365, cost: 0.4545, recon: 0.4300, kl: 0.6692, train_time_taken: 119.5778
# INFO:tensorflow:step: 2360, lr: 0.000792, klw: 0.0367, cost: 0.4570, recon: 0.4330, kl: 0.6527, train_time_taken: 118.0398
# INFO:tensorflow:step: 2380, lr: 0.000790, klw: 0.0369, cost: 0.4657, recon: 0.4417, kl: 0.6520, train_time_taken: 118.4798
# INFO:tensorflow:step: 2400, lr: 0.000789, klw: 0.0371, cost: 0.4011, recon: 0.3782, kl: 0.6166, train_time_taken: 119.7930
# INFO:tensorflow:step: 2420, lr: 0.000787, klw: 0.0374, cost: 0.4182, recon: 0.3939, kl: 0.6511, train_time_taken: 117.9145
# INFO:tensorflow:step: 2440, lr: 0.000786, klw: 0.0376, cost: 0.4708, recon: 0.4444, kl: 0.7012, train_time_taken: 118.2822
# INFO:tensorflow:step: 2460, lr: 0.000784, klw: 0.0378, cost: 0.4316, recon: 0.4076, kl: 0.6365, train_time_taken: 119.1193
# INFO:tensorflow:step: 2480, lr: 0.000783, klw: 0.0380, cost: 0.4001, recon: 0.3755, kl: 0.6468, train_time_taken: 117.5407
# INFO:tensorflow:step: 2500, lr: 0.000781, klw: 0.0382, cost: 0.4060, recon: 0.3808, kl: 0.6582, train_time_taken: 118.3134
# INFO:tensorflow:best_valid_cost: 0.3996, valid_cost: 0.3996, valid_recon: 0.3927, valid_kl: 0.6925, valid_time_taken: 4.6488
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 2500.
# INFO:tensorflow:time_taken_save 0.6862.
# INFO:tensorflow:eval_cost: 0.3686, eval_recon: 0.3617, eval_kl: 0.6884, eval_time_taken: 4.9815
# INFO:tensorflow:step: 2520, lr: 0.000779, klw: 0.0384, cost: 0.4343, recon: 0.4088, kl: 0.6650, train_time_taken: 117.1831
# INFO:tensorflow:step: 2540, lr: 0.000778, klw: 0.0386, cost: 0.5293, recon: 0.5035, kl: 0.6659, train_time_taken: 117.3769
# INFO:tensorflow:step: 2560, lr: 0.000776, klw: 0.0388, cost: 0.4409, recon: 0.4166, kl: 0.6269, train_time_taken: 118.3099
# INFO:tensorflow:step: 2580, lr: 0.000775, klw: 0.0390, cost: 0.3894, recon: 0.3641, kl: 0.6475, train_time_taken: 118.0971
# INFO:tensorflow:step: 2600, lr: 0.000773, klw: 0.0393, cost: 0.3963, recon: 0.3711, kl: 0.6416, train_time_taken: 119.0868
# INFO:tensorflow:step: 2620, lr: 0.000772, klw: 0.0395, cost: 0.4373, recon: 0.4122, kl: 0.6357, train_time_taken: 117.6324
# INFO:tensorflow:step: 2640, lr: 0.000770, klw: 0.0397, cost: 0.4360, recon: 0.4104, kl: 0.6451, train_time_taken: 118.7950
# INFO:tensorflow:step: 2660, lr: 0.000769, klw: 0.0399, cost: 0.4448, recon: 0.4208, kl: 0.6018, train_time_taken: 118.6096
# INFO:tensorflow:step: 2680, lr: 0.000767, klw: 0.0401, cost: 0.3978, recon: 0.3717, kl: 0.6504, train_time_taken: 117.6403
# INFO:tensorflow:step: 2700, lr: 0.000766, klw: 0.0403, cost: 0.4080, recon: 0.3825, kl: 0.6321, train_time_taken: 118.2959
# INFO:tensorflow:step: 2720, lr: 0.000764, klw: 0.0405, cost: 0.3886, recon: 0.3629, kl: 0.6360, train_time_taken: 119.0975
# INFO:tensorflow:step: 2740, lr: 0.000763, klw: 0.0407, cost: 0.4916, recon: 0.4648, kl: 0.6572, train_time_taken: 118.4132
# INFO:tensorflow:step: 2760, lr: 0.000761, klw: 0.0409, cost: 0.3788, recon: 0.3520, kl: 0.6537, train_time_taken: 119.3529
# INFO:tensorflow:step: 2780, lr: 0.000760, klw: 0.0411, cost: 0.3818, recon: 0.3571, kl: 0.6002, train_time_taken: 117.4712
# INFO:tensorflow:step: 2800, lr: 0.000758, klw: 0.0414, cost: 0.4248, recon: 0.3985, kl: 0.6371, train_time_taken: 116.9583
# INFO:tensorflow:step: 2820, lr: 0.000757, klw: 0.0416, cost: 0.4338, recon: 0.4074, kl: 0.6361, train_time_taken: 118.4787
# INFO:tensorflow:step: 2840, lr: 0.000755, klw: 0.0418, cost: 0.3895, recon: 0.3634, kl: 0.6237, train_time_taken: 117.2805
# INFO:tensorflow:step: 2860, lr: 0.000754, klw: 0.0420, cost: 0.3347, recon: 0.3092, kl: 0.6058, train_time_taken: 118.0001
# INFO:tensorflow:step: 2880, lr: 0.000752, klw: 0.0422, cost: 0.3878, recon: 0.3595, kl: 0.6700, train_time_taken: 117.3677
# INFO:tensorflow:step: 2900, lr: 0.000751, klw: 0.0424, cost: 0.3683, recon: 0.3419, kl: 0.6244, train_time_taken: 117.0874
# INFO:tensorflow:step: 2920, lr: 0.000749, klw: 0.0426, cost: 0.3993, recon: 0.3720, kl: 0.6414, train_time_taken: 119.9647
# INFO:tensorflow:step: 2940, lr: 0.000748, klw: 0.0428, cost: 0.3578, recon: 0.3305, kl: 0.6368, train_time_taken: 118.3810
# INFO:tensorflow:step: 2960, lr: 0.000746, klw: 0.0430, cost: 0.3430, recon: 0.3162, kl: 0.6237, train_time_taken: 118.0975
# INFO:tensorflow:step: 2980, lr: 0.000745, klw: 0.0432, cost: 0.3416, recon: 0.3134, kl: 0.6529, train_time_taken: 118.1657
# INFO:tensorflow:step: 3000, lr: 0.000743, klw: 0.0434, cost: 0.3292, recon: 0.3014, kl: 0.6402, train_time_taken: 117.1145
# INFO:tensorflow:best_valid_cost: 0.2931, valid_cost: 0.2931, valid_recon: 0.2862, valid_kl: 0.6877, valid_time_taken: 4.6988
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 3000.
# INFO:tensorflow:time_taken_save 0.6704.
# INFO:tensorflow:eval_cost: 0.2715, eval_recon: 0.2647, eval_kl: 0.6816, eval_time_taken: 4.7112
# INFO:tensorflow:step: 3020, lr: 0.000742, klw: 0.0436, cost: 0.4078, recon: 0.3782, kl: 0.6790, train_time_taken: 118.9699
# INFO:tensorflow:step: 3040, lr: 0.000740, klw: 0.0438, cost: 0.3059, recon: 0.2809, kl: 0.5702, train_time_taken: 117.1841
# INFO:tensorflow:step: 3060, lr: 0.000739, klw: 0.0440, cost: 0.3802, recon: 0.3534, kl: 0.6082, train_time_taken: 118.4373
# INFO:tensorflow:step: 3080, lr: 0.000738, klw: 0.0443, cost: 0.3626, recon: 0.3343, kl: 0.6400, train_time_taken: 118.5758
# INFO:tensorflow:step: 3100, lr: 0.000736, klw: 0.0445, cost: 0.2791, recon: 0.2519, kl: 0.6109, train_time_taken: 118.0553
# INFO:tensorflow:step: 3120, lr: 0.000735, klw: 0.0447, cost: 0.3794, recon: 0.3519, kl: 0.6160, train_time_taken: 118.8051
# INFO:tensorflow:step: 3140, lr: 0.000733, klw: 0.0449, cost: 0.3242, recon: 0.3011, kl: 0.5164, train_time_taken: 116.4730
# INFO:tensorflow:step: 3160, lr: 0.000732, klw: 0.0451, cost: 0.3485, recon: 0.3233, kl: 0.5582, train_time_taken: 117.1760
# INFO:tensorflow:step: 3180, lr: 0.000730, klw: 0.0453, cost: 0.3176, recon: 0.2922, kl: 0.5601, train_time_taken: 118.1611
# INFO:tensorflow:step: 3200, lr: 0.000729, klw: 0.0455, cost: 0.3658, recon: 0.3399, kl: 0.5688, train_time_taken: 118.4946
# INFO:tensorflow:step: 3220, lr: 0.000727, klw: 0.0457, cost: 0.3097, recon: 0.2831, kl: 0.5816, train_time_taken: 118.7990
# INFO:tensorflow:step: 3240, lr: 0.000726, klw: 0.0459, cost: 0.3951, recon: 0.3694, kl: 0.5589, train_time_taken: 117.4355
# INFO:tensorflow:step: 3260, lr: 0.000725, klw: 0.0461, cost: 0.3655, recon: 0.3374, kl: 0.6094, train_time_taken: 118.7628
# INFO:tensorflow:step: 3280, lr: 0.000723, klw: 0.0463, cost: 0.3331, recon: 0.3050, kl: 0.6066, train_time_taken: 119.3096
# INFO:tensorflow:step: 3300, lr: 0.000722, klw: 0.0465, cost: 0.3606, recon: 0.3351, kl: 0.5474, train_time_taken: 119.2537
# INFO:tensorflow:step: 3320, lr: 0.000720, klw: 0.0467, cost: 0.3097, recon: 0.2840, kl: 0.5496, train_time_taken: 117.2931
# INFO:tensorflow:step: 3340, lr: 0.000719, klw: 0.0469, cost: 0.3423, recon: 0.3153, kl: 0.5750, train_time_taken: 118.6178
# INFO:tensorflow:step: 3360, lr: 0.000717, klw: 0.0471, cost: 0.3153, recon: 0.2910, kl: 0.5159, train_time_taken: 118.6160
# INFO:tensorflow:step: 3380, lr: 0.000716, klw: 0.0473, cost: 0.3835, recon: 0.3562, kl: 0.5770, train_time_taken: 117.6831
# INFO:tensorflow:step: 3400, lr: 0.000715, klw: 0.0475, cost: 0.3630, recon: 0.3368, kl: 0.5505, train_time_taken: 118.6237
# INFO:tensorflow:step: 3420, lr: 0.000713, klw: 0.0477, cost: 0.2963, recon: 0.2705, kl: 0.5394, train_time_taken: 117.5563
# INFO:tensorflow:step: 3440, lr: 0.000712, klw: 0.0479, cost: 0.2661, recon: 0.2397, kl: 0.5507, train_time_taken: 118.6120
# INFO:tensorflow:step: 3460, lr: 0.000710, klw: 0.0481, cost: 0.3025, recon: 0.2768, kl: 0.5339, train_time_taken: 117.7356
# INFO:tensorflow:step: 3480, lr: 0.000709, klw: 0.0483, cost: 0.3341, recon: 0.3067, kl: 0.5663, train_time_taken: 117.4207
# INFO:tensorflow:step: 3500, lr: 0.000708, klw: 0.0485, cost: 0.3477, recon: 0.3210, kl: 0.5492, train_time_taken: 116.5808
# INFO:tensorflow:best_valid_cost: 0.2781, valid_cost: 0.2781, valid_recon: 0.2724, valid_kl: 0.5728, valid_time_taken: 4.7277
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 3500.
# INFO:tensorflow:time_taken_save 0.6600.
# INFO:tensorflow:eval_cost: 0.2566, eval_recon: 0.2509, eval_kl: 0.5668, eval_time_taken: 4.7460
# INFO:tensorflow:step: 3520, lr: 0.000706, klw: 0.0487, cost: 0.3055, recon: 0.2791, kl: 0.5411, train_time_taken: 117.4907
# INFO:tensorflow:step: 3540, lr: 0.000705, klw: 0.0489, cost: 0.2928, recon: 0.2651, kl: 0.5673, train_time_taken: 117.1404
# INFO:tensorflow:step: 3560, lr: 0.000703, klw: 0.0491, cost: 0.2842, recon: 0.2581, kl: 0.5314, train_time_taken: 118.3614
# INFO:tensorflow:step: 3580, lr: 0.000702, klw: 0.0493, cost: 0.3418, recon: 0.3132, kl: 0.5802, train_time_taken: 117.9142
# INFO:tensorflow:step: 3600, lr: 0.000701, klw: 0.0495, cost: 0.3829, recon: 0.3544, kl: 0.5751, train_time_taken: 119.3680
# INFO:tensorflow:step: 3620, lr: 0.000699, klw: 0.0497, cost: 0.2794, recon: 0.2513, kl: 0.5662, train_time_taken: 118.5745
# INFO:tensorflow:step: 3640, lr: 0.000698, klw: 0.0499, cost: 0.2850, recon: 0.2571, kl: 0.5574, train_time_taken: 117.1765
# INFO:tensorflow:step: 3660, lr: 0.000697, klw: 0.0501, cost: 0.2792, recon: 0.2520, kl: 0.5440, train_time_taken: 118.6172
# INFO:tensorflow:step: 3680, lr: 0.000695, klw: 0.0503, cost: 0.3574, recon: 0.3306, kl: 0.5329, train_time_taken: 117.5813
# INFO:tensorflow:step: 3700, lr: 0.000694, klw: 0.0505, cost: 0.3497, recon: 0.3204, kl: 0.5783, train_time_taken: 118.6188
# INFO:tensorflow:step: 3720, lr: 0.000692, klw: 0.0507, cost: 0.2757, recon: 0.2465, kl: 0.5748, train_time_taken: 117.5510
# INFO:tensorflow:step: 3740, lr: 0.000691, klw: 0.0509, cost: 0.3005, recon: 0.2716, kl: 0.5655, train_time_taken: 119.4235
# INFO:tensorflow:step: 3760, lr: 0.000690, klw: 0.0511, cost: 0.2538, recon: 0.2269, kl: 0.5246, train_time_taken: 118.9448
# INFO:tensorflow:step: 3780, lr: 0.000688, klw: 0.0513, cost: 0.2973, recon: 0.2710, kl: 0.5116, train_time_taken: 118.8992
# INFO:tensorflow:step: 3800, lr: 0.000687, klw: 0.0515, cost: 0.2477, recon: 0.2185, kl: 0.5679, train_time_taken: 118.2545
# INFO:tensorflow:step: 3820, lr: 0.000686, klw: 0.0517, cost: 0.2437, recon: 0.2136, kl: 0.5819, train_time_taken: 119.1570
# INFO:tensorflow:step: 3840, lr: 0.000684, klw: 0.0519, cost: 0.2476, recon: 0.2192, kl: 0.5469, train_time_taken: 119.0240
# INFO:tensorflow:step: 3860, lr: 0.000683, klw: 0.0521, cost: 0.2637, recon: 0.2338, kl: 0.5732, train_time_taken: 118.6560
# INFO:tensorflow:step: 3880, lr: 0.000682, klw: 0.0523, cost: 0.2845, recon: 0.2550, kl: 0.5653, train_time_taken: 117.4621
# INFO:tensorflow:step: 3900, lr: 0.000680, klw: 0.0525, cost: 0.2857, recon: 0.2532, kl: 0.6199, train_time_taken: 119.2160
# INFO:tensorflow:step: 3920, lr: 0.000679, klw: 0.0527, cost: 0.2836, recon: 0.2540, kl: 0.5626, train_time_taken: 118.0867
# INFO:tensorflow:step: 3940, lr: 0.000678, klw: 0.0529, cost: 0.2580, recon: 0.2288, kl: 0.5521, train_time_taken: 117.5005
# INFO:tensorflow:step: 3960, lr: 0.000676, klw: 0.0531, cost: 0.2883, recon: 0.2587, kl: 0.5561, train_time_taken: 118.6321
# INFO:tensorflow:step: 3980, lr: 0.000675, klw: 0.0533, cost: 0.2268, recon: 0.2009, kl: 0.4867, train_time_taken: 117.8112
# INFO:tensorflow:step: 4000, lr: 0.000674, klw: 0.0535, cost: 0.2537, recon: 0.2250, kl: 0.5356, train_time_taken: 117.0659
# INFO:tensorflow:best_valid_cost: 0.1896, valid_cost: 0.1896, valid_recon: 0.1838, valid_kl: 0.5769, valid_time_taken: 4.7338
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 4000.
# INFO:tensorflow:time_taken_save 0.6866.
# INFO:tensorflow:eval_cost: 0.1657, eval_recon: 0.1600, eval_kl: 0.5702, eval_time_taken: 4.6440
# INFO:tensorflow:step: 4020, lr: 0.000672, klw: 0.0537, cost: 0.2582, recon: 0.2283, kl: 0.5558, train_time_taken: 117.4027
# INFO:tensorflow:step: 4040, lr: 0.000671, klw: 0.0539, cost: 0.2516, recon: 0.2227, kl: 0.5369, train_time_taken: 118.4776
# INFO:tensorflow:step: 4060, lr: 0.000670, klw: 0.0541, cost: 0.2730, recon: 0.2434, kl: 0.5480, train_time_taken: 117.3261
# INFO:tensorflow:step: 4080, lr: 0.000668, klw: 0.0543, cost: 0.2169, recon: 0.1880, kl: 0.5318, train_time_taken: 118.6748
# INFO:tensorflow:step: 4100, lr: 0.000667, klw: 0.0545, cost: 0.2621, recon: 0.2324, kl: 0.5447, train_time_taken: 118.3979
# INFO:tensorflow:step: 4120, lr: 0.000666, klw: 0.0547, cost: 0.2693, recon: 0.2392, kl: 0.5498, train_time_taken: 118.2530
# INFO:tensorflow:step: 4140, lr: 0.000664, klw: 0.0549, cost: 0.2821, recon: 0.2541, kl: 0.5109, train_time_taken: 118.4931
# INFO:tensorflow:step: 4160, lr: 0.000663, klw: 0.0551, cost: 0.3147, recon: 0.2858, kl: 0.5239, train_time_taken: 118.5629
# INFO:tensorflow:step: 4180, lr: 0.000662, klw: 0.0553, cost: 0.2972, recon: 0.2666, kl: 0.5537, train_time_taken: 118.6469
# INFO:tensorflow:step: 4200, lr: 0.000660, klw: 0.0555, cost: 0.2360, recon: 0.2071, kl: 0.5209, train_time_taken: 117.9395
# INFO:tensorflow:step: 4220, lr: 0.000659, klw: 0.0557, cost: 0.2809, recon: 0.2513, kl: 0.5306, train_time_taken: 118.1554
# INFO:tensorflow:step: 4240, lr: 0.000658, klw: 0.0558, cost: 0.2570, recon: 0.2290, kl: 0.4999, train_time_taken: 118.0225
# INFO:tensorflow:step: 4260, lr: 0.000657, klw: 0.0560, cost: 0.2480, recon: 0.2185, kl: 0.5256, train_time_taken: 117.4457
# INFO:tensorflow:step: 4280, lr: 0.000655, klw: 0.0562, cost: 0.2559, recon: 0.2280, kl: 0.4969, train_time_taken: 117.7047
# INFO:tensorflow:step: 4300, lr: 0.000654, klw: 0.0564, cost: 0.2619, recon: 0.2317, kl: 0.5357, train_time_taken: 118.6282
# INFO:tensorflow:step: 4320, lr: 0.000653, klw: 0.0566, cost: 0.3360, recon: 0.3072, kl: 0.5083, train_time_taken: 118.3648
# INFO:tensorflow:step: 4340, lr: 0.000651, klw: 0.0568, cost: 0.2608, recon: 0.2321, kl: 0.5060, train_time_taken: 118.3801
# INFO:tensorflow:step: 4360, lr: 0.000650, klw: 0.0570, cost: 0.2524, recon: 0.2230, kl: 0.5153, train_time_taken: 117.5605
# INFO:tensorflow:step: 4380, lr: 0.000649, klw: 0.0572, cost: 0.3167, recon: 0.2856, kl: 0.5434, train_time_taken: 118.6752
# INFO:tensorflow:step: 4400, lr: 0.000648, klw: 0.0574, cost: 0.2395, recon: 0.2096, kl: 0.5212, train_time_taken: 118.3431
# INFO:tensorflow:step: 4420, lr: 0.000646, klw: 0.0576, cost: 0.2043, recon: 0.1746, kl: 0.5162, train_time_taken: 118.5151
# INFO:tensorflow:step: 4440, lr: 0.000645, klw: 0.0578, cost: 0.2777, recon: 0.2485, kl: 0.5057, train_time_taken: 118.3893
# INFO:tensorflow:step: 4460, lr: 0.000644, klw: 0.0580, cost: 0.2071, recon: 0.1783, kl: 0.4960, train_time_taken: 118.0245
# INFO:tensorflow:step: 4480, lr: 0.000643, klw: 0.0582, cost: 0.1984, recon: 0.1675, kl: 0.5321, train_time_taken: 118.3220
# INFO:tensorflow:step: 4500, lr: 0.000641, klw: 0.0584, cost: 0.1700, recon: 0.1415, kl: 0.4880, train_time_taken: 118.0887
# INFO:tensorflow:best_valid_cost: 0.1378, valid_cost: 0.1378, valid_recon: 0.1324, valid_kl: 0.5400, valid_time_taken: 4.7236
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 4500.
# INFO:tensorflow:time_taken_save 0.6525.
# INFO:tensorflow:eval_cost: 0.1167, eval_recon: 0.1114, eval_kl: 0.5355, eval_time_taken: 4.8625
# INFO:tensorflow:step: 4520, lr: 0.000640, klw: 0.0585, cost: 0.2415, recon: 0.2102, kl: 0.5334, train_time_taken: 119.1121
# INFO:tensorflow:step: 4540, lr: 0.000639, klw: 0.0587, cost: 0.1859, recon: 0.1549, kl: 0.5262, train_time_taken: 117.3225
# INFO:tensorflow:step: 4560, lr: 0.000637, klw: 0.0589, cost: 0.2515, recon: 0.2223, kl: 0.4956, train_time_taken: 117.3721
# INFO:tensorflow:step: 4580, lr: 0.000636, klw: 0.0591, cost: 0.1966, recon: 0.1675, kl: 0.4929, train_time_taken: 117.3874
# INFO:tensorflow:step: 4600, lr: 0.000635, klw: 0.0593, cost: 0.3122, recon: 0.2843, kl: 0.4705, train_time_taken: 118.8531
# INFO:tensorflow:step: 4620, lr: 0.000634, klw: 0.0595, cost: 0.1810, recon: 0.1503, kl: 0.5166, train_time_taken: 118.4337
# INFO:tensorflow:step: 4640, lr: 0.000632, klw: 0.0597, cost: 0.2594, recon: 0.2315, kl: 0.4674, train_time_taken: 117.4524
# INFO:tensorflow:step: 4660, lr: 0.000631, klw: 0.0599, cost: 0.2576, recon: 0.2273, kl: 0.5060, train_time_taken: 116.8351
# INFO:tensorflow:step: 4680, lr: 0.000630, klw: 0.0601, cost: 0.1896, recon: 0.1612, kl: 0.4742, train_time_taken: 116.8312
# INFO:tensorflow:step: 4700, lr: 0.000629, klw: 0.0603, cost: 0.1940, recon: 0.1642, kl: 0.4941, train_time_taken: 117.6224
# INFO:tensorflow:step: 4720, lr: 0.000628, klw: 0.0605, cost: 0.2184, recon: 0.1887, kl: 0.4911, train_time_taken: 118.7596
# INFO:tensorflow:step: 4740, lr: 0.000626, klw: 0.0606, cost: 0.1969, recon: 0.1662, kl: 0.5075, train_time_taken: 117.6923
# INFO:tensorflow:step: 4760, lr: 0.000625, klw: 0.0608, cost: 0.2276, recon: 0.1997, kl: 0.4584, train_time_taken: 118.0963
# INFO:tensorflow:step: 4780, lr: 0.000624, klw: 0.0610, cost: 0.1599, recon: 0.1310, kl: 0.4732, train_time_taken: 118.1605
# INFO:tensorflow:step: 4800, lr: 0.000623, klw: 0.0612, cost: 0.2102, recon: 0.1800, kl: 0.4936, train_time_taken: 119.0430
# INFO:tensorflow:step: 4820, lr: 0.000621, klw: 0.0614, cost: 0.2114, recon: 0.1807, kl: 0.5005, train_time_taken: 118.5330
# INFO:tensorflow:step: 4840, lr: 0.000620, klw: 0.0616, cost: 0.1417, recon: 0.1098, kl: 0.5177, train_time_taken: 117.5506
# INFO:tensorflow:step: 4860, lr: 0.000619, klw: 0.0618, cost: 0.1517, recon: 0.1210, kl: 0.4965, train_time_taken: 118.7715
# INFO:tensorflow:step: 4880, lr: 0.000618, klw: 0.0620, cost: 0.2039, recon: 0.1724, kl: 0.5089, train_time_taken: 117.6283
# INFO:tensorflow:step: 4900, lr: 0.000616, klw: 0.0622, cost: 0.1977, recon: 0.1675, kl: 0.4862, train_time_taken: 117.9840
# INFO:tensorflow:step: 4920, lr: 0.000615, klw: 0.0623, cost: 0.1775, recon: 0.1472, kl: 0.4847, train_time_taken: 118.4638
# INFO:tensorflow:step: 4940, lr: 0.000614, klw: 0.0625, cost: 0.2121, recon: 0.1832, kl: 0.4625, train_time_taken: 118.2761
# INFO:tensorflow:step: 4960, lr: 0.000613, klw: 0.0627, cost: 0.1784, recon: 0.1469, kl: 0.5033, train_time_taken: 118.4456
# INFO:tensorflow:step: 4980, lr: 0.000612, klw: 0.0629, cost: 0.1839, recon: 0.1528, kl: 0.4939, train_time_taken: 117.6782
# INFO:tensorflow:step: 5000, lr: 0.000610, klw: 0.0631, cost: 0.1351, recon: 0.1032, kl: 0.5057, train_time_taken: 118.7175
# INFO:tensorflow:best_valid_cost: 0.1184, valid_cost: 0.1184, valid_recon: 0.1134, valid_kl: 0.5002, valid_time_taken: 4.8502
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 5000.
# INFO:tensorflow:time_taken_save 0.6708.
# INFO:tensorflow:eval_cost: 0.0964, eval_recon: 0.0914, eval_kl: 0.4974, eval_time_taken: 4.7198
# INFO:tensorflow:step: 5020, lr: 0.000609, klw: 0.0633, cost: 0.1939, recon: 0.1641, kl: 0.4721, train_time_taken: 118.8972
# INFO:tensorflow:step: 5040, lr: 0.000608, klw: 0.0635, cost: 0.2256, recon: 0.1932, kl: 0.5102, train_time_taken: 117.8858
# INFO:tensorflow:step: 5060, lr: 0.000607, klw: 0.0636, cost: 0.1954, recon: 0.1651, kl: 0.4769, train_time_taken: 118.6283
# INFO:tensorflow:step: 5080, lr: 0.000606, klw: 0.0638, cost: 0.1927, recon: 0.1621, kl: 0.4793, train_time_taken: 118.7195
# INFO:tensorflow:step: 5100, lr: 0.000604, klw: 0.0640, cost: 0.2113, recon: 0.1812, kl: 0.4704, train_time_taken: 117.1505
# INFO:tensorflow:step: 5120, lr: 0.000603, klw: 0.0642, cost: 0.2037, recon: 0.1725, kl: 0.4860, train_time_taken: 118.6523
# INFO:tensorflow:step: 5140, lr: 0.000602, klw: 0.0644, cost: 0.1533, recon: 0.1238, kl: 0.4588, train_time_taken: 117.9999
# INFO:tensorflow:step: 5160, lr: 0.000601, klw: 0.0646, cost: 0.2372, recon: 0.2052, kl: 0.4954, train_time_taken: 117.0494
# INFO:tensorflow:step: 5180, lr: 0.000600, klw: 0.0648, cost: 0.2179, recon: 0.1909, kl: 0.4159, train_time_taken: 119.1189
# INFO:tensorflow:step: 5200, lr: 0.000599, klw: 0.0649, cost: 0.2090, recon: 0.1803, kl: 0.4417, train_time_taken: 117.1574
# INFO:tensorflow:step: 5220, lr: 0.000597, klw: 0.0651, cost: 0.1875, recon: 0.1581, kl: 0.4514, train_time_taken: 117.8812
# INFO:tensorflow:step: 5240, lr: 0.000596, klw: 0.0653, cost: 0.1933, recon: 0.1629, kl: 0.4659, train_time_taken: 117.1750
# INFO:tensorflow:step: 5260, lr: 0.000595, klw: 0.0655, cost: 0.2282, recon: 0.1982, kl: 0.4581, train_time_taken: 118.7647
# INFO:tensorflow:step: 5280, lr: 0.000594, klw: 0.0657, cost: 0.1450, recon: 0.1115, kl: 0.5094, train_time_taken: 120.0303
# INFO:tensorflow:step: 5300, lr: 0.000593, klw: 0.0659, cost: 0.2288, recon: 0.1993, kl: 0.4488, train_time_taken: 118.4732
# INFO:tensorflow:step: 5320, lr: 0.000592, klw: 0.0661, cost: 0.1363, recon: 0.1061, kl: 0.4583, train_time_taken: 117.4379
# INFO:tensorflow:step: 5340, lr: 0.000590, klw: 0.0662, cost: 0.2003, recon: 0.1719, kl: 0.4282, train_time_taken: 118.9370
# INFO:tensorflow:step: 5360, lr: 0.000589, klw: 0.0664, cost: 0.1436, recon: 0.1144, kl: 0.4396, train_time_taken: 117.2756
# INFO:tensorflow:step: 5380, lr: 0.000588, klw: 0.0666, cost: 0.1959, recon: 0.1661, kl: 0.4463, train_time_taken: 119.2363
# INFO:tensorflow:step: 5400, lr: 0.000587, klw: 0.0668, cost: 0.1820, recon: 0.1509, kl: 0.4661, train_time_taken: 117.8079
# INFO:tensorflow:step: 5420, lr: 0.000586, klw: 0.0670, cost: 0.1819, recon: 0.1523, kl: 0.4413, train_time_taken: 117.6455
# INFO:tensorflow:step: 5440, lr: 0.000585, klw: 0.0672, cost: 0.1754, recon: 0.1461, kl: 0.4364, train_time_taken: 118.9320
# INFO:tensorflow:step: 5460, lr: 0.000583, klw: 0.0673, cost: 0.2547, recon: 0.2237, kl: 0.4599, train_time_taken: 118.3143
# INFO:tensorflow:step: 5480, lr: 0.000582, klw: 0.0675, cost: 0.2216, recon: 0.1918, kl: 0.4423, train_time_taken: 119.4495
# INFO:tensorflow:step: 5500, lr: 0.000581, klw: 0.0677, cost: 0.2126, recon: 0.1844, kl: 0.4170, train_time_taken: 117.4971
# INFO:tensorflow:best_valid_cost: 0.1010, valid_cost: 0.1010, valid_recon: 0.0965, valid_kl: 0.4514, valid_time_taken: 4.8435
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 5500.
# INFO:tensorflow:time_taken_save 0.6823.
# INFO:tensorflow:eval_cost: 0.0809, eval_recon: 0.0764, eval_kl: 0.4493, eval_time_taken: 4.6182
# INFO:tensorflow:step: 5520, lr: 0.000580, klw: 0.0679, cost: 0.1700, recon: 0.1387, kl: 0.4610, train_time_taken: 118.1188
# INFO:tensorflow:step: 5540, lr: 0.000579, klw: 0.0681, cost: 0.1816, recon: 0.1509, kl: 0.4505, train_time_taken: 117.6122
# INFO:tensorflow:step: 5560, lr: 0.000578, klw: 0.0683, cost: 0.1774, recon: 0.1480, kl: 0.4320, train_time_taken: 118.4700
# INFO:tensorflow:step: 5580, lr: 0.000577, klw: 0.0684, cost: 0.1686, recon: 0.1406, kl: 0.4094, train_time_taken: 116.9727
# INFO:tensorflow:step: 5600, lr: 0.000575, klw: 0.0686, cost: 0.1636, recon: 0.1327, kl: 0.4513, train_time_taken: 117.5896
# INFO:tensorflow:step: 5620, lr: 0.000574, klw: 0.0688, cost: 0.1483, recon: 0.1189, kl: 0.4284, train_time_taken: 116.4401
# INFO:tensorflow:step: 5640, lr: 0.000573, klw: 0.0690, cost: 0.1742, recon: 0.1450, kl: 0.4234, train_time_taken: 117.8502
# INFO:tensorflow:step: 5660, lr: 0.000572, klw: 0.0692, cost: 0.1971, recon: 0.1687, kl: 0.4115, train_time_taken: 117.4223
# INFO:tensorflow:step: 5680, lr: 0.000571, klw: 0.0693, cost: 0.1848, recon: 0.1531, kl: 0.4580, train_time_taken: 117.9745
# INFO:tensorflow:step: 5700, lr: 0.000570, klw: 0.0695, cost: 0.1672, recon: 0.1367, kl: 0.4393, train_time_taken: 119.3161
# INFO:tensorflow:step: 5720, lr: 0.000569, klw: 0.0697, cost: 0.1898, recon: 0.1591, kl: 0.4404, train_time_taken: 117.7252
# INFO:tensorflow:step: 5740, lr: 0.000568, klw: 0.0699, cost: 0.1287, recon: 0.0980, kl: 0.4388, train_time_taken: 118.5994
# INFO:tensorflow:step: 5760, lr: 0.000567, klw: 0.0701, cost: 0.1376, recon: 0.1056, kl: 0.4577, train_time_taken: 118.1303
# INFO:tensorflow:step: 5780, lr: 0.000565, klw: 0.0702, cost: 0.1902, recon: 0.1598, kl: 0.4340, train_time_taken: 116.5696
# INFO:tensorflow:step: 5800, lr: 0.000564, klw: 0.0704, cost: 0.1547, recon: 0.1254, kl: 0.4164, train_time_taken: 118.7486
# INFO:tensorflow:step: 5820, lr: 0.000563, klw: 0.0706, cost: 0.1381, recon: 0.1087, kl: 0.4168, train_time_taken: 116.6390
# INFO:tensorflow:step: 5840, lr: 0.000562, klw: 0.0708, cost: 0.2019, recon: 0.1715, kl: 0.4293, train_time_taken: 117.4511
# INFO:tensorflow:step: 5860, lr: 0.000561, klw: 0.0710, cost: 0.1980, recon: 0.1674, kl: 0.4304, train_time_taken: 118.9741
# INFO:tensorflow:step: 5880, lr: 0.000560, klw: 0.0711, cost: 0.1884, recon: 0.1598, kl: 0.4027, train_time_taken: 117.1001
# INFO:tensorflow:step: 5900, lr: 0.000559, klw: 0.0713, cost: 0.1597, recon: 0.1289, kl: 0.4325, train_time_taken: 119.1026
# INFO:tensorflow:step: 5920, lr: 0.000558, klw: 0.0715, cost: 0.1316, recon: 0.1021, kl: 0.4138, train_time_taken: 117.9121
# INFO:tensorflow:step: 5940, lr: 0.000557, klw: 0.0717, cost: 0.1247, recon: 0.0942, kl: 0.4242, train_time_taken: 118.1075
# INFO:tensorflow:step: 5960, lr: 0.000555, klw: 0.0718, cost: 0.1354, recon: 0.1064, kl: 0.4034, train_time_taken: 117.6896
# INFO:tensorflow:step: 5980, lr: 0.000554, klw: 0.0720, cost: 0.1542, recon: 0.1236, kl: 0.4236, train_time_taken: 117.7275
# INFO:tensorflow:step: 6000, lr: 0.000553, klw: 0.0722, cost: 0.1541, recon: 0.1232, kl: 0.4285, train_time_taken: 118.9163
# INFO:tensorflow:best_valid_cost: 0.0885, valid_cost: 0.0885, valid_recon: 0.0841, valid_kl: 0.4384, valid_time_taken: 4.8044
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 6000.
# INFO:tensorflow:time_taken_save 0.7002.
# INFO:tensorflow:eval_cost: 0.0644, eval_recon: 0.0600, eval_kl: 0.4371, eval_time_taken: 4.8114
# INFO:tensorflow:step: 6020, lr: 0.000552, klw: 0.0724, cost: 0.1484, recon: 0.1170, kl: 0.4342, train_time_taken: 118.2282
# INFO:tensorflow:step: 6040, lr: 0.000551, klw: 0.0726, cost: 0.1754, recon: 0.1443, kl: 0.4295, train_time_taken: 117.8075
# INFO:tensorflow:step: 6060, lr: 0.000550, klw: 0.0727, cost: 0.1642, recon: 0.1334, kl: 0.4232, train_time_taken: 119.1193
# INFO:tensorflow:step: 6080, lr: 0.000549, klw: 0.0729, cost: 0.2130, recon: 0.1829, kl: 0.4131, train_time_taken: 118.9451
# INFO:tensorflow:step: 6100, lr: 0.000548, klw: 0.0731, cost: 0.1952, recon: 0.1635, kl: 0.4328, train_time_taken: 118.2091
# ...
# INFO:tensorflow:step: 22700, lr: 0.000112, klw: 0.1729, cost: -0.1445, recon: -0.1919, kl: 0.2745, train_time_taken: 117.9164
# INFO:tensorflow:step: 22720, lr: 0.000112, klw: 0.1729, cost: -0.1519, recon: -0.1990, kl: 0.2722, train_time_taken: 116.7281
# INFO:tensorflow:step: 22740, lr: 0.000112, klw: 0.1730, cost: -0.1172, recon: -0.1635, kl: 0.2675, train_time_taken: 117.3170
# INFO:tensorflow:step: 22760, lr: 0.000112, klw: 0.1731, cost: -0.0881, recon: -0.1350, kl: 0.2710, train_time_taken: 116.2062
# INFO:tensorflow:step: 22780, lr: 0.000111, klw: 0.1732, cost: -0.1364, recon: -0.1835, kl: 0.2716, train_time_taken: 116.2056
# INFO:tensorflow:step: 22800, lr: 0.000111, klw: 0.1732, cost: -0.1105, recon: -0.1567, kl: 0.2668, train_time_taken: 116.9787
# INFO:tensorflow:step: 22820, lr: 0.000111, klw: 0.1733, cost: -0.0824, recon: -0.1289, kl: 0.2685, train_time_taken: 117.9480
# INFO:tensorflow:step: 22840, lr: 0.000111, klw: 0.1734, cost: -0.1596, recon: -0.2066, kl: 0.2713, train_time_taken: 116.0039
# INFO:tensorflow:step: 22860, lr: 0.000111, klw: 0.1735, cost: -0.1300, recon: -0.1769, kl: 0.2706, train_time_taken: 117.7131
# INFO:tensorflow:step: 22880, lr: 0.000110, klw: 0.1736, cost: -0.1101, recon: -0.1574, kl: 0.2724, train_time_taken: 116.6976
# INFO:tensorflow:step: 22900, lr: 0.000110, klw: 0.1736, cost: -0.1040, recon: -0.1513, kl: 0.2724, train_time_taken: 117.5891
# INFO:tensorflow:step: 22920, lr: 0.000110, klw: 0.1737, cost: -0.1778, recon: -0.2250, kl: 0.2718, train_time_taken: 115.6634
# INFO:tensorflow:step: 22940, lr: 0.000110, klw: 0.1738, cost: -0.1869, recon: -0.2341, kl: 0.2715, train_time_taken: 116.5282
# INFO:tensorflow:step: 22960, lr: 0.000110, klw: 0.1739, cost: -0.0800, recon: -0.1267, kl: 0.2684, train_time_taken: 116.9959
# INFO:tensorflow:step: 22980, lr: 0.000109, klw: 0.1739, cost: -0.1192, recon: -0.1659, kl: 0.2687, train_time_taken: 116.8517
# INFO:tensorflow:step: 23000, lr: 0.000109, klw: 0.1740, cost: -0.0863, recon: -0.1339, kl: 0.2736, train_time_taken: 116.0699
# INFO:tensorflow:best_valid_cost: -0.1487, valid_cost: -0.1487, valid_recon: -0.1515, valid_kl: 0.2757, valid_time_taken: 4.4830
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 23000.
# INFO:tensorflow:time_taken_save 0.9872.
# INFO:tensorflow:eval_cost: -0.1560, eval_recon: -0.1588, eval_kl: 0.2765, eval_time_taken: 4.6197
# INFO:tensorflow:step: 23020, lr: 0.000109, klw: 0.1741, cost: -0.0867, recon: -0.1337, kl: 0.2701, train_time_taken: 118.1911
# INFO:tensorflow:step: 23040, lr: 0.000109, klw: 0.1742, cost: -0.1696, recon: -0.2172, kl: 0.2732, train_time_taken: 116.6296
# INFO:tensorflow:step: 23060, lr: 0.000109, klw: 0.1742, cost: -0.0987, recon: -0.1460, kl: 0.2712, train_time_taken: 116.9284
# INFO:tensorflow:step: 23080, lr: 0.000108, klw: 0.1743, cost: -0.1333, recon: -0.1806, kl: 0.2712, train_time_taken: 117.7027
# INFO:tensorflow:step: 23100, lr: 0.000108, klw: 0.1744, cost: -0.1648, recon: -0.2117, kl: 0.2691, train_time_taken: 116.4659
# INFO:tensorflow:step: 23120, lr: 0.000108, klw: 0.1745, cost: -0.1747, recon: -0.2216, kl: 0.2690, train_time_taken: 117.5099
# INFO:tensorflow:step: 23140, lr: 0.000108, klw: 0.1745, cost: -0.1570, recon: -0.2044, kl: 0.2714, train_time_taken: 116.5926
# INFO:tensorflow:step: 23160, lr: 0.000108, klw: 0.1746, cost: -0.1314, recon: -0.1779, kl: 0.2664, train_time_taken: 116.8786
# INFO:tensorflow:step: 23180, lr: 0.000107, klw: 0.1747, cost: -0.1161, recon: -0.1631, kl: 0.2688, train_time_taken: 117.5873
# INFO:tensorflow:step: 23200, lr: 0.000107, klw: 0.1748, cost: -0.1292, recon: -0.1759, kl: 0.2670, train_time_taken: 117.2388
# INFO:tensorflow:step: 23220, lr: 0.000107, klw: 0.1748, cost: -0.1001, recon: -0.1466, kl: 0.2661, train_time_taken: 117.7266
# INFO:tensorflow:step: 23240, lr: 0.000107, klw: 0.1749, cost: -0.1049, recon: -0.1524, kl: 0.2716, train_time_taken: 117.6020
# INFO:tensorflow:step: 23260, lr: 0.000107, klw: 0.1750, cost: -0.1517, recon: -0.1991, kl: 0.2707, train_time_taken: 115.9129
# INFO:tensorflow:step: 23280, lr: 0.000107, klw: 0.1751, cost: -0.0927, recon: -0.1399, kl: 0.2695, train_time_taken: 118.0434
# INFO:tensorflow:step: 23300, lr: 0.000106, klw: 0.1751, cost: -0.1037, recon: -0.1514, kl: 0.2725, train_time_taken: 117.5119
# INFO:tensorflow:step: 23320, lr: 0.000106, klw: 0.1752, cost: -0.1410, recon: -0.1886, kl: 0.2717, train_time_taken: 117.7921
# INFO:tensorflow:step: 23340, lr: 0.000106, klw: 0.1753, cost: -0.1082, recon: -0.1551, kl: 0.2679, train_time_taken: 115.4640
# INFO:tensorflow:step: 23360, lr: 0.000106, klw: 0.1754, cost: -0.1348, recon: -0.1825, kl: 0.2719, train_time_taken: 116.8354
# INFO:tensorflow:step: 23380, lr: 0.000106, klw: 0.1754, cost: -0.0892, recon: -0.1361, kl: 0.2671, train_time_taken: 117.3350
# INFO:tensorflow:step: 23400, lr: 0.000105, klw: 0.1755, cost: -0.1547, recon: -0.2018, kl: 0.2685, train_time_taken: 116.7587
# INFO:tensorflow:step: 23420, lr: 0.000105, klw: 0.1756, cost: -0.1528, recon: -0.2003, kl: 0.2705, train_time_taken: 116.3753
# INFO:tensorflow:step: 23440, lr: 0.000105, klw: 0.1757, cost: -0.1521, recon: -0.1997, kl: 0.2710, train_time_taken: 117.9340
# INFO:tensorflow:step: 23460, lr: 0.000105, klw: 0.1757, cost: -0.0643, recon: -0.1112, kl: 0.2671, train_time_taken: 117.0060
# INFO:tensorflow:step: 23480, lr: 0.000105, klw: 0.1758, cost: -0.0996, recon: -0.1467, kl: 0.2682, train_time_taken: 119.3028
# INFO:tensorflow:step: 23500, lr: 0.000104, klw: 0.1759, cost: -0.1560, recon: -0.2035, kl: 0.2698, train_time_taken: 116.0634
# INFO:tensorflow:best_valid_cost: -0.1520, valid_cost: -0.1520, valid_recon: -0.1548, valid_kl: 0.2737, valid_time_taken: 4.7715
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 23500.
# INFO:tensorflow:time_taken_save 1.0113.
# INFO:tensorflow:eval_cost: -0.1628, eval_recon: -0.1656, eval_kl: 0.2744, eval_time_taken: 4.6381
# INFO:tensorflow:step: 23520, lr: 0.000104, klw: 0.1760, cost: -0.1073, recon: -0.1541, kl: 0.2662, train_time_taken: 117.3608
# INFO:tensorflow:step: 23540, lr: 0.000104, klw: 0.1760, cost: -0.2088, recon: -0.2567, kl: 0.2721, train_time_taken: 117.6393
# INFO:tensorflow:step: 23560, lr: 0.000104, klw: 0.1761, cost: -0.1531, recon: -0.2005, kl: 0.2692, train_time_taken: 116.3219
# INFO:tensorflow:step: 23580, lr: 0.000104, klw: 0.1762, cost: -0.1961, recon: -0.2440, kl: 0.2715, train_time_taken: 116.1481
# INFO:tensorflow:step: 23600, lr: 0.000103, klw: 0.1763, cost: -0.1236, recon: -0.1707, kl: 0.2667, train_time_taken: 117.7997
# INFO:tensorflow:step: 23620, lr: 0.000103, klw: 0.1763, cost: -0.1131, recon: -0.1611, kl: 0.2724, train_time_taken: 116.7743
# INFO:tensorflow:step: 23640, lr: 0.000103, klw: 0.1764, cost: -0.1335, recon: -0.1817, kl: 0.2728, train_time_taken: 117.8934
# INFO:tensorflow:step: 23660, lr: 0.000103, klw: 0.1765, cost: -0.0720, recon: -0.1191, kl: 0.2671, train_time_taken: 116.4823
# INFO:tensorflow:step: 23680, lr: 0.000103, klw: 0.1765, cost: -0.1187, recon: -0.1660, kl: 0.2677, train_time_taken: 116.0128
# INFO:tensorflow:step: 23700, lr: 0.000103, klw: 0.1766, cost: -0.1211, recon: -0.1684, kl: 0.2677, train_time_taken: 118.1875
# INFO:tensorflow:step: 23720, lr: 0.000102, klw: 0.1767, cost: -0.0781, recon: -0.1249, kl: 0.2645, train_time_taken: 116.7347
# INFO:tensorflow:step: 23740, lr: 0.000102, klw: 0.1768, cost: -0.0964, recon: -0.1437, kl: 0.2677, train_time_taken: 117.1220
# INFO:tensorflow:step: 23760, lr: 0.000102, klw: 0.1768, cost: -0.1404, recon: -0.1872, kl: 0.2648, train_time_taken: 117.7554
# INFO:tensorflow:step: 23780, lr: 0.000102, klw: 0.1769, cost: -0.1812, recon: -0.2291, kl: 0.2710, train_time_taken: 115.3656
# INFO:tensorflow:step: 23800, lr: 0.000102, klw: 0.1770, cost: -0.1195, recon: -0.1671, kl: 0.2691, train_time_taken: 118.6830
# INFO:tensorflow:step: 23820, lr: 0.000101, klw: 0.1771, cost: -0.1276, recon: -0.1751, kl: 0.2683, train_time_taken: 116.4342
# INFO:tensorflow:step: 23840, lr: 0.000101, klw: 0.1771, cost: -0.1907, recon: -0.2389, kl: 0.2721, train_time_taken: 117.0676
# INFO:tensorflow:step: 23860, lr: 0.000101, klw: 0.1772, cost: -0.1490, recon: -0.1966, kl: 0.2688, train_time_taken: 117.9497
# INFO:tensorflow:step: 23880, lr: 0.000101, klw: 0.1773, cost: -0.0624, recon: -0.1097, kl: 0.2666, train_time_taken: 116.4075
# INFO:tensorflow:step: 23900, lr: 0.000101, klw: 0.1774, cost: -0.0967, recon: -0.1440, kl: 0.2667, train_time_taken: 116.6041
# INFO:tensorflow:step: 23920, lr: 0.000101, klw: 0.1774, cost: -0.2081, recon: -0.2558, kl: 0.2686, train_time_taken: 118.1005
# INFO:tensorflow:step: 23940, lr: 0.000100, klw: 0.1775, cost: -0.1067, recon: -0.1537, kl: 0.2652, train_time_taken: 115.7713
# INFO:tensorflow:step: 23960, lr: 0.000100, klw: 0.1776, cost: -0.1822, recon: -0.2299, kl: 0.2684, train_time_taken: 118.3238
# INFO:tensorflow:step: 23980, lr: 0.000100, klw: 0.1776, cost: -0.1586, recon: -0.2067, kl: 0.2712, train_time_taken: 117.5212
# INFO:tensorflow:step: 24000, lr: 0.000100, klw: 0.1777, cost: -0.1291, recon: -0.1768, kl: 0.2685, train_time_taken: 115.6938
# INFO:tensorflow:best_valid_cost: -0.1520, valid_cost: -0.1447, valid_recon: -0.1474, valid_kl: 0.2732, valid_time_taken: 4.5657
# INFO:tensorflow:step: 24020, lr: 0.000100, klw: 0.1778, cost: -0.1181, recon: -0.1656, kl: 0.2674, train_time_taken: 118.6659
# INFO:tensorflow:step: 24040, lr: 0.000099, klw: 0.1779, cost: -0.0935, recon: -0.1412, kl: 0.2686, train_time_taken: 116.4761
# INFO:tensorflow:step: 24060, lr: 0.000099, klw: 0.1779, cost: -0.1423, recon: -0.1907, kl: 0.2717, train_time_taken: 116.6905
# INFO:tensorflow:step: 24080, lr: 0.000099, klw: 0.1780, cost: -0.1257, recon: -0.1733, kl: 0.2678, train_time_taken: 118.1507
# INFO:tensorflow:step: 24100, lr: 0.000099, klw: 0.1781, cost: -0.1778, recon: -0.2256, kl: 0.2683, train_time_taken: 116.1180
# INFO:tensorflow:step: 24120, lr: 0.000099, klw: 0.1781, cost: -0.1554, recon: -0.2036, kl: 0.2703, train_time_taken: 118.4853
# INFO:tensorflow:step: 24140, lr: 0.000099, klw: 0.1782, cost: -0.1556, recon: -0.2039, kl: 0.2710, train_time_taken: 116.4087
# INFO:tensorflow:step: 24160, lr: 0.000098, klw: 0.1783, cost: -0.1317, recon: -0.1797, kl: 0.2696, train_time_taken: 116.3991
# INFO:tensorflow:step: 24180, lr: 0.000098, klw: 0.1784, cost: -0.1202, recon: -0.1682, kl: 0.2690, train_time_taken: 118.3988
# INFO:tensorflow:step: 24200, lr: 0.000098, klw: 0.1784, cost: -0.1843, recon: -0.2323, kl: 0.2688, train_time_taken: 116.5812
# INFO:tensorflow:step: 24220, lr: 0.000098, klw: 0.1785, cost: -0.1324, recon: -0.1801, kl: 0.2672, train_time_taken: 118.3110
# INFO:tensorflow:step: 24240, lr: 0.000098, klw: 0.1786, cost: -0.1321, recon: -0.1803, kl: 0.2702, train_time_taken: 117.4157
# INFO:tensorflow:step: 24260, lr: 0.000097, klw: 0.1786, cost: -0.1290, recon: -0.1773, kl: 0.2702, train_time_taken: 116.6026
# INFO:tensorflow:step: 24280, lr: 0.000097, klw: 0.1787, cost: -0.0944, recon: -0.1427, kl: 0.2701, train_time_taken: 118.0775
# INFO:tensorflow:step: 24300, lr: 0.000097, klw: 0.1788, cost: -0.1483, recon: -0.1968, kl: 0.2709, train_time_taken: 116.3440
# INFO:tensorflow:step: 24320, lr: 0.000097, klw: 0.1789, cost: -0.1489, recon: -0.1969, kl: 0.2687, train_time_taken: 116.6183
# INFO:tensorflow:step: 24340, lr: 0.000097, klw: 0.1789, cost: -0.1608, recon: -0.2091, kl: 0.2697, train_time_taken: 117.9703
# INFO:tensorflow:step: 24360, lr: 0.000097, klw: 0.1790, cost: -0.0799, recon: -0.1275, kl: 0.2662, train_time_taken: 116.5062
# INFO:tensorflow:step: 24380, lr: 0.000096, klw: 0.1791, cost: -0.1787, recon: -0.2274, kl: 0.2722, train_time_taken: 118.0042
# INFO:tensorflow:step: 24400, lr: 0.000096, klw: 0.1791, cost: -0.0723, recon: -0.1208, kl: 0.2712, train_time_taken: 116.5355
# INFO:tensorflow:step: 24420, lr: 0.000096, klw: 0.1792, cost: -0.1264, recon: -0.1747, kl: 0.2693, train_time_taken: 117.2324
# INFO:tensorflow:step: 24440, lr: 0.000096, klw: 0.1793, cost: -0.1526, recon: -0.2011, kl: 0.2708, train_time_taken: 118.7452
# INFO:tensorflow:step: 24460, lr: 0.000096, klw: 0.1794, cost: -0.0989, recon: -0.1471, kl: 0.2686, train_time_taken: 116.1354
# INFO:tensorflow:step: 24480, lr: 0.000096, klw: 0.1794, cost: -0.1339, recon: -0.1815, kl: 0.2653, train_time_taken: 117.1714
# INFO:tensorflow:step: 24500, lr: 0.000095, klw: 0.1795, cost: -0.1450, recon: -0.1933, kl: 0.2691, train_time_taken: 118.8597
# INFO:tensorflow:best_valid_cost: -0.1611, valid_cost: -0.1611, valid_recon: -0.1639, valid_kl: 0.2740, valid_time_taken: 4.7149
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 24500.
# INFO:tensorflow:time_taken_save 1.0449.
# INFO:tensorflow:eval_cost: -0.1655, eval_recon: -0.1682, eval_kl: 0.2746, eval_time_taken: 4.6319
# INFO:tensorflow:step: 24520, lr: 0.000095, klw: 0.1796, cost: -0.1356, recon: -0.1834, kl: 0.2662, train_time_taken: 116.3007
# INFO:tensorflow:step: 24540, lr: 0.000095, klw: 0.1796, cost: -0.1513, recon: -0.2002, kl: 0.2719, train_time_taken: 117.7105
# INFO:tensorflow:step: 24560, lr: 0.000095, klw: 0.1797, cost: -0.1527, recon: -0.2013, kl: 0.2701, train_time_taken: 117.0255
# INFO:tensorflow:step: 24580, lr: 0.000095, klw: 0.1798, cost: -0.1314, recon: -0.1800, kl: 0.2704, train_time_taken: 116.7738
# INFO:tensorflow:step: 24600, lr: 0.000095, klw: 0.1799, cost: -0.1873, recon: -0.2361, kl: 0.2710, train_time_taken: 118.5889
# INFO:tensorflow:step: 24620, lr: 0.000094, klw: 0.1799, cost: -0.1549, recon: -0.2032, kl: 0.2685, train_time_taken: 116.6118
# INFO:tensorflow:step: 24640, lr: 0.000094, klw: 0.1800, cost: -0.2109, recon: -0.2597, kl: 0.2708, train_time_taken: 117.4547
# INFO:tensorflow:step: 24660, lr: 0.000094, klw: 0.1801, cost: -0.1151, recon: -0.1633, kl: 0.2681, train_time_taken: 116.9608
# INFO:tensorflow:step: 24680, lr: 0.000094, klw: 0.1801, cost: -0.0936, recon: -0.1421, kl: 0.2692, train_time_taken: 116.9496
# INFO:tensorflow:step: 24700, lr: 0.000094, klw: 0.1802, cost: -0.1105, recon: -0.1581, kl: 0.2645, train_time_taken: 118.4960
# INFO:tensorflow:step: 24720, lr: 0.000094, klw: 0.1803, cost: -0.1322, recon: -0.1799, kl: 0.2645, train_time_taken: 115.2121
# INFO:tensorflow:step: 24740, lr: 0.000093, klw: 0.1803, cost: -0.1432, recon: -0.1918, kl: 0.2696, train_time_taken: 116.7412
# INFO:tensorflow:step: 24760, lr: 0.000093, klw: 0.1804, cost: -0.1251, recon: -0.1732, kl: 0.2666, train_time_taken: 118.8732
# INFO:tensorflow:step: 24780, lr: 0.000093, klw: 0.1805, cost: -0.1406, recon: -0.1884, kl: 0.2651, train_time_taken: 116.4113
# INFO:tensorflow:step: 24800, lr: 0.000093, klw: 0.1805, cost: -0.1404, recon: -0.1892, kl: 0.2701, train_time_taken: 116.9828
# INFO:tensorflow:step: 24820, lr: 0.000093, klw: 0.1806, cost: -0.1760, recon: -0.2244, kl: 0.2684, train_time_taken: 117.1223
# INFO:tensorflow:step: 24840, lr: 0.000093, klw: 0.1807, cost: -0.1156, recon: -0.1636, kl: 0.2653, train_time_taken: 116.8369
# INFO:tensorflow:step: 24860, lr: 0.000092, klw: 0.1808, cost: -0.0889, recon: -0.1374, kl: 0.2682, train_time_taken: 119.6894
# INFO:tensorflow:step: 24880, lr: 0.000092, klw: 0.1808, cost: -0.1471, recon: -0.1957, kl: 0.2686, train_time_taken: 116.9661
# INFO:tensorflow:step: 24900, lr: 0.000092, klw: 0.1809, cost: -0.1350, recon: -0.1837, kl: 0.2694, train_time_taken: 117.0557
# INFO:tensorflow:step: 24920, lr: 0.000092, klw: 0.1810, cost: -0.1618, recon: -0.2101, kl: 0.2667, train_time_taken: 118.7449
# INFO:tensorflow:step: 24940, lr: 0.000092, klw: 0.1810, cost: -0.1663, recon: -0.2142, kl: 0.2649, train_time_taken: 116.6469
# INFO:tensorflow:step: 24960, lr: 0.000092, klw: 0.1811, cost: -0.1423, recon: -0.1906, kl: 0.2665, train_time_taken: 118.0355
# INFO:tensorflow:step: 24980, lr: 0.000091, klw: 0.1812, cost: -0.1182, recon: -0.1665, kl: 0.2670, train_time_taken: 117.3302
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
console_entry_point()
# Out:
# INFO:tensorflow:sketch-rnn
# INFO:tensorflow:Hyperparams:
# INFO:tensorflow:random_scale_factor = 0.15
# INFO:tensorflow:num_steps = 50001
# INFO:tensorflow:use_recurrent_dropout = True
# INFO:tensorflow:z_size = 128
# INFO:tensorflow:kl_weight_start = 0.01
# INFO:tensorflow:dec_model = layer_norm
# INFO:tensorflow:conditional = True
# INFO:tensorflow:use_input_dropout = False
# INFO:tensorflow:min_learning_rate = 1e-05
# INFO:tensorflow:learning_rate = 0.001
# INFO:tensorflow:recurrent_dropout_prob = 0.9
# INFO:tensorflow:num_mixture = 20
# INFO:tensorflow:augment_stroke_prob = 0.1
# INFO:tensorflow:max_seq_len = 250
# INFO:tensorflow:data_set = ['aaron_sheep.npz']
# INFO:tensorflow:save_every = 500
# INFO:tensorflow:kl_tolerance = 0.2
# INFO:tensorflow:decay_rate = 0.9999
# INFO:tensorflow:use_output_dropout = False
# INFO:tensorflow:input_dropout_prob = 0.9
# INFO:tensorflow:kl_weight = 0.25
# INFO:tensorflow:batch_size = 100
# INFO:tensorflow:enc_rnn_size = 256
# INFO:tensorflow:is_training = True
# INFO:tensorflow:output_dropout_prob = 0.9
# INFO:tensorflow:kl_decay_rate = 0.99995
# INFO:tensorflow:enc_model = layer_norm
# INFO:tensorflow:grad_clip = 1.0
# INFO:tensorflow:dec_rnn_size = 512
# INFO:tensorflow:Loading data files.
# INFO:tensorflow:Downloading https://github.com/hardmaru/sketch-rnn-datasets/raw/master/aaron_sheep/aaron_sheep.npz
# INFO:tensorflow:Loaded 7400/300/300 from aaron_sheep.npz
# INFO:tensorflow:Dataset combined: 8000 (7400/300/300), avg len 125
# INFO:tensorflow:model_params.max_seq_len 250.
# total images <= max_seq_len is 7400
# total images <= max_seq_len is 300
# total images <= max_seq_len is 300
# INFO:tensorflow:normalizing_scale_factor 18.5198.
# INFO:tensorflow:Model using gpu.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Input dropout mode = False.
# INFO:tensorflow:Output dropout mode = False.
# INFO:tensorflow:Recurrent dropout mode = True.
# WARNING:tensorflow:From /home/jupyter/model.py:90: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/jupyter/rnn.py:288: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/jupyter/model.py:323: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/jupyter/model.py:342: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/jupyter/model.py:352: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# INFO:tensorflow:Model using gpu.
# INFO:tensorflow:Input dropout mode = 0.
# INFO:tensorflow:Output dropout mode = 0.
# INFO:tensorflow:Recurrent dropout mode = 0.
# INFO:tensorflow:Loading model log/initialp25/vector-24500.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from log/initialp25/vector-24500
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/linear/super_linear_w:0 (128, 1024) 131072
# INFO:tensorflow:vector_rnn/linear/super_linear_b:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/RNN/output_w:0 (512, 123) 62976
# INFO:tensorflow:vector_rnn/RNN/output_b:0 (123,) 123
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_xh:0 (133, 2048) 272384
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_hh:0 (512, 2048) 1048576
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_gamma:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_beta:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_gamma:0 (512,) 512
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_beta:0 (512,) 512
# INFO:tensorflow:Total trainable variables 2192251.
# INFO:tensorflow:step: 24520, lr: 0.000095, klw: 0.1796, cost: -0.1165, recon: -0.1649, kl: 0.2697, train_time_taken: 149.5342
# INFO:tensorflow:step: 24540, lr: 0.000095, klw: 0.1796, cost: -0.1630, recon: -0.2122, kl: 0.2734, train_time_taken: 141.0461
# INFO:tensorflow:step: 24560, lr: 0.000095, klw: 0.1797, cost: -0.1257, recon: -0.1738, kl: 0.2675, train_time_taken: 140.0548
# INFO:tensorflow:step: 24580, lr: 0.000095, klw: 0.1798, cost: -0.1081, recon: -0.1562, kl: 0.2676, train_time_taken: 136.6989
# INFO:tensorflow:step: 24600, lr: 0.000095, klw: 0.1799, cost: -0.0868, recon: -0.1343, kl: 0.2642, train_time_taken: 140.7355
# INFO:tensorflow:step: 24620, lr: 0.000094, klw: 0.1799, cost: -0.1608, recon: -0.2093, kl: 0.2697, train_time_taken: 139.8671
# INFO:tensorflow:step: 24640, lr: 0.000094, klw: 0.1800, cost: -0.2383, recon: -0.2867, kl: 0.2689, train_time_taken: 138.4992
# INFO:tensorflow:step: 24660, lr: 0.000094, klw: 0.1801, cost: -0.0747, recon: -0.1232, kl: 0.2691, train_time_taken: 140.2101
# INFO:tensorflow:step: 24680, lr: 0.000094, klw: 0.1801, cost: -0.1470, recon: -0.1955, kl: 0.2697, train_time_taken: 142.1399
# INFO:tensorflow:step: 24700, lr: 0.000094, klw: 0.1802, cost: -0.2120, recon: -0.2606, kl: 0.2699, train_time_taken: 139.8830
# INFO:tensorflow:step: 24720, lr: 0.000094, klw: 0.1803, cost: -0.1297, recon: -0.1783, kl: 0.2694, train_time_taken: 141.5341
# INFO:tensorflow:step: 24740, lr: 0.000093, klw: 0.1803, cost: -0.1373, recon: -0.1857, kl: 0.2685, train_time_taken: 142.4341
# INFO:tensorflow:step: 24760, lr: 0.000093, klw: 0.1804, cost: -0.1230, recon: -0.1708, kl: 0.2648, train_time_taken: 140.1291
# INFO:tensorflow:step: 24780, lr: 0.000093, klw: 0.1805, cost: -0.0669, recon: -0.1151, kl: 0.2669, train_time_taken: 140.0424
# INFO:tensorflow:step: 24800, lr: 0.000093, klw: 0.1805, cost: -0.1110, recon: -0.1595, kl: 0.2691, train_time_taken: 136.7538
# INFO:tensorflow:step: 24820, lr: 0.000093, klw: 0.1806, cost: -0.1214, recon: -0.1699, kl: 0.2685, train_time_taken: 140.5432
# INFO:tensorflow:step: 24840, lr: 0.000093, klw: 0.1807, cost: -0.0718, recon: -0.1210, kl: 0.2726, train_time_taken: 138.4848
# INFO:tensorflow:step: 24860, lr: 0.000092, klw: 0.1808, cost: -0.1187, recon: -0.1672, kl: 0.2684, train_time_taken: 137.2837
# INFO:tensorflow:step: 24880, lr: 0.000092, klw: 0.1808, cost: -0.1177, recon: -0.1661, kl: 0.2677, train_time_taken: 135.7574
# INFO:tensorflow:step: 24900, lr: 0.000092, klw: 0.1809, cost: -0.1870, recon: -0.2359, kl: 0.2701, train_time_taken: 139.3046
# INFO:tensorflow:step: 24920, lr: 0.000092, klw: 0.1810, cost: -0.1171, recon: -0.1653, kl: 0.2663, train_time_taken: 137.2952
# INFO:tensorflow:step: 24940, lr: 0.000092, klw: 0.1810, cost: -0.1176, recon: -0.1661, kl: 0.2677, train_time_taken: 141.7001
# INFO:tensorflow:step: 24960, lr: 0.000092, klw: 0.1811, cost: -0.1579, recon: -0.2064, kl: 0.2679, train_time_taken: 143.8953
# INFO:tensorflow:step: 24980, lr: 0.000091, klw: 0.1812, cost: -0.1670, recon: -0.2157, kl: 0.2687, train_time_taken: 140.7379
# INFO:tensorflow:step: 25000, lr: 0.000091, klw: 0.1812, cost: -0.2039, recon: -0.2530, kl: 0.2705, train_time_taken: 141.6583
# INFO:tensorflow:best_valid_cost: -0.1688, valid_cost: -0.1688, valid_recon: -0.1715, valid_kl: 0.2729, valid_time_taken: 6.4184
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 25000.
# INFO:tensorflow:time_taken_save 1.0380.
# INFO:tensorflow:eval_cost: -0.1779, eval_recon: -0.1806, eval_kl: 0.2735, eval_time_taken: 5.3713
# INFO:tensorflow:step: 25020, lr: 0.000091, klw: 0.1813, cost: -0.1615, recon: -0.2106, kl: 0.2704, train_time_taken: 140.8919
# INFO:tensorflow:step: 25040, lr: 0.000091, klw: 0.1814, cost: -0.1275, recon: -0.1760, kl: 0.2675, train_time_taken: 143.5946
# INFO:tensorflow:step: 25060, lr: 0.000091, klw: 0.1814, cost: -0.0370, recon: -0.0853, kl: 0.2663, train_time_taken: 140.0478
# INFO:tensorflow:step: 25080, lr: 0.000091, klw: 0.1815, cost: -0.1815, recon: -0.2301, kl: 0.2673, train_time_taken: 144.1378
# INFO:tensorflow:step: 25100, lr: 0.000090, klw: 0.1816, cost: -0.1679, recon: -0.2166, kl: 0.2684, train_time_taken: 141.6301
# INFO:tensorflow:step: 25120, lr: 0.000090, klw: 0.1817, cost: -0.1392, recon: -0.1881, kl: 0.2691, train_time_taken: 143.6008
# INFO:tensorflow:step: 25140, lr: 0.000090, klw: 0.1817, cost: -0.2072, recon: -0.2565, kl: 0.2708, train_time_taken: 142.5799
# INFO:tensorflow:step: 25160, lr: 0.000090, klw: 0.1818, cost: -0.1270, recon: -0.1755, kl: 0.2666, train_time_taken: 142.5353
# INFO:tensorflow:step: 25180, lr: 0.000090, klw: 0.1819, cost: -0.0965, recon: -0.1448, kl: 0.2654, train_time_taken: 141.4562
# INFO:tensorflow:step: 25200, lr: 0.000090, klw: 0.1819, cost: -0.1812, recon: -0.2301, kl: 0.2687, train_time_taken: 139.9205
# INFO:tensorflow:step: 25220, lr: 0.000089, klw: 0.1820, cost: -0.1700, recon: -0.2187, kl: 0.2671, train_time_taken: 140.9352
# INFO:tensorflow:step: 25240, lr: 0.000089, klw: 0.1821, cost: -0.1356, recon: -0.1843, kl: 0.2676, train_time_taken: 136.2744
# INFO:tensorflow:step: 25260, lr: 0.000089, klw: 0.1821, cost: -0.1079, recon: -0.1567, kl: 0.2680, train_time_taken: 138.5834
# INFO:tensorflow:step: 25280, lr: 0.000089, klw: 0.1822, cost: -0.1376, recon: -0.1854, kl: 0.2621, train_time_taken: 143.0856
# INFO:tensorflow:step: 25300, lr: 0.000089, klw: 0.1823, cost: -0.0820, recon: -0.1306, kl: 0.2661, train_time_taken: 145.5280
# INFO:tensorflow:step: 25320, lr: 0.000089, klw: 0.1823, cost: -0.1603, recon: -0.2089, kl: 0.2662, train_time_taken: 143.0199
# INFO:tensorflow:step: 25340, lr: 0.000089, klw: 0.1824, cost: -0.0913, recon: -0.1400, kl: 0.2669, train_time_taken: 145.4303
# INFO:tensorflow:step: 25360, lr: 0.000088, klw: 0.1825, cost: -0.1002, recon: -0.1486, kl: 0.2653, train_time_taken: 146.5419
# INFO:tensorflow:step: 25380, lr: 0.000088, klw: 0.1825, cost: -0.0542, recon: -0.1032, kl: 0.2688, train_time_taken: 148.0379
# INFO:tensorflow:step: 25400, lr: 0.000088, klw: 0.1826, cost: -0.1384, recon: -0.1876, kl: 0.2697, train_time_taken: 146.0784
# INFO:tensorflow:step: 25420, lr: 0.000088, klw: 0.1827, cost: -0.0789, recon: -0.1287, kl: 0.2725, train_time_taken: 151.8678
# INFO:tensorflow:step: 25440, lr: 0.000088, klw: 0.1827, cost: -0.1997, recon: -0.2483, kl: 0.2661, train_time_taken: 150.0973
# INFO:tensorflow:step: 25460, lr: 0.000088, klw: 0.1828, cost: -0.1621, recon: -0.2111, kl: 0.2679, train_time_taken: 145.7790
# INFO:tensorflow:step: 25480, lr: 0.000087, klw: 0.1829, cost: -0.1988, recon: -0.2482, kl: 0.2702, train_time_taken: 147.9040
# INFO:tensorflow:step: 25500, lr: 0.000087, klw: 0.1829, cost: -0.1580, recon: -0.2076, kl: 0.2707, train_time_taken: 145.2127
# INFO:tensorflow:best_valid_cost: -0.1688, valid_cost: -0.1668, valid_recon: -0.1696, valid_kl: 0.2716, valid_time_taken: 5.6499
# INFO:tensorflow:step: 25520, lr: 0.000087, klw: 0.1830, cost: -0.2017, recon: -0.2512, kl: 0.2704, train_time_taken: 144.4591
# INFO:tensorflow:step: 25540, lr: 0.000087, klw: 0.1831, cost: -0.1003, recon: -0.1491, kl: 0.2666, train_time_taken: 143.0586
# INFO:tensorflow:step: 25560, lr: 0.000087, klw: 0.1831, cost: -0.1026, recon: -0.1517, kl: 0.2683, train_time_taken: 143.6082
# INFO:tensorflow:step: 25580, lr: 0.000087, klw: 0.1832, cost: -0.1817, recon: -0.2311, kl: 0.2695, train_time_taken: 142.9206
# INFO:tensorflow:step: 25600, lr: 0.000087, klw: 0.1833, cost: -0.1726, recon: -0.2216, kl: 0.2673, train_time_taken: 142.8529
# INFO:tensorflow:step: 25620, lr: 0.000086, klw: 0.1833, cost: -0.1083, recon: -0.1566, kl: 0.2636, train_time_taken: 143.4131
# INFO:tensorflow:step: 25640, lr: 0.000086, klw: 0.1834, cost: -0.1468, recon: -0.1958, kl: 0.2671, train_time_taken: 146.5075
# INFO:tensorflow:step: 25660, lr: 0.000086, klw: 0.1835, cost: -0.2162, recon: -0.2657, kl: 0.2700, train_time_taken: 147.2336
# INFO:tensorflow:step: 25680, lr: 0.000086, klw: 0.1835, cost: -0.1782, recon: -0.2280, kl: 0.2715, train_time_taken: 147.5279
# INFO:tensorflow:step: 25700, lr: 0.000086, klw: 0.1836, cost: -0.1518, recon: -0.2009, kl: 0.2673, train_time_taken: 144.9778
# INFO:tensorflow:step: 25720, lr: 0.000086, klw: 0.1837, cost: -0.1701, recon: -0.2194, kl: 0.2685, train_time_taken: 144.5183
# INFO:tensorflow:step: 25740, lr: 0.000085, klw: 0.1837, cost: -0.1390, recon: -0.1878, kl: 0.2656, train_time_taken: 144.9944
# INFO:tensorflow:step: 25760, lr: 0.000085, klw: 0.1838, cost: -0.1315, recon: -0.1808, kl: 0.2679, train_time_taken: 146.1598
# INFO:tensorflow:step: 25780, lr: 0.000085, klw: 0.1839, cost: -0.1193, recon: -0.1681, kl: 0.2652, train_time_taken: 144.2132
# INFO:tensorflow:step: 25800, lr: 0.000085, klw: 0.1839, cost: -0.1621, recon: -0.2114, kl: 0.2683, train_time_taken: 141.4591
# INFO:tensorflow:step: 25820, lr: 0.000085, klw: 0.1840, cost: -0.1382, recon: -0.1872, kl: 0.2664, train_time_taken: 141.2036
# INFO:tensorflow:step: 25840, lr: 0.000085, klw: 0.1841, cost: -0.1618, recon: -0.2109, kl: 0.2667, train_time_taken: 145.1416
# INFO:tensorflow:step: 25860, lr: 0.000085, klw: 0.1841, cost: -0.1565, recon: -0.2058, kl: 0.2675, train_time_taken: 144.1678
# INFO:tensorflow:step: 25880, lr: 0.000084, klw: 0.1842, cost: -0.1314, recon: -0.1800, kl: 0.2639, train_time_taken: 140.7525
# INFO:tensorflow:step: 25900, lr: 0.000084, klw: 0.1843, cost: -0.1499, recon: -0.1989, kl: 0.2659, train_time_taken: 140.3537
# INFO:tensorflow:step: 25920, lr: 0.000084, klw: 0.1843, cost: -0.1462, recon: -0.1947, kl: 0.2633, train_time_taken: 138.7987
# INFO:tensorflow:step: 25940, lr: 0.000084, klw: 0.1844, cost: -0.1632, recon: -0.2124, kl: 0.2666, train_time_taken: 139.2563
# INFO:tensorflow:step: 25960, lr: 0.000084, klw: 0.1845, cost: -0.1120, recon: -0.1608, kl: 0.2646, train_time_taken: 138.6367
# INFO:tensorflow:step: 25980, lr: 0.000084, klw: 0.1845, cost: -0.2331, recon: -0.2829, kl: 0.2698, train_time_taken: 142.8808
# INFO:tensorflow:step: 26000, lr: 0.000084, klw: 0.1846, cost: -0.1601, recon: -0.2088, kl: 0.2642, train_time_taken: 144.5858
# INFO:tensorflow:best_valid_cost: -0.1746, valid_cost: -0.1746, valid_recon: -0.1773, valid_kl: 0.2708, valid_time_taken: 5.5845
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 26000.
# INFO:tensorflow:time_taken_save 0.7503.
# INFO:tensorflow:eval_cost: -0.1853, eval_recon: -0.1880, eval_kl: 0.2714, eval_time_taken: 5.4718
# INFO:tensorflow:step: 26020, lr: 0.000083, klw: 0.1847, cost: -0.1190, recon: -0.1685, kl: 0.2678, train_time_taken: 142.7594
# INFO:tensorflow:step: 26040, lr: 0.000083, klw: 0.1847, cost: -0.1213, recon: -0.1705, kl: 0.2662, train_time_taken: 141.3999
# INFO:tensorflow:step: 26060, lr: 0.000083, klw: 0.1848, cost: -0.0843, recon: -0.1329, kl: 0.2628, train_time_taken: 140.0499
# INFO:tensorflow:step: 26080, lr: 0.000083, klw: 0.1849, cost: -0.1440, recon: -0.1936, kl: 0.2685, train_time_taken: 146.0960
# INFO:tensorflow:step: 26100, lr: 0.000083, klw: 0.1849, cost: -0.1774, recon: -0.2269, kl: 0.2678, train_time_taken: 146.8084
# INFO:tensorflow:step: 26120, lr: 0.000083, klw: 0.1850, cost: -0.1319, recon: -0.1810, kl: 0.2657, train_time_taken: 146.3425
# INFO:tensorflow:step: 26140, lr: 0.000082, klw: 0.1851, cost: -0.1645, recon: -0.2141, kl: 0.2681, train_time_taken: 144.2558
# INFO:tensorflow:step: 26160, lr: 0.000082, klw: 0.1851, cost: -0.1315, recon: -0.1809, kl: 0.2672, train_time_taken: 145.6613
# INFO:tensorflow:step: 26180, lr: 0.000082, klw: 0.1852, cost: -0.1613, recon: -0.2114, kl: 0.2706, train_time_taken: 141.8713
# INFO:tensorflow:step: 26200, lr: 0.000082, klw: 0.1852, cost: -0.2629, recon: -0.3128, kl: 0.2695, train_time_taken: 142.1505
# INFO:tensorflow:step: 26220, lr: 0.000082, klw: 0.1853, cost: -0.1302, recon: -0.1795, kl: 0.2661, train_time_taken: 140.0302
# INFO:tensorflow:step: 26240, lr: 0.000082, klw: 0.1854, cost: -0.1465, recon: -0.1955, kl: 0.2643, train_time_taken: 137.1229
# INFO:tensorflow:step: 26260, lr: 0.000082, klw: 0.1854, cost: -0.1181, recon: -0.1675, kl: 0.2664, train_time_taken: 140.1246
# INFO:tensorflow:step: 26280, lr: 0.000081, klw: 0.1855, cost: -0.1276, recon: -0.1770, kl: 0.2662, train_time_taken: 139.9382
# INFO:tensorflow:step: 26300, lr: 0.000081, klw: 0.1856, cost: -0.2293, recon: -0.2795, kl: 0.2705, train_time_taken: 138.9157
# INFO:tensorflow:step: 26320, lr: 0.000081, klw: 0.1856, cost: -0.1821, recon: -0.2318, kl: 0.2679, train_time_taken: 137.9538
# INFO:tensorflow:step: 26340, lr: 0.000081, klw: 0.1857, cost: -0.1786, recon: -0.2279, kl: 0.2651, train_time_taken: 148.0244
# INFO:tensorflow:step: 26360, lr: 0.000081, klw: 0.1858, cost: -0.1469, recon: -0.1965, kl: 0.2671, train_time_taken: 144.5360
# INFO:tensorflow:step: 26380, lr: 0.000081, klw: 0.1858, cost: -0.2604, recon: -0.3103, kl: 0.2687, train_time_taken: 146.1003
# INFO:tensorflow:step: 26400, lr: 0.000081, klw: 0.1859, cost: -0.1188, recon: -0.1674, kl: 0.2617, train_time_taken: 142.8278
# INFO:tensorflow:step: 26420, lr: 0.000080, klw: 0.1860, cost: -0.1101, recon: -0.1596, kl: 0.2661, train_time_taken: 146.3053
# INFO:tensorflow:step: 26440, lr: 0.000080, klw: 0.1860, cost: -0.1673, recon: -0.2170, kl: 0.2670, train_time_taken: 142.8791
# INFO:tensorflow:step: 26460, lr: 0.000080, klw: 0.1861, cost: -0.1527, recon: -0.2028, kl: 0.2694, train_time_taken: 142.4406
# INFO:tensorflow:step: 26480, lr: 0.000080, klw: 0.1861, cost: -0.1762, recon: -0.2262, kl: 0.2688, train_time_taken: 144.9096
# INFO:tensorflow:step: 26500, lr: 0.000080, klw: 0.1862, cost: -0.1681, recon: -0.2178, kl: 0.2671, train_time_taken: 143.7591
# INFO:tensorflow:best_valid_cost: -0.1746, valid_cost: -0.1708, valid_recon: -0.1735, valid_kl: 0.2699, valid_time_taken: 5.5651
# INFO:tensorflow:step: 26520, lr: 0.000080, klw: 0.1863, cost: -0.1357, recon: -0.1852, kl: 0.2655, train_time_taken: 148.8712
# INFO:tensorflow:step: 26540, lr: 0.000080, klw: 0.1863, cost: -0.1118, recon: -0.1617, kl: 0.2676, train_time_taken: 139.1775
# INFO:tensorflow:step: 26560, lr: 0.000080, klw: 0.1864, cost: -0.1756, recon: -0.2254, kl: 0.2671, train_time_taken: 148.2569
# INFO:tensorflow:step: 26580, lr: 0.000079, klw: 0.1865, cost: -0.1358, recon: -0.1851, kl: 0.2647, train_time_taken: 145.7526
# INFO:tensorflow:step: 26600, lr: 0.000079, klw: 0.1865, cost: -0.1533, recon: -0.2032, kl: 0.2674, train_time_taken: 147.8855
# INFO:tensorflow:step: 26620, lr: 0.000079, klw: 0.1866, cost: -0.1531, recon: -0.2031, kl: 0.2678, train_time_taken: 142.2702
# INFO:tensorflow:step: 26640, lr: 0.000079, klw: 0.1867, cost: -0.1212, recon: -0.1710, kl: 0.2670, train_time_taken: 146.6249
# INFO:tensorflow:step: 26660, lr: 0.000079, klw: 0.1867, cost: -0.1422, recon: -0.1918, kl: 0.2656, train_time_taken: 142.1110
# INFO:tensorflow:step: 26680, lr: 0.000079, klw: 0.1868, cost: -0.1316, recon: -0.1812, kl: 0.2655, train_time_taken: 144.1379
# INFO:tensorflow:step: 26700, lr: 0.000079, klw: 0.1868, cost: -0.1407, recon: -0.1901, kl: 0.2647, train_time_taken: 143.0009
# INFO:tensorflow:step: 26720, lr: 0.000078, klw: 0.1869, cost: -0.1125, recon: -0.1622, kl: 0.2659, train_time_taken: 144.6462
# INFO:tensorflow:step: 26740, lr: 0.000078, klw: 0.1870, cost: -0.0917, recon: -0.1412, kl: 0.2646, train_time_taken: 140.0525
# INFO:tensorflow:step: 26760, lr: 0.000078, klw: 0.1870, cost: -0.1841, recon: -0.2333, kl: 0.2631, train_time_taken: 142.6335
# INFO:tensorflow:step: 26780, lr: 0.000078, klw: 0.1871, cost: -0.1259, recon: -0.1748, kl: 0.2615, train_time_taken: 145.6955
# INFO:tensorflow:step: 26800, lr: 0.000078, klw: 0.1872, cost: -0.2038, recon: -0.2538, kl: 0.2672, train_time_taken: 145.4622
# INFO:tensorflow:step: 26820, lr: 0.000078, klw: 0.1872, cost: -0.1340, recon: -0.1841, kl: 0.2675, train_time_taken: 147.1834
# INFO:tensorflow:step: 26840, lr: 0.000078, klw: 0.1873, cost: -0.1091, recon: -0.1590, kl: 0.2663, train_time_taken: 143.7914
# INFO:tensorflow:step: 26860, lr: 0.000077, klw: 0.1873, cost: -0.0930, recon: -0.1427, kl: 0.2650, train_time_taken: 146.3256
# INFO:tensorflow:step: 26880, lr: 0.000077, klw: 0.1874, cost: -0.1571, recon: -0.2070, kl: 0.2663, train_time_taken: 144.5448
# INFO:tensorflow:step: 26900, lr: 0.000077, klw: 0.1875, cost: -0.1673, recon: -0.2170, kl: 0.2654, train_time_taken: 148.0389
# INFO:tensorflow:step: 26920, lr: 0.000077, klw: 0.1875, cost: -0.1407, recon: -0.1904, kl: 0.2652, train_time_taken: 144.2741
# INFO:tensorflow:step: 26940, lr: 0.000077, klw: 0.1876, cost: -0.0643, recon: -0.1140, kl: 0.2651, train_time_taken: 147.6458
# INFO:tensorflow:step: 26960, lr: 0.000077, klw: 0.1877, cost: -0.1379, recon: -0.1879, kl: 0.2662, train_time_taken: 143.4333
# INFO:tensorflow:step: 26980, lr: 0.000077, klw: 0.1877, cost: -0.1544, recon: -0.2048, kl: 0.2685, train_time_taken: 148.5355
# INFO:tensorflow:step: 27000, lr: 0.000077, klw: 0.1878, cost: -0.1459, recon: -0.1956, kl: 0.2646, train_time_taken: 141.8496
# INFO:tensorflow:best_valid_cost: -0.1746, valid_cost: -0.1744, valid_recon: -0.1771, valid_kl: 0.2705, valid_time_taken: 5.5966
# INFO:tensorflow:step: 27020, lr: 0.000076, klw: 0.1878, cost: -0.1818, recon: -0.2319, kl: 0.2666, train_time_taken: 144.6371
# INFO:tensorflow:step: 27040, lr: 0.000076, klw: 0.1879, cost: -0.1458, recon: -0.1956, kl: 0.2651, train_time_taken: 143.3551
# INFO:tensorflow:step: 27060, lr: 0.000076, klw: 0.1880, cost: -0.1534, recon: -0.2037, kl: 0.2676, train_time_taken: 143.7333
# INFO:tensorflow:step: 27080, lr: 0.000076, klw: 0.1880, cost: -0.1360, recon: -0.1858, kl: 0.2649, train_time_taken: 142.8148
# INFO:tensorflow:step: 27100, lr: 0.000076, klw: 0.1881, cost: -0.1217, recon: -0.1717, kl: 0.2658, train_time_taken: 139.5556
# INFO:tensorflow:step: 27120, lr: 0.000076, klw: 0.1882, cost: -0.1414, recon: -0.1917, kl: 0.2673, train_time_taken: 140.7780
# INFO:tensorflow:step: 27140, lr: 0.000076, klw: 0.1882, cost: -0.2473, recon: -0.2977, kl: 0.2673, train_time_taken: 143.5672
# INFO:tensorflow:step: 27160, lr: 0.000075, klw: 0.1883, cost: -0.2034, recon: -0.2535, kl: 0.2658, train_time_taken: 142.8371
# INFO:tensorflow:step: 27180, lr: 0.000075, klw: 0.1883, cost: -0.1137, recon: -0.1631, kl: 0.2620, train_time_taken: 142.0869
# INFO:tensorflow:step: 27200, lr: 0.000075, klw: 0.1884, cost: -0.0714, recon: -0.1213, kl: 0.2651, train_time_taken: 141.9855
# INFO:tensorflow:step: 27220, lr: 0.000075, klw: 0.1885, cost: -0.2735, recon: -0.3244, kl: 0.2703, train_time_taken: 142.3653
# INFO:tensorflow:step: 27240, lr: 0.000075, klw: 0.1885, cost: -0.1505, recon: -0.2003, kl: 0.2643, train_time_taken: 145.2425
# INFO:tensorflow:step: 27260, lr: 0.000075, klw: 0.1886, cost: -0.1558, recon: -0.2061, kl: 0.2672, train_time_taken: 138.6062
# INFO:tensorflow:step: 27280, lr: 0.000075, klw: 0.1886, cost: -0.1378, recon: -0.1874, kl: 0.2630, train_time_taken: 143.8712
# INFO:tensorflow:step: 27300, lr: 0.000075, klw: 0.1887, cost: -0.0856, recon: -0.1350, kl: 0.2619, train_time_taken: 140.7381
# INFO:tensorflow:step: 27320, lr: 0.000074, klw: 0.1888, cost: -0.2283, recon: -0.2791, kl: 0.2689, train_time_taken: 139.3664
# INFO:tensorflow:step: 27340, lr: 0.000074, klw: 0.1888, cost: -0.1530, recon: -0.2035, kl: 0.2675, train_time_taken: 142.8373
# INFO:tensorflow:step: 27360, lr: 0.000074, klw: 0.1889, cost: -0.1124, recon: -0.1624, kl: 0.2644, train_time_taken: 140.5232
# INFO:tensorflow:step: 27380, lr: 0.000074, klw: 0.1890, cost: -0.1219, recon: -0.1719, kl: 0.2643, train_time_taken: 140.9001
# INFO:tensorflow:step: 27400, lr: 0.000074, klw: 0.1890, cost: -0.1448, recon: -0.1951, kl: 0.2660, train_time_taken: 137.0796
# INFO:tensorflow:step: 27420, lr: 0.000074, klw: 0.1891, cost: -0.1538, recon: -0.2039, kl: 0.2651, train_time_taken: 139.7081
# INFO:tensorflow:step: 27440, lr: 0.000074, klw: 0.1891, cost: -0.2067, recon: -0.2570, kl: 0.2656, train_time_taken: 133.6385
# INFO:tensorflow:step: 27460, lr: 0.000074, klw: 0.1892, cost: -0.1884, recon: -0.2383, kl: 0.2638, train_time_taken: 134.6082
# INFO:tensorflow:step: 27480, lr: 0.000073, klw: 0.1893, cost: -0.1457, recon: -0.1956, kl: 0.2639, train_time_taken: 134.4126
# INFO:tensorflow:step: 27500, lr: 0.000073, klw: 0.1893, cost: -0.1731, recon: -0.2238, kl: 0.2678, train_time_taken: 136.4150
# INFO:tensorflow:best_valid_cost: -0.1837, valid_cost: -0.1837, valid_recon: -0.1864, valid_kl: 0.2711, valid_time_taken: 5.3717
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 27500.
# INFO:tensorflow:time_taken_save 0.7500.
# INFO:tensorflow:eval_cost: -0.1883, eval_recon: -0.1910, eval_kl: 0.2718, eval_time_taken: 5.3472
# INFO:tensorflow:step: 27520, lr: 0.000073, klw: 0.1894, cost: -0.1800, recon: -0.2303, kl: 0.2656, train_time_taken: 139.8311
# INFO:tensorflow:step: 27540, lr: 0.000073, klw: 0.1894, cost: -0.1920, recon: -0.2422, kl: 0.2650, train_time_taken: 138.2188
# INFO:tensorflow:step: 27560, lr: 0.000073, klw: 0.1895, cost: -0.1356, recon: -0.1857, kl: 0.2644, train_time_taken: 142.4301
# INFO:tensorflow:step: 27580, lr: 0.000073, klw: 0.1896, cost: -0.1901, recon: -0.2403, kl: 0.2650, train_time_taken: 136.6170
# INFO:tensorflow:step: 27600, lr: 0.000073, klw: 0.1896, cost: -0.1927, recon: -0.2430, kl: 0.2652, train_time_taken: 141.3898
# INFO:tensorflow:step: 27620, lr: 0.000073, klw: 0.1897, cost: -0.2299, recon: -0.2803, kl: 0.2661, train_time_taken: 136.5944
# INFO:tensorflow:step: 27640, lr: 0.000072, klw: 0.1897, cost: -0.1481, recon: -0.1983, kl: 0.2648, train_time_taken: 138.6471
# INFO:tensorflow:step: 27660, lr: 0.000072, klw: 0.1898, cost: -0.1398, recon: -0.1910, kl: 0.2693, train_time_taken: 134.6463
# INFO:tensorflow:step: 27680, lr: 0.000072, klw: 0.1899, cost: -0.1132, recon: -0.1639, kl: 0.2669, train_time_taken: 137.6579
# INFO:tensorflow:step: 27700, lr: 0.000072, klw: 0.1899, cost: -0.2029, recon: -0.2539, kl: 0.2686, train_time_taken: 135.7398
# INFO:tensorflow:step: 27720, lr: 0.000072, klw: 0.1900, cost: -0.1834, recon: -0.2344, kl: 0.2680, train_time_taken: 133.6291
# INFO:tensorflow:step: 27740, lr: 0.000072, klw: 0.1900, cost: -0.0754, recon: -0.1250, kl: 0.2614, train_time_taken: 134.8671
# INFO:tensorflow:step: 27760, lr: 0.000072, klw: 0.1901, cost: -0.2096, recon: -0.2602, kl: 0.2664, train_time_taken: 133.3544
# INFO:tensorflow:step: 27780, lr: 0.000072, klw: 0.1902, cost: -0.2356, recon: -0.2864, kl: 0.2670, train_time_taken: 134.8251
# INFO:tensorflow:step: 27800, lr: 0.000071, klw: 0.1902, cost: -0.0709, recon: -0.1216, kl: 0.2662, train_time_taken: 130.2013
# INFO:tensorflow:step: 27820, lr: 0.000071, klw: 0.1903, cost: -0.1204, recon: -0.1714, kl: 0.2682, train_time_taken: 133.3620
# INFO:tensorflow:step: 27840, lr: 0.000071, klw: 0.1903, cost: -0.1216, recon: -0.1721, kl: 0.2654, train_time_taken: 134.3597
# INFO:tensorflow:step: 27860, lr: 0.000071, klw: 0.1904, cost: -0.1683, recon: -0.2189, kl: 0.2657, train_time_taken: 133.3303
# INFO:tensorflow:step: 27880, lr: 0.000071, klw: 0.1905, cost: -0.1495, recon: -0.2000, kl: 0.2651, train_time_taken: 132.0846
# INFO:tensorflow:step: 27900, lr: 0.000071, klw: 0.1905, cost: -0.1384, recon: -0.1892, kl: 0.2668, train_time_taken: 130.3420
# INFO:tensorflow:step: 27920, lr: 0.000071, klw: 0.1906, cost: -0.2247, recon: -0.2755, kl: 0.2665, train_time_taken: 129.2141
# INFO:tensorflow:step: 27940, lr: 0.000071, klw: 0.1906, cost: -0.1544, recon: -0.2046, kl: 0.2634, train_time_taken: 129.0244
# INFO:tensorflow:step: 27960, lr: 0.000070, klw: 0.1907, cost: -0.1392, recon: -0.1900, kl: 0.2667, train_time_taken: 130.0088
# INFO:tensorflow:step: 27980, lr: 0.000070, klw: 0.1908, cost: -0.1362, recon: -0.1863, kl: 0.2626, train_time_taken: 130.6353
# INFO:tensorflow:step: 28000, lr: 0.000070, klw: 0.1908, cost: -0.1390, recon: -0.1898, kl: 0.2662, train_time_taken: 129.7910
# INFO:tensorflow:best_valid_cost: -0.1934, valid_cost: -0.1934, valid_recon: -0.1961, valid_kl: 0.2696, valid_time_taken: 5.0745
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 28000.
# INFO:tensorflow:time_taken_save 0.7379.
# INFO:tensorflow:eval_cost: -0.2003, eval_recon: -0.2030, eval_kl: 0.2703, eval_time_taken: 5.2211
# INFO:tensorflow:step: 28020, lr: 0.000070, klw: 0.1909, cost: -0.1498, recon: -0.2008, kl: 0.2669, train_time_taken: 129.9314
# INFO:tensorflow:step: 28040, lr: 0.000070, klw: 0.1909, cost: -0.2115, recon: -0.2612, kl: 0.2606, train_time_taken: 129.4518
# INFO:tensorflow:step: 28060, lr: 0.000070, klw: 0.1910, cost: -0.0784, recon: -0.1284, kl: 0.2617, train_time_taken: 132.8059
# INFO:tensorflow:step: 28080, lr: 0.000070, klw: 0.1911, cost: -0.2151, recon: -0.2661, kl: 0.2666, train_time_taken: 136.9170
# INFO:tensorflow:step: 28100, lr: 0.000070, klw: 0.1911, cost: -0.2491, recon: -0.3002, kl: 0.2675, train_time_taken: 142.0156
# INFO:tensorflow:step: 28120, lr: 0.000069, klw: 0.1912, cost: -0.1655, recon: -0.2163, kl: 0.2657, train_time_taken: 143.6634
# INFO:tensorflow:step: 28140, lr: 0.000069, klw: 0.1912, cost: -0.2044, recon: -0.2556, kl: 0.2677, train_time_taken: 142.3499
# INFO:tensorflow:step: 28160, lr: 0.000069, klw: 0.1913, cost: -0.1282, recon: -0.1793, kl: 0.2669, train_time_taken: 143.9105
# INFO:tensorflow:step: 28180, lr: 0.000069, klw: 0.1913, cost: -0.2036, recon: -0.2539, kl: 0.2625, train_time_taken: 143.3438
# INFO:tensorflow:step: 28200, lr: 0.000069, klw: 0.1914, cost: -0.1583, recon: -0.2089, kl: 0.2644, train_time_taken: 141.3576
# INFO:tensorflow:step: 28220, lr: 0.000069, klw: 0.1915, cost: -0.1495, recon: -0.2006, kl: 0.2665, train_time_taken: 136.5553
# INFO:tensorflow:step: 28240, lr: 0.000069, klw: 0.1915, cost: -0.1675, recon: -0.2186, kl: 0.2669, train_time_taken: 136.4751
# INFO:tensorflow:step: 28260, lr: 0.000069, klw: 0.1916, cost: -0.1060, recon: -0.1568, kl: 0.2654, train_time_taken: 135.1667
# INFO:tensorflow:step: 28280, lr: 0.000069, klw: 0.1916, cost: -0.1982, recon: -0.2484, kl: 0.2622, train_time_taken: 137.5007
# INFO:tensorflow:step: 28300, lr: 0.000068, klw: 0.1917, cost: -0.1927, recon: -0.2436, kl: 0.2655, train_time_taken: 139.2917
# INFO:tensorflow:step: 28320, lr: 0.000068, klw: 0.1918, cost: -0.1810, recon: -0.2320, kl: 0.2656, train_time_taken: 135.6851
# INFO:tensorflow:step: 28340, lr: 0.000068, klw: 0.1918, cost: -0.2234, recon: -0.2749, kl: 0.2685, train_time_taken: 134.9915
# INFO:tensorflow:step: 28360, lr: 0.000068, klw: 0.1919, cost: -0.2100, recon: -0.2609, kl: 0.2649, train_time_taken: 136.3859
# INFO:tensorflow:step: 28380, lr: 0.000068, klw: 0.1919, cost: -0.2025, recon: -0.2535, kl: 0.2654, train_time_taken: 137.3138
# INFO:tensorflow:step: 28400, lr: 0.000068, klw: 0.1920, cost: -0.1798, recon: -0.2314, kl: 0.2690, train_time_taken: 137.0026
# INFO:tensorflow:step: 28420, lr: 0.000068, klw: 0.1920, cost: -0.1824, recon: -0.2337, kl: 0.2670, train_time_taken: 137.6166
# INFO:tensorflow:step: 28440, lr: 0.000068, klw: 0.1921, cost: -0.1728, recon: -0.2236, kl: 0.2644, train_time_taken: 135.8522
# INFO:tensorflow:step: 28460, lr: 0.000067, klw: 0.1922, cost: -0.2053, recon: -0.2569, kl: 0.2685, train_time_taken: 133.8458
# INFO:tensorflow:step: 28480, lr: 0.000067, klw: 0.1922, cost: -0.1628, recon: -0.2138, kl: 0.2654, train_time_taken: 132.5344
# INFO:tensorflow:step: 28500, lr: 0.000067, klw: 0.1923, cost: -0.1587, recon: -0.2092, kl: 0.2629, train_time_taken: 129.8214
# INFO:tensorflow:best_valid_cost: -0.1934, valid_cost: -0.1850, valid_recon: -0.1877, valid_kl: 0.2687, valid_time_taken: 5.2344
# INFO:tensorflow:step: 28520, lr: 0.000067, klw: 0.1923, cost: -0.1704, recon: -0.2214, kl: 0.2650, train_time_taken: 134.9974
# INFO:tensorflow:step: 28540, lr: 0.000067, klw: 0.1924, cost: -0.0883, recon: -0.1394, kl: 0.2654, train_time_taken: 131.7842
# INFO:tensorflow:step: 28560, lr: 0.000067, klw: 0.1925, cost: -0.0948, recon: -0.1457, kl: 0.2648, train_time_taken: 133.5216
# INFO:tensorflow:step: 28580, lr: 0.000067, klw: 0.1925, cost: -0.1493, recon: -0.2003, kl: 0.2649, train_time_taken: 134.8017
# INFO:tensorflow:step: 28600, lr: 0.000067, klw: 0.1926, cost: -0.1747, recon: -0.2253, kl: 0.2631, train_time_taken: 138.2262
# INFO:tensorflow:step: 28620, lr: 0.000067, klw: 0.1926, cost: -0.1765, recon: -0.2279, kl: 0.2667, train_time_taken: 141.1612
# INFO:tensorflow:step: 28640, lr: 0.000066, klw: 0.1927, cost: -0.1933, recon: -0.2443, kl: 0.2649, train_time_taken: 139.5642
# INFO:tensorflow:step: 28660, lr: 0.000066, klw: 0.1927, cost: -0.1297, recon: -0.1805, kl: 0.2636, train_time_taken: 138.5091
# INFO:tensorflow:step: 28680, lr: 0.000066, klw: 0.1928, cost: -0.2237, recon: -0.2753, kl: 0.2674, train_time_taken: 134.7619
# INFO:tensorflow:step: 28700, lr: 0.000066, klw: 0.1929, cost: -0.1922, recon: -0.2430, kl: 0.2634, train_time_taken: 132.2062
# INFO:tensorflow:step: 28720, lr: 0.000066, klw: 0.1929, cost: -0.1712, recon: -0.2222, kl: 0.2643, train_time_taken: 133.5027
# INFO:tensorflow:step: 28740, lr: 0.000066, klw: 0.1930, cost: -0.1992, recon: -0.2508, kl: 0.2672, train_time_taken: 130.5011
# INFO:tensorflow:step: 28760, lr: 0.000066, klw: 0.1930, cost: -0.2033, recon: -0.2547, kl: 0.2665, train_time_taken: 132.5863
# INFO:tensorflow:step: 28780, lr: 0.000066, klw: 0.1931, cost: -0.1500, recon: -0.2013, kl: 0.2659, train_time_taken: 130.9688
# INFO:tensorflow:step: 28800, lr: 0.000066, klw: 0.1931, cost: -0.2169, recon: -0.2681, kl: 0.2651, train_time_taken: 132.6078
# INFO:tensorflow:step: 28820, lr: 0.000065, klw: 0.1932, cost: -0.1106, recon: -0.1618, kl: 0.2649, train_time_taken: 128.3519
# INFO:tensorflow:step: 28840, lr: 0.000065, klw: 0.1933, cost: -0.2140, recon: -0.2649, kl: 0.2634, train_time_taken: 130.7086
# INFO:tensorflow:step: 28860, lr: 0.000065, klw: 0.1933, cost: -0.1806, recon: -0.2315, kl: 0.2634, train_time_taken: 130.6341
# INFO:tensorflow:step: 28880, lr: 0.000065, klw: 0.1934, cost: -0.1010, recon: -0.1524, kl: 0.2658, train_time_taken: 130.4162
# INFO:tensorflow:step: 28900, lr: 0.000065, klw: 0.1934, cost: -0.2201, recon: -0.2715, kl: 0.2656, train_time_taken: 136.7024
# INFO:tensorflow:step: 28920, lr: 0.000065, klw: 0.1935, cost: -0.1914, recon: -0.2430, kl: 0.2671, train_time_taken: 135.0499
# INFO:tensorflow:step: 28940, lr: 0.000065, klw: 0.1935, cost: -0.2296, recon: -0.2814, kl: 0.2677, train_time_taken: 134.2734
# INFO:tensorflow:step: 28960, lr: 0.000065, klw: 0.1936, cost: -0.1709, recon: -0.2215, kl: 0.2615, train_time_taken: 129.8143
# INFO:tensorflow:step: 28980, lr: 0.000065, klw: 0.1936, cost: -0.2409, recon: -0.2916, kl: 0.2615, train_time_taken: 130.1644
# INFO:tensorflow:step: 29000, lr: 0.000064, klw: 0.1937, cost: -0.1843, recon: -0.2358, kl: 0.2659, train_time_taken: 129.9790
# INFO:tensorflow:best_valid_cost: -0.1980, valid_cost: -0.1980, valid_recon: -0.2007, valid_kl: 0.2690, valid_time_taken: 5.0730
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 29000.
# INFO:tensorflow:time_taken_save 0.8087.
# INFO:tensorflow:eval_cost: -0.2009, eval_recon: -0.2036, eval_kl: 0.2696, eval_time_taken: 5.0856
# INFO:tensorflow:step: 29020, lr: 0.000064, klw: 0.1938, cost: -0.1515, recon: -0.2029, kl: 0.2655, train_time_taken: 130.0479
# INFO:tensorflow:step: 29040, lr: 0.000064, klw: 0.1938, cost: -0.1767, recon: -0.2270, kl: 0.2596, train_time_taken: 131.7138
# INFO:tensorflow:step: 29060, lr: 0.000064, klw: 0.1939, cost: -0.1796, recon: -0.2311, kl: 0.2655, train_time_taken: 129.9417
# INFO:tensorflow:step: 29080, lr: 0.000064, klw: 0.1939, cost: -0.1631, recon: -0.2144, kl: 0.2645, train_time_taken: 130.3811
# INFO:tensorflow:step: 29100, lr: 0.000064, klw: 0.1940, cost: -0.2047, recon: -0.2562, kl: 0.2656, train_time_taken: 128.8163
# INFO:tensorflow:step: 29120, lr: 0.000064, klw: 0.1940, cost: -0.1660, recon: -0.2169, kl: 0.2625, train_time_taken: 131.4840
# INFO:tensorflow:step: 29140, lr: 0.000064, klw: 0.1941, cost: -0.1355, recon: -0.1871, kl: 0.2659, train_time_taken: 133.3961
# INFO:tensorflow:step: 29160, lr: 0.000064, klw: 0.1942, cost: -0.1267, recon: -0.1778, kl: 0.2632, train_time_taken: 135.3444
# INFO:tensorflow:step: 29180, lr: 0.000063, klw: 0.1942, cost: -0.1970, recon: -0.2486, kl: 0.2655, train_time_taken: 139.6081
# INFO:tensorflow:step: 29200, lr: 0.000063, klw: 0.1943, cost: -0.1567, recon: -0.2080, kl: 0.2639, train_time_taken: 136.6153
# INFO:tensorflow:step: 29220, lr: 0.000063, klw: 0.1943, cost: -0.2508, recon: -0.3028, kl: 0.2677, train_time_taken: 137.5107
# INFO:tensorflow:step: 29240, lr: 0.000063, klw: 0.1944, cost: -0.2166, recon: -0.2687, kl: 0.2679, train_time_taken: 130.0450
# INFO:tensorflow:step: 29260, lr: 0.000063, klw: 0.1944, cost: -0.2346, recon: -0.2859, kl: 0.2637, train_time_taken: 134.6095
# INFO:tensorflow:step: 29280, lr: 0.000063, klw: 0.1945, cost: -0.2344, recon: -0.2862, kl: 0.2661, train_time_taken: 133.0420
# INFO:tensorflow:step: 29300, lr: 0.000063, klw: 0.1945, cost: -0.1663, recon: -0.2173, kl: 0.2622, train_time_taken: 133.1898
# INFO:tensorflow:step: 29320, lr: 0.000063, klw: 0.1946, cost: -0.2064, recon: -0.2576, kl: 0.2631, train_time_taken: 144.8127
# INFO:tensorflow:step: 29340, lr: 0.000063, klw: 0.1947, cost: -0.1712, recon: -0.2228, kl: 0.2649, train_time_taken: 143.8148
# INFO:tensorflow:step: 29360, lr: 0.000063, klw: 0.1947, cost: -0.2068, recon: -0.2589, kl: 0.2676, train_time_taken: 136.1326
# INFO:tensorflow:step: 29380, lr: 0.000062, klw: 0.1948, cost: -0.1683, recon: -0.2198, kl: 0.2643, train_time_taken: 134.2183
# INFO:tensorflow:step: 29400, lr: 0.000062, klw: 0.1948, cost: -0.1874, recon: -0.2389, kl: 0.2640, train_time_taken: 144.4063
# INFO:tensorflow:step: 29420, lr: 0.000062, klw: 0.1949, cost: -0.1563, recon: -0.2077, kl: 0.2641, train_time_taken: 143.9425
# INFO:tensorflow:step: 29440, lr: 0.000062, klw: 0.1949, cost: -0.2054, recon: -0.2572, kl: 0.2657, train_time_taken: 139.2998
# INFO:tensorflow:step: 29460, lr: 0.000062, klw: 0.1950, cost: -0.1183, recon: -0.1695, kl: 0.2624, train_time_taken: 139.1199
# INFO:tensorflow:step: 29480, lr: 0.000062, klw: 0.1950, cost: -0.2049, recon: -0.2562, kl: 0.2627, train_time_taken: 131.3090
# INFO:tensorflow:step: 29500, lr: 0.000062, klw: 0.1951, cost: -0.1868, recon: -0.2380, kl: 0.2627, train_time_taken: 130.8220
# INFO:tensorflow:best_valid_cost: -0.2006, valid_cost: -0.2006, valid_recon: -0.2032, valid_kl: 0.2683, valid_time_taken: 5.1405
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 29500.
# INFO:tensorflow:time_taken_save 0.7830.
# INFO:tensorflow:eval_cost: -0.2091, eval_recon: -0.2118, eval_kl: 0.2689, eval_time_taken: 5.2024
# INFO:tensorflow:step: 29520, lr: 0.000062, klw: 0.1952, cost: -0.2206, recon: -0.2716, kl: 0.2611, train_time_taken: 129.2089
# INFO:tensorflow:step: 29540, lr: 0.000062, klw: 0.1952, cost: -0.2100, recon: -0.2617, kl: 0.2647, train_time_taken: 130.7542
# INFO:tensorflow:step: 29560, lr: 0.000061, klw: 0.1953, cost: -0.2475, recon: -0.2993, kl: 0.2654, train_time_taken: 130.0000
# INFO:tensorflow:step: 29580, lr: 0.000061, klw: 0.1953, cost: -0.2218, recon: -0.2738, kl: 0.2667, train_time_taken: 132.1588
# INFO:tensorflow:step: 29600, lr: 0.000061, klw: 0.1954, cost: -0.1661, recon: -0.2174, kl: 0.2624, train_time_taken: 129.3955
# INFO:tensorflow:step: 29620, lr: 0.000061, klw: 0.1954, cost: -0.1508, recon: -0.2027, kl: 0.2657, train_time_taken: 129.8824
# INFO:tensorflow:step: 29640, lr: 0.000061, klw: 0.1955, cost: -0.1917, recon: -0.2435, kl: 0.2647, train_time_taken: 131.2036
# INFO:tensorflow:step: 29660, lr: 0.000061, klw: 0.1955, cost: -0.2027, recon: -0.2541, kl: 0.2629, train_time_taken: 130.6824
# INFO:tensorflow:step: 29680, lr: 0.000061, klw: 0.1956, cost: -0.1901, recon: -0.2422, kl: 0.2665, train_time_taken: 137.0179
# INFO:tensorflow:step: 29700, lr: 0.000061, klw: 0.1956, cost: -0.1653, recon: -0.2165, kl: 0.2615, train_time_taken: 138.2326
# INFO:tensorflow:step: 29720, lr: 0.000061, klw: 0.1957, cost: -0.1840, recon: -0.2364, kl: 0.2676, train_time_taken: 141.7218
# INFO:tensorflow:step: 29740, lr: 0.000061, klw: 0.1958, cost: -0.2110, recon: -0.2627, kl: 0.2645, train_time_taken: 138.0281
# INFO:tensorflow:step: 29760, lr: 0.000060, klw: 0.1958, cost: -0.2143, recon: -0.2662, kl: 0.2651, train_time_taken: 140.7593
# INFO:tensorflow:step: 29780, lr: 0.000060, klw: 0.1959, cost: -0.1801, recon: -0.2315, kl: 0.2628, train_time_taken: 140.2289
# INFO:tensorflow:step: 29800, lr: 0.000060, klw: 0.1959, cost: -0.1923, recon: -0.2432, kl: 0.2597, train_time_taken: 139.0138
# INFO:tensorflow:step: 29820, lr: 0.000060, klw: 0.1960, cost: -0.1705, recon: -0.2221, kl: 0.2633, train_time_taken: 136.3945
# INFO:tensorflow:step: 29840, lr: 0.000060, klw: 0.1960, cost: -0.1161, recon: -0.1679, kl: 0.2644, train_time_taken: 133.5316
# INFO:tensorflow:step: 29860, lr: 0.000060, klw: 0.1961, cost: -0.2346, recon: -0.2864, kl: 0.2638, train_time_taken: 135.0206
# INFO:tensorflow:step: 29880, lr: 0.000060, klw: 0.1961, cost: -0.1946, recon: -0.2467, kl: 0.2656, train_time_taken: 131.4242
# INFO:tensorflow:step: 29900, lr: 0.000060, klw: 0.1962, cost: -0.2698, recon: -0.3218, kl: 0.2652, train_time_taken: 137.2072
# INFO:tensorflow:step: 29920, lr: 0.000060, klw: 0.1962, cost: -0.1725, recon: -0.2244, kl: 0.2646, train_time_taken: 133.2752
# INFO:tensorflow:step: 29940, lr: 0.000060, klw: 0.1963, cost: -0.1055, recon: -0.1573, kl: 0.2639, train_time_taken: 136.3569
# INFO:tensorflow:step: 29960, lr: 0.000059, klw: 0.1963, cost: -0.1710, recon: -0.2221, kl: 0.2604, train_time_taken: 139.3105
# INFO:tensorflow:step: 29980, lr: 0.000059, klw: 0.1964, cost: -0.2078, recon: -0.2605, kl: 0.2680, train_time_taken: 138.1207
# INFO:tensorflow:step: 30000, lr: 0.000059, klw: 0.1965, cost: -0.1760, recon: -0.2278, kl: 0.2636, train_time_taken: 138.4194
# INFO:tensorflow:best_valid_cost: -0.2006, valid_cost: -0.1995, valid_recon: -0.2022, valid_kl: 0.2676, valid_time_taken: 5.4827
# INFO:tensorflow:step: 30020, lr: 0.000059, klw: 0.1965, cost: -0.2310, recon: -0.2826, kl: 0.2629, train_time_taken: 136.7873
# INFO:tensorflow:step: 30040, lr: 0.000059, klw: 0.1966, cost: -0.1786, recon: -0.2308, kl: 0.2658, train_time_taken: 139.3480
# INFO:tensorflow:step: 30060, lr: 0.000059, klw: 0.1966, cost: -0.1364, recon: -0.1882, kl: 0.2635, train_time_taken: 136.7533
# INFO:tensorflow:step: 30080, lr: 0.000059, klw: 0.1967, cost: -0.1863, recon: -0.2379, kl: 0.2622, train_time_taken: 134.5112
# INFO:tensorflow:step: 30100, lr: 0.000059, klw: 0.1967, cost: -0.1435, recon: -0.1953, kl: 0.2633, train_time_taken: 128.6153
# INFO:tensorflow:step: 30120, lr: 0.000059, klw: 0.1968, cost: -0.1872, recon: -0.2387, kl: 0.2619, train_time_taken: 131.5775
# INFO:tensorflow:step: 30140, lr: 0.000059, klw: 0.1968, cost: -0.1775, recon: -0.2295, kl: 0.2642, train_time_taken: 132.5738
# INFO:tensorflow:step: 30160, lr: 0.000058, klw: 0.1969, cost: -0.2319, recon: -0.2839, kl: 0.2643, train_time_taken: 128.7179
# INFO:tensorflow:step: 30180, lr: 0.000058, klw: 0.1969, cost: -0.1734, recon: -0.2248, kl: 0.2612, train_time_taken: 131.1365
# INFO:tensorflow:step: 30200, lr: 0.000058, klw: 0.1970, cost: -0.2051, recon: -0.2570, kl: 0.2633, train_time_taken: 132.6109
# INFO:tensorflow:step: 30220, lr: 0.000058, klw: 0.1970, cost: -0.1538, recon: -0.2058, kl: 0.2635, train_time_taken: 138.3307
# INFO:tensorflow:step: 30240, lr: 0.000058, klw: 0.1971, cost: -0.2001, recon: -0.2525, kl: 0.2659, train_time_taken: 137.6237
# INFO:tensorflow:step: 30260, lr: 0.000058, klw: 0.1971, cost: -0.1675, recon: -0.2193, kl: 0.2630, train_time_taken: 140.2613
# INFO:tensorflow:step: 30280, lr: 0.000058, klw: 0.1972, cost: -0.2438, recon: -0.2959, kl: 0.2641, train_time_taken: 138.6985
# INFO:tensorflow:step: 30300, lr: 0.000058, klw: 0.1972, cost: -0.2477, recon: -0.2997, kl: 0.2636, train_time_taken: 138.8900
# INFO:tensorflow:step: 30320, lr: 0.000058, klw: 0.1973, cost: -0.2209, recon: -0.2731, kl: 0.2645, train_time_taken: 140.8594
# INFO:tensorflow:step: 30340, lr: 0.000058, klw: 0.1974, cost: -0.2156, recon: -0.2683, kl: 0.2672, train_time_taken: 137.3484
# INFO:tensorflow:step: 30360, lr: 0.000058, klw: 0.1974, cost: -0.2141, recon: -0.2661, kl: 0.2634, train_time_taken: 134.1444
# INFO:tensorflow:step: 30380, lr: 0.000057, klw: 0.1975, cost: -0.1670, recon: -0.2191, kl: 0.2639, train_time_taken: 134.1952
# INFO:tensorflow:step: 30400, lr: 0.000057, klw: 0.1975, cost: -0.1116, recon: -0.1639, kl: 0.2649, train_time_taken: 133.8949
# INFO:tensorflow:step: 30420, lr: 0.000057, klw: 0.1976, cost: -0.2112, recon: -0.2633, kl: 0.2637, train_time_taken: 130.2636
# INFO:tensorflow:step: 30440, lr: 0.000057, klw: 0.1976, cost: -0.1952, recon: -0.2474, kl: 0.2637, train_time_taken: 130.5431
# INFO:tensorflow:step: 30460, lr: 0.000057, klw: 0.1977, cost: -0.2211, recon: -0.2738, kl: 0.2662, train_time_taken: 130.9753
# INFO:tensorflow:step: 30480, lr: 0.000057, klw: 0.1977, cost: -0.2121, recon: -0.2648, kl: 0.2667, train_time_taken: 131.4024
# INFO:tensorflow:step: 30500, lr: 0.000057, klw: 0.1978, cost: -0.2033, recon: -0.2554, kl: 0.2638, train_time_taken: 136.8949
# INFO:tensorflow:best_valid_cost: -0.2042, valid_cost: -0.2042, valid_recon: -0.2069, valid_kl: 0.2686, valid_time_taken: 5.3024
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 30500.
# INFO:tensorflow:time_taken_save 0.8226.
# INFO:tensorflow:eval_cost: -0.2115, eval_recon: -0.2142, eval_kl: 0.2691, eval_time_taken: 5.4332
# INFO:tensorflow:step: 30520, lr: 0.000057, klw: 0.1978, cost: -0.1305, recon: -0.1822, kl: 0.2617, train_time_taken: 134.9072
# INFO:tensorflow:step: 30540, lr: 0.000057, klw: 0.1979, cost: -0.2013, recon: -0.2534, kl: 0.2633, train_time_taken: 132.0540
# INFO:tensorflow:step: 30560, lr: 0.000057, klw: 0.1979, cost: -0.2268, recon: -0.2791, kl: 0.2641, train_time_taken: 131.7032
# ...
# INFO:tensorflow:step: 48240, lr: 0.000018, klw: 0.2285, cost: -0.2835, recon: -0.3432, kl: 0.2611, train_time_taken: 139.9974
# INFO:tensorflow:step: 48260, lr: 0.000018, klw: 0.2285, cost: -0.2996, recon: -0.3583, kl: 0.2570, train_time_taken: 140.4086
# INFO:tensorflow:step: 48280, lr: 0.000018, klw: 0.2285, cost: -0.1739, recon: -0.2329, kl: 0.2584, train_time_taken: 135.3089
# INFO:tensorflow:step: 48300, lr: 0.000018, klw: 0.2286, cost: -0.3052, recon: -0.3644, kl: 0.2588, train_time_taken: 136.7232
# INFO:tensorflow:step: 48320, lr: 0.000018, klw: 0.2286, cost: -0.2993, recon: -0.3584, kl: 0.2585, train_time_taken: 136.2110
# INFO:tensorflow:step: 48340, lr: 0.000018, klw: 0.2286, cost: -0.3303, recon: -0.3899, kl: 0.2610, train_time_taken: 134.3937
# INFO:tensorflow:step: 48360, lr: 0.000018, klw: 0.2286, cost: -0.3544, recon: -0.4144, kl: 0.2623, train_time_taken: 136.0932
# INFO:tensorflow:step: 48380, lr: 0.000018, klw: 0.2286, cost: -0.3133, recon: -0.3726, kl: 0.2590, train_time_taken: 133.6824
# INFO:tensorflow:step: 48400, lr: 0.000018, klw: 0.2287, cost: -0.3481, recon: -0.4076, kl: 0.2600, train_time_taken: 137.6796
# INFO:tensorflow:step: 48420, lr: 0.000018, klw: 0.2287, cost: -0.3075, recon: -0.3672, kl: 0.2609, train_time_taken: 137.6806
# INFO:tensorflow:step: 48440, lr: 0.000018, klw: 0.2287, cost: -0.2809, recon: -0.3403, kl: 0.2596, train_time_taken: 139.0208
# INFO:tensorflow:step: 48460, lr: 0.000018, klw: 0.2287, cost: -0.3144, recon: -0.3738, kl: 0.2597, train_time_taken: 135.2892
# INFO:tensorflow:step: 48480, lr: 0.000018, klw: 0.2287, cost: -0.2591, recon: -0.3185, kl: 0.2598, train_time_taken: 133.2510
# INFO:tensorflow:step: 48500, lr: 0.000018, klw: 0.2288, cost: -0.2262, recon: -0.2852, kl: 0.2580, train_time_taken: 133.5817
# INFO:tensorflow:best_valid_cost: -0.2963, valid_cost: -0.2950, valid_recon: -0.2976, valid_kl: 0.2623, valid_time_taken: 5.1384
# INFO:tensorflow:step: 48520, lr: 0.000018, klw: 0.2288, cost: -0.3126, recon: -0.3718, kl: 0.2588, train_time_taken: 131.6315
# INFO:tensorflow:step: 48540, lr: 0.000018, klw: 0.2288, cost: -0.2206, recon: -0.2792, kl: 0.2562, train_time_taken: 134.3252
# INFO:tensorflow:step: 48560, lr: 0.000018, klw: 0.2288, cost: -0.2745, recon: -0.3340, kl: 0.2602, train_time_taken: 132.6378
# INFO:tensorflow:step: 48580, lr: 0.000018, klw: 0.2289, cost: -0.2893, recon: -0.3494, kl: 0.2625, train_time_taken: 133.6798
# INFO:tensorflow:step: 48600, lr: 0.000018, klw: 0.2289, cost: -0.3236, recon: -0.3830, kl: 0.2599, train_time_taken: 132.0204
# INFO:tensorflow:step: 48620, lr: 0.000018, klw: 0.2289, cost: -0.2860, recon: -0.3451, kl: 0.2583, train_time_taken: 131.4464
# INFO:tensorflow:step: 48640, lr: 0.000018, klw: 0.2289, cost: -0.2882, recon: -0.3471, kl: 0.2575, train_time_taken: 134.6706
# INFO:tensorflow:step: 48660, lr: 0.000018, klw: 0.2289, cost: -0.2392, recon: -0.2984, kl: 0.2584, train_time_taken: 133.5541
# INFO:tensorflow:step: 48680, lr: 0.000018, klw: 0.2290, cost: -0.3016, recon: -0.3616, kl: 0.2624, train_time_taken: 138.2569
# INFO:tensorflow:step: 48700, lr: 0.000018, klw: 0.2290, cost: -0.2884, recon: -0.3483, kl: 0.2614, train_time_taken: 138.9499
# INFO:tensorflow:step: 48720, lr: 0.000018, klw: 0.2290, cost: -0.2632, recon: -0.3225, kl: 0.2585, train_time_taken: 142.5361
# INFO:tensorflow:step: 48740, lr: 0.000018, klw: 0.2290, cost: -0.2611, recon: -0.3204, kl: 0.2589, train_time_taken: 136.4905
# INFO:tensorflow:step: 48760, lr: 0.000018, klw: 0.2290, cost: -0.3065, recon: -0.3663, kl: 0.2611, train_time_taken: 138.1226
# INFO:tensorflow:step: 48780, lr: 0.000018, klw: 0.2291, cost: -0.2784, recon: -0.3383, kl: 0.2615, train_time_taken: 136.2194
# INFO:tensorflow:step: 48800, lr: 0.000018, klw: 0.2291, cost: -0.2120, recon: -0.2715, kl: 0.2597, train_time_taken: 134.8409
# INFO:tensorflow:step: 48820, lr: 0.000018, klw: 0.2291, cost: -0.2886, recon: -0.3479, kl: 0.2585, train_time_taken: 137.5080
# INFO:tensorflow:step: 48840, lr: 0.000017, klw: 0.2291, cost: -0.2214, recon: -0.2803, kl: 0.2573, train_time_taken: 135.0743
# INFO:tensorflow:step: 48860, lr: 0.000017, klw: 0.2291, cost: -0.2839, recon: -0.3427, kl: 0.2568, train_time_taken: 135.5663
# INFO:tensorflow:step: 48880, lr: 0.000017, klw: 0.2292, cost: -0.2655, recon: -0.3250, kl: 0.2596, train_time_taken: 134.1142
# INFO:tensorflow:step: 48900, lr: 0.000017, klw: 0.2292, cost: -0.2940, recon: -0.3535, kl: 0.2596, train_time_taken: 135.7561
# INFO:tensorflow:step: 48920, lr: 0.000017, klw: 0.2292, cost: -0.2140, recon: -0.2736, kl: 0.2601, train_time_taken: 134.1403
# INFO:tensorflow:step: 48940, lr: 0.000017, klw: 0.2292, cost: -0.3361, recon: -0.3951, kl: 0.2571, train_time_taken: 137.0775
# INFO:tensorflow:step: 48960, lr: 0.000017, klw: 0.2292, cost: -0.2181, recon: -0.2772, kl: 0.2577, train_time_taken: 136.8947
# INFO:tensorflow:step: 48980, lr: 0.000017, klw: 0.2293, cost: -0.2412, recon: -0.3010, kl: 0.2606, train_time_taken: 133.9215
# INFO:tensorflow:step: 49000, lr: 0.000017, klw: 0.2293, cost: -0.2788, recon: -0.3378, kl: 0.2576, train_time_taken: 135.2725
# INFO:tensorflow:best_valid_cost: -0.2964, valid_cost: -0.2964, valid_recon: -0.2990, valid_kl: 0.2624, valid_time_taken: 5.0951
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 49000.
# INFO:tensorflow:time_taken_save 1.1242.
# INFO:tensorflow:eval_cost: -0.3020, eval_recon: -0.3047, eval_kl: 0.2627, eval_time_taken: 5.1715
# INFO:tensorflow:step: 49020, lr: 0.000017, klw: 0.2293, cost: -0.2845, recon: -0.3434, kl: 0.2566, train_time_taken: 132.5198
# INFO:tensorflow:step: 49040, lr: 0.000017, klw: 0.2293, cost: -0.3802, recon: -0.4395, kl: 0.2589, train_time_taken: 134.6251
# INFO:tensorflow:step: 49060, lr: 0.000017, klw: 0.2294, cost: -0.2498, recon: -0.3093, kl: 0.2594, train_time_taken: 131.9283
# INFO:tensorflow:step: 49080, lr: 0.000017, klw: 0.2294, cost: -0.2334, recon: -0.2921, kl: 0.2555, train_time_taken: 133.7357
# INFO:tensorflow:step: 49100, lr: 0.000017, klw: 0.2294, cost: -0.2404, recon: -0.3004, kl: 0.2619, train_time_taken: 133.7075
# INFO:tensorflow:step: 49120, lr: 0.000017, klw: 0.2294, cost: -0.2686, recon: -0.3278, kl: 0.2577, train_time_taken: 132.2939
# INFO:tensorflow:step: 49140, lr: 0.000017, klw: 0.2294, cost: -0.2377, recon: -0.2971, kl: 0.2588, train_time_taken: 135.8175
# INFO:tensorflow:step: 49160, lr: 0.000017, klw: 0.2295, cost: -0.2784, recon: -0.3375, kl: 0.2576, train_time_taken: 132.6010
# INFO:tensorflow:step: 49180, lr: 0.000017, klw: 0.2295, cost: -0.2697, recon: -0.3291, kl: 0.2585, train_time_taken: 135.5370
# INFO:tensorflow:step: 49200, lr: 0.000017, klw: 0.2295, cost: -0.2902, recon: -0.3487, kl: 0.2546, train_time_taken: 137.9370
# INFO:tensorflow:step: 49220, lr: 0.000017, klw: 0.2295, cost: -0.3233, recon: -0.3828, kl: 0.2595, train_time_taken: 139.2827
# INFO:tensorflow:step: 49240, lr: 0.000017, klw: 0.2295, cost: -0.3433, recon: -0.4031, kl: 0.2606, train_time_taken: 137.9010
# INFO:tensorflow:step: 49260, lr: 0.000017, klw: 0.2296, cost: -0.2088, recon: -0.2683, kl: 0.2593, train_time_taken: 136.3796
# INFO:tensorflow:step: 49280, lr: 0.000017, klw: 0.2296, cost: -0.2617, recon: -0.3214, kl: 0.2601, train_time_taken: 135.4970
# INFO:tensorflow:step: 49300, lr: 0.000017, klw: 0.2296, cost: -0.1778, recon: -0.2374, kl: 0.2596, train_time_taken: 134.1706
# INFO:tensorflow:step: 49320, lr: 0.000017, klw: 0.2296, cost: -0.2723, recon: -0.3321, kl: 0.2601, train_time_taken: 135.3946
# INFO:tensorflow:step: 49340, lr: 0.000017, klw: 0.2296, cost: -0.2610, recon: -0.3206, kl: 0.2597, train_time_taken: 134.2300
# INFO:tensorflow:step: 49360, lr: 0.000017, klw: 0.2297, cost: -0.2998, recon: -0.3591, kl: 0.2584, train_time_taken: 135.1178
# INFO:tensorflow:step: 49380, lr: 0.000017, klw: 0.2297, cost: -0.2281, recon: -0.2878, kl: 0.2599, train_time_taken: 131.4692
# INFO:tensorflow:step: 49400, lr: 0.000017, klw: 0.2297, cost: -0.3671, recon: -0.4269, kl: 0.2603, train_time_taken: 133.6390
# INFO:tensorflow:step: 49420, lr: 0.000017, klw: 0.2297, cost: -0.3098, recon: -0.3693, kl: 0.2594, train_time_taken: 133.5924
# INFO:tensorflow:step: 49440, lr: 0.000017, klw: 0.2297, cost: -0.2159, recon: -0.2762, kl: 0.2624, train_time_taken: 132.1489
# INFO:tensorflow:step: 49460, lr: 0.000017, klw: 0.2298, cost: -0.2796, recon: -0.3393, kl: 0.2597, train_time_taken: 134.1730
# INFO:tensorflow:step: 49480, lr: 0.000017, klw: 0.2298, cost: -0.3190, recon: -0.3786, kl: 0.2595, train_time_taken: 134.6801
# INFO:tensorflow:step: 49500, lr: 0.000017, klw: 0.2298, cost: -0.2721, recon: -0.3315, kl: 0.2586, train_time_taken: 136.4392
# INFO:tensorflow:best_valid_cost: -0.3038, valid_cost: -0.3038, valid_recon: -0.3065, valid_kl: 0.2630, valid_time_taken: 5.1516
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 49500.
# INFO:tensorflow:time_taken_save 1.2137.
# INFO:tensorflow:eval_cost: -0.3081, eval_recon: -0.3107, eval_kl: 0.2634, eval_time_taken: 5.2754
# INFO:tensorflow:step: 49520, lr: 0.000017, klw: 0.2298, cost: -0.2448, recon: -0.3040, kl: 0.2576, train_time_taken: 130.8804
# INFO:tensorflow:step: 49540, lr: 0.000017, klw: 0.2298, cost: -0.3256, recon: -0.3857, kl: 0.2612, train_time_taken: 132.2304
# INFO:tensorflow:step: 49560, lr: 0.000017, klw: 0.2299, cost: -0.2663, recon: -0.3267, kl: 0.2626, train_time_taken: 133.9192
# INFO:tensorflow:step: 49580, lr: 0.000017, klw: 0.2299, cost: -0.2487, recon: -0.3081, kl: 0.2584, train_time_taken: 133.6010
# INFO:tensorflow:step: 49600, lr: 0.000017, klw: 0.2299, cost: -0.2938, recon: -0.3539, kl: 0.2611, train_time_taken: 133.2681
# INFO:tensorflow:step: 49620, lr: 0.000017, klw: 0.2299, cost: -0.3160, recon: -0.3755, kl: 0.2590, train_time_taken: 132.4710
# INFO:tensorflow:step: 49640, lr: 0.000017, klw: 0.2299, cost: -0.2678, recon: -0.3278, kl: 0.2610, train_time_taken: 133.6139
# INFO:tensorflow:step: 49660, lr: 0.000017, klw: 0.2300, cost: -0.2628, recon: -0.3227, kl: 0.2603, train_time_taken: 130.4074
# INFO:tensorflow:step: 49680, lr: 0.000017, klw: 0.2300, cost: -0.2393, recon: -0.2989, kl: 0.2591, train_time_taken: 131.4750
# INFO:tensorflow:step: 49700, lr: 0.000017, klw: 0.2300, cost: -0.2339, recon: -0.2935, kl: 0.2593, train_time_taken: 137.0650
# INFO:tensorflow:step: 49720, lr: 0.000017, klw: 0.2300, cost: -0.1874, recon: -0.2466, kl: 0.2574, train_time_taken: 140.5466
# INFO:tensorflow:step: 49740, lr: 0.000017, klw: 0.2300, cost: -0.2713, recon: -0.3307, kl: 0.2585, train_time_taken: 143.5881
# INFO:tensorflow:step: 49760, lr: 0.000017, klw: 0.2301, cost: -0.2917, recon: -0.3510, kl: 0.2578, train_time_taken: 142.6614
# INFO:tensorflow:step: 49780, lr: 0.000017, klw: 0.2301, cost: -0.3136, recon: -0.3727, kl: 0.2568, train_time_taken: 142.2508
# INFO:tensorflow:step: 49800, lr: 0.000017, klw: 0.2301, cost: -0.2569, recon: -0.3166, kl: 0.2594, train_time_taken: 141.6079
# INFO:tensorflow:step: 49820, lr: 0.000017, klw: 0.2301, cost: -0.2967, recon: -0.3568, kl: 0.2610, train_time_taken: 141.3428
# INFO:tensorflow:step: 49840, lr: 0.000017, klw: 0.2301, cost: -0.2612, recon: -0.3202, kl: 0.2563, train_time_taken: 140.4356
# INFO:tensorflow:step: 49860, lr: 0.000017, klw: 0.2302, cost: -0.3943, recon: -0.4546, kl: 0.2619, train_time_taken: 139.0753
# INFO:tensorflow:step: 49880, lr: 0.000017, klw: 0.2302, cost: -0.2951, recon: -0.3548, kl: 0.2595, train_time_taken: 136.1494
# INFO:tensorflow:step: 49900, lr: 0.000017, klw: 0.2302, cost: -0.2139, recon: -0.2738, kl: 0.2600, train_time_taken: 134.3368
# INFO:tensorflow:step: 49920, lr: 0.000017, klw: 0.2302, cost: -0.2039, recon: -0.2635, kl: 0.2589, train_time_taken: 134.9743
# INFO:tensorflow:step: 49940, lr: 0.000017, klw: 0.2302, cost: -0.2927, recon: -0.3523, kl: 0.2590, train_time_taken: 133.6688
# INFO:tensorflow:step: 49960, lr: 0.000017, klw: 0.2303, cost: -0.2615, recon: -0.3216, kl: 0.2610, train_time_taken: 134.5943
# INFO:tensorflow:step: 49980, lr: 0.000017, klw: 0.2303, cost: -0.2553, recon: -0.3143, kl: 0.2562, train_time_taken: 135.4737
# INFO:tensorflow:step: 50000, lr: 0.000017, klw: 0.2303, cost: -0.2490, recon: -0.3081, kl: 0.2568, train_time_taken: 137.8482
# INFO:tensorflow:best_valid_cost: -0.3038, valid_cost: -0.3024, valid_recon: -0.3051, valid_kl: 0.2626, valid_time_taken: 5.2802
# INFO:tensorflow:step: 50020, lr: 0.000017, klw: 0.2303, cost: -0.3334, recon: -0.3930, kl: 0.2588, train_time_taken: 134.2165
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d77b59fb3cb1> in <module>
# ----> 1 console_entry_point()
#
# <ipython-input-1-a0ef2f6eccfb> in console_entry_point()
#     465
#     466 def console_entry_point():
# --> 467     tf.app.run(main)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/platform/app.py in run(main, argv)
#     123   # Call the main function, passing through any arguments
#     124   # to the final program.
# --> 125   _sys.exit(main(argv))
#     126
#
# <ipython-input-1-a0ef2f6eccfb> in main(unused_argv)
#     461     if FLAGS.hparams:
#     462         model_params.parse(FLAGS.hparams)
# --> 463     trainer(model_params)
#     464
#     465
#
# <ipython-input-1-a0ef2f6eccfb> in trainer(model_params)
#     453         json.dump(model_params.values(), f, indent=True)
#     454
# --> 455     train(sess, model, eval_model, train_set, valid_set, test_set)
#     456
#     457
#
# <ipython-input-1-a0ef2f6eccfb> in train(sess, model, eval_model, train_set, valid_set, test_set)
#     292             model.cost, model.r_cost, model.kl_cost, model.final_state,
#     293             model.global_step, model.train_op
# --> 294         ], feed)
#     295
#     296         if step % 20 == 0 and step > 0:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
console_entry_point()
# Out:
# INFO:tensorflow:sketch-rnn
# INFO:tensorflow:Hyperparams:
# INFO:tensorflow:decay_rate = 0.9999
# INFO:tensorflow:dec_rnn_size = 512
# INFO:tensorflow:num_mixture = 20
# INFO:tensorflow:random_scale_factor = 0.15
# INFO:tensorflow:output_dropout_prob = 0.9
# INFO:tensorflow:enc_model = layer_norm
# INFO:tensorflow:dec_model = layer_norm
# INFO:tensorflow:enc_rnn_size = 256
# INFO:tensorflow:kl_decay_rate = 0.99995
# INFO:tensorflow:z_size = 128
# INFO:tensorflow:num_steps = 75020
# INFO:tensorflow:data_set = ['aaron_sheep.npz']
# INFO:tensorflow:use_input_dropout = False
# INFO:tensorflow:recurrent_dropout_prob = 0.9
# INFO:tensorflow:batch_size = 100
# INFO:tensorflow:grad_clip = 1.0
# INFO:tensorflow:use_recurrent_dropout = True
# INFO:tensorflow:kl_weight_start = 0.01
# INFO:tensorflow:save_every = 500
# INFO:tensorflow:input_dropout_prob = 0.9
# INFO:tensorflow:kl_weight = 0.25
# INFO:tensorflow:learning_rate = 0.001
# INFO:tensorflow:conditional = True
# INFO:tensorflow:max_seq_len = 250
# INFO:tensorflow:is_training = True
# INFO:tensorflow:use_output_dropout = False
# INFO:tensorflow:kl_tolerance = 0.2
# INFO:tensorflow:augment_stroke_prob = 0.1
# INFO:tensorflow:min_learning_rate = 1e-05
# INFO:tensorflow:Loading data files.
# INFO:tensorflow:Downloading https://github.com/hardmaru/sketch-rnn-datasets/raw/master/aaron_sheep/aaron_sheep.npz
# INFO:tensorflow:Loaded 7400/300/300 from aaron_sheep.npz
# INFO:tensorflow:Dataset combined: 8000 (7400/300/300), avg len 125
# INFO:tensorflow:model_params.max_seq_len 250.
# total images <= max_seq_len is 7400
# total images <= max_seq_len is 300
# total images <= max_seq_len is 300
# INFO:tensorflow:normalizing_scale_factor 18.5198.
# INFO:tensorflow:Model using gpu.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Input dropout mode = False.
# INFO:tensorflow:Output dropout mode = False.
# INFO:tensorflow:Recurrent dropout mode = True.
# WARNING:tensorflow:From /home/jupyter/model.py:90: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/jupyter/rnn.py:288: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/jupyter/model.py:323: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/jupyter/model.py:342: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/jupyter/model.py:352: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# INFO:tensorflow:Model using gpu.
# INFO:tensorflow:Input dropout mode = 0.
# INFO:tensorflow:Output dropout mode = 0.
# INFO:tensorflow:Recurrent dropout mode = 0.
# INFO:tensorflow:Loading model log/initialp25/vector-49500.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from log/initialp25/vector-49500
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/fw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_xh:0 (5, 1024) 5120
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/W_hh:0 (256, 1024) 262144
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_gamma:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_all/ln_beta:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_gamma:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN/bw/LayerNormLSTMCell/ln_c/ln_beta:0 (256,) 256
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_mu/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_w:0 (512, 128) 65536
# INFO:tensorflow:vector_rnn/ENC_RNN_sigma/super_linear_b:0 (128,) 128
# INFO:tensorflow:vector_rnn/linear/super_linear_w:0 (128, 1024) 131072
# INFO:tensorflow:vector_rnn/linear/super_linear_b:0 (1024,) 1024
# INFO:tensorflow:vector_rnn/RNN/output_w:0 (512, 123) 62976
# INFO:tensorflow:vector_rnn/RNN/output_b:0 (123,) 123
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_xh:0 (133, 2048) 272384
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/W_hh:0 (512, 2048) 1048576
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_gamma:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_all/ln_beta:0 (2048,) 2048
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_gamma:0 (512,) 512
# INFO:tensorflow:vector_rnn/RNN/LayerNormLSTMCell/ln_c/ln_beta:0 (512,) 512
# INFO:tensorflow:Total trainable variables 2192251.
# INFO:tensorflow:step: 49520, lr: 0.000017, klw: 0.2298, cost: -0.3248, recon: -0.3846, kl: 0.2603, train_time_taken: 136.6261
# INFO:tensorflow:step: 49540, lr: 0.000017, klw: 0.2298, cost: -0.3890, recon: -0.4491, kl: 0.2612, train_time_taken: 131.4772
# INFO:tensorflow:step: 49560, lr: 0.000017, klw: 0.2299, cost: -0.2645, recon: -0.3240, kl: 0.2590, train_time_taken: 132.7877
# INFO:tensorflow:step: 49580, lr: 0.000017, klw: 0.2299, cost: -0.3083, recon: -0.3680, kl: 0.2596, train_time_taken: 132.4201
# INFO:tensorflow:step: 49600, lr: 0.000017, klw: 0.2299, cost: -0.3027, recon: -0.3624, kl: 0.2598, train_time_taken: 133.5558
# INFO:tensorflow:step: 49620, lr: 0.000017, klw: 0.2299, cost: -0.2350, recon: -0.2945, kl: 0.2584, train_time_taken: 132.9335
# INFO:tensorflow:step: 49640, lr: 0.000017, klw: 0.2299, cost: -0.2940, recon: -0.3535, kl: 0.2588, train_time_taken: 131.3811
# INFO:tensorflow:step: 49660, lr: 0.000017, klw: 0.2300, cost: -0.3024, recon: -0.3619, kl: 0.2585, train_time_taken: 132.9619
# INFO:tensorflow:step: 49680, lr: 0.000017, klw: 0.2300, cost: -0.2696, recon: -0.3288, kl: 0.2577, train_time_taken: 131.6122
# INFO:tensorflow:step: 49700, lr: 0.000017, klw: 0.2300, cost: -0.2760, recon: -0.3357, kl: 0.2596, train_time_taken: 134.7761
# INFO:tensorflow:step: 49720, lr: 0.000017, klw: 0.2300, cost: -0.2965, recon: -0.3559, kl: 0.2583, train_time_taken: 136.1960
# INFO:tensorflow:step: 49740, lr: 0.000017, klw: 0.2300, cost: -0.2997, recon: -0.3599, kl: 0.2616, train_time_taken: 136.4133
# INFO:tensorflow:step: 49760, lr: 0.000017, klw: 0.2301, cost: -0.3322, recon: -0.3923, kl: 0.2613, train_time_taken: 136.8288
# INFO:tensorflow:step: 49780, lr: 0.000017, klw: 0.2301, cost: -0.2261, recon: -0.2855, kl: 0.2578, train_time_taken: 136.9303
# INFO:tensorflow:step: 49800, lr: 0.000017, klw: 0.2301, cost: -0.3444, recon: -0.4047, kl: 0.2623, train_time_taken: 130.0805
# INFO:tensorflow:step: 49820, lr: 0.000017, klw: 0.2301, cost: -0.2695, recon: -0.3295, kl: 0.2609, train_time_taken: 131.2519
# INFO:tensorflow:step: 49840, lr: 0.000017, klw: 0.2301, cost: -0.2768, recon: -0.3372, kl: 0.2622, train_time_taken: 130.7053
# INFO:tensorflow:step: 49860, lr: 0.000017, klw: 0.2302, cost: -0.2999, recon: -0.3591, kl: 0.2569, train_time_taken: 129.9067
# INFO:tensorflow:step: 49880, lr: 0.000017, klw: 0.2302, cost: -0.2691, recon: -0.3289, kl: 0.2597, train_time_taken: 131.0772
# INFO:tensorflow:step: 49900, lr: 0.000017, klw: 0.2302, cost: -0.3284, recon: -0.3886, kl: 0.2615, train_time_taken: 129.7535
# INFO:tensorflow:step: 49920, lr: 0.000017, klw: 0.2302, cost: -0.2641, recon: -0.3240, kl: 0.2602, train_time_taken: 129.0393
# INFO:tensorflow:step: 49940, lr: 0.000017, klw: 0.2302, cost: -0.2590, recon: -0.3189, kl: 0.2601, train_time_taken: 131.1357
# INFO:tensorflow:step: 49960, lr: 0.000017, klw: 0.2303, cost: -0.3369, recon: -0.3964, kl: 0.2585, train_time_taken: 129.9147
# INFO:tensorflow:step: 49980, lr: 0.000017, klw: 0.2303, cost: -0.1909, recon: -0.2506, kl: 0.2595, train_time_taken: 133.3638
# INFO:tensorflow:step: 50000, lr: 0.000017, klw: 0.2303, cost: -0.2619, recon: -0.3218, kl: 0.2600, train_time_taken: 133.0455
# INFO:tensorflow:best_valid_cost: -0.3049, valid_cost: -0.3049, valid_recon: -0.3075, valid_kl: 0.2624, valid_time_taken: 5.9168
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 50000.
# INFO:tensorflow:time_taken_save 1.0856.
# INFO:tensorflow:eval_cost: -0.3110, eval_recon: -0.3136, eval_kl: 0.2627, eval_time_taken: 5.2116
# INFO:tensorflow:step: 50020, lr: 0.000017, klw: 0.2303, cost: -0.3986, recon: -0.4587, kl: 0.2611, train_time_taken: 135.6934
# INFO:tensorflow:step: 50040, lr: 0.000017, klw: 0.2303, cost: -0.3850, recon: -0.4454, kl: 0.2622, train_time_taken: 130.6148
# INFO:tensorflow:step: 50060, lr: 0.000017, klw: 0.2304, cost: -0.1746, recon: -0.2340, kl: 0.2575, train_time_taken: 129.8108
# INFO:tensorflow:step: 50080, lr: 0.000017, klw: 0.2304, cost: -0.2568, recon: -0.3164, kl: 0.2586, train_time_taken: 132.4943
# INFO:tensorflow:step: 50100, lr: 0.000017, klw: 0.2304, cost: -0.3389, recon: -0.3988, kl: 0.2604, train_time_taken: 129.8470
# INFO:tensorflow:step: 50120, lr: 0.000017, klw: 0.2304, cost: -0.2721, recon: -0.3320, kl: 0.2598, train_time_taken: 130.4114
# INFO:tensorflow:step: 50140, lr: 0.000017, klw: 0.2304, cost: -0.3199, recon: -0.3796, kl: 0.2589, train_time_taken: 129.5457
# INFO:tensorflow:step: 50160, lr: 0.000017, klw: 0.2305, cost: -0.2073, recon: -0.2668, kl: 0.2581, train_time_taken: 131.2555
# INFO:tensorflow:step: 50180, lr: 0.000017, klw: 0.2305, cost: -0.3007, recon: -0.3606, kl: 0.2598, train_time_taken: 129.8504
# INFO:tensorflow:step: 50200, lr: 0.000017, klw: 0.2305, cost: -0.3219, recon: -0.3813, kl: 0.2577, train_time_taken: 129.5662
# INFO:tensorflow:step: 50220, lr: 0.000017, klw: 0.2305, cost: -0.3061, recon: -0.3655, kl: 0.2576, train_time_taken: 131.2409
# INFO:tensorflow:step: 50240, lr: 0.000017, klw: 0.2305, cost: -0.2925, recon: -0.3523, kl: 0.2592, train_time_taken: 131.8207
# INFO:tensorflow:step: 50260, lr: 0.000016, klw: 0.2306, cost: -0.3735, recon: -0.4336, kl: 0.2606, train_time_taken: 136.9461
# INFO:tensorflow:step: 50280, lr: 0.000016, klw: 0.2306, cost: -0.3617, recon: -0.4217, kl: 0.2604, train_time_taken: 135.9288
# INFO:tensorflow:step: 50300, lr: 0.000016, klw: 0.2306, cost: -0.3513, recon: -0.4111, kl: 0.2596, train_time_taken: 136.4317
# INFO:tensorflow:step: 50320, lr: 0.000016, klw: 0.2306, cost: -0.2875, recon: -0.3473, kl: 0.2593, train_time_taken: 134.9126
# INFO:tensorflow:step: 50340, lr: 0.000016, klw: 0.2306, cost: -0.2800, recon: -0.3395, kl: 0.2581, train_time_taken: 130.7992
# INFO:tensorflow:step: 50360, lr: 0.000016, klw: 0.2307, cost: -0.2778, recon: -0.3376, kl: 0.2596, train_time_taken: 132.4880
# INFO:tensorflow:step: 50380, lr: 0.000016, klw: 0.2307, cost: -0.3450, recon: -0.4052, kl: 0.2610, train_time_taken: 128.8774
# INFO:tensorflow:step: 50400, lr: 0.000016, klw: 0.2307, cost: -0.3334, recon: -0.3934, kl: 0.2599, train_time_taken: 131.4123
# INFO:tensorflow:step: 50420, lr: 0.000016, klw: 0.2307, cost: -0.3154, recon: -0.3756, kl: 0.2608, train_time_taken: 130.1274
# INFO:tensorflow:step: 50440, lr: 0.000016, klw: 0.2307, cost: -0.2889, recon: -0.3488, kl: 0.2596, train_time_taken: 130.6120
# INFO:tensorflow:step: 50460, lr: 0.000016, klw: 0.2307, cost: -0.2801, recon: -0.3402, kl: 0.2605, train_time_taken: 131.2793
# INFO:tensorflow:step: 50480, lr: 0.000016, klw: 0.2308, cost: -0.3427, recon: -0.4033, kl: 0.2626, train_time_taken: 129.0812
# INFO:tensorflow:step: 50500, lr: 0.000016, klw: 0.2308, cost: -0.2542, recon: -0.3143, kl: 0.2604, train_time_taken: 131.2858
# INFO:tensorflow:best_valid_cost: -0.3075, valid_cost: -0.3075, valid_recon: -0.3101, valid_kl: 0.2629, valid_time_taken: 5.0340
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 50500.
# INFO:tensorflow:time_taken_save 0.7535.
# INFO:tensorflow:eval_cost: -0.3088, eval_recon: -0.3114, eval_kl: 0.2632, eval_time_taken: 4.9968
# INFO:tensorflow:step: 50520, lr: 0.000016, klw: 0.2308, cost: -0.2706, recon: -0.3307, kl: 0.2605, train_time_taken: 129.0730
# INFO:tensorflow:step: 50540, lr: 0.000016, klw: 0.2308, cost: -0.2791, recon: -0.3391, kl: 0.2599, train_time_taken: 136.6317
# INFO:tensorflow:step: 50560, lr: 0.000016, klw: 0.2308, cost: -0.3596, recon: -0.4189, kl: 0.2566, train_time_taken: 133.5824
# INFO:tensorflow:step: 50580, lr: 0.000016, klw: 0.2309, cost: -0.3187, recon: -0.3787, kl: 0.2600, train_time_taken: 130.3470
# INFO:tensorflow:step: 50600, lr: 0.000016, klw: 0.2309, cost: -0.2797, recon: -0.3402, kl: 0.2623, train_time_taken: 129.4737
# INFO:tensorflow:step: 50620, lr: 0.000016, klw: 0.2309, cost: -0.3113, recon: -0.3713, kl: 0.2597, train_time_taken: 128.0338
# INFO:tensorflow:step: 50640, lr: 0.000016, klw: 0.2309, cost: -0.2676, recon: -0.3271, kl: 0.2578, train_time_taken: 130.9947
# INFO:tensorflow:step: 50660, lr: 0.000016, klw: 0.2309, cost: -0.2835, recon: -0.3429, kl: 0.2571, train_time_taken: 128.7654
# INFO:tensorflow:step: 50680, lr: 0.000016, klw: 0.2310, cost: -0.2842, recon: -0.3442, kl: 0.2601, train_time_taken: 129.9000
# INFO:tensorflow:step: 50700, lr: 0.000016, klw: 0.2310, cost: -0.2031, recon: -0.2627, kl: 0.2582, train_time_taken: 130.0212
# INFO:tensorflow:step: 50720, lr: 0.000016, klw: 0.2310, cost: -0.2645, recon: -0.3244, kl: 0.2592, train_time_taken: 127.9147
# INFO:tensorflow:step: 50740, lr: 0.000016, klw: 0.2310, cost: -0.2515, recon: -0.3113, kl: 0.2589, train_time_taken: 130.6529
# INFO:tensorflow:step: 50760, lr: 0.000016, klw: 0.2310, cost: -0.2458, recon: -0.3056, kl: 0.2591, train_time_taken: 128.8704
# INFO:tensorflow:step: 50780, lr: 0.000016, klw: 0.2311, cost: -0.2722, recon: -0.3327, kl: 0.2619, train_time_taken: 133.0199
# INFO:tensorflow:step: 50800, lr: 0.000016, klw: 0.2311, cost: -0.2374, recon: -0.2970, kl: 0.2576, train_time_taken: 130.4464
# INFO:tensorflow:step: 50820, lr: 0.000016, klw: 0.2311, cost: -0.3211, recon: -0.3813, kl: 0.2607, train_time_taken: 131.7148
# INFO:tensorflow:step: 50840, lr: 0.000016, klw: 0.2311, cost: -0.3292, recon: -0.3895, kl: 0.2612, train_time_taken: 135.9419
# INFO:tensorflow:step: 50860, lr: 0.000016, klw: 0.2311, cost: -0.3696, recon: -0.4295, kl: 0.2593, train_time_taken: 134.4530
# INFO:tensorflow:step: 50880, lr: 0.000016, klw: 0.2311, cost: -0.3160, recon: -0.3765, kl: 0.2614, train_time_taken: 135.1111
# INFO:tensorflow:step: 50900, lr: 0.000016, klw: 0.2312, cost: -0.2487, recon: -0.3081, kl: 0.2567, train_time_taken: 129.6311
# INFO:tensorflow:step: 50920, lr: 0.000016, klw: 0.2312, cost: -0.2376, recon: -0.2972, kl: 0.2577, train_time_taken: 131.5850
# INFO:tensorflow:step: 50940, lr: 0.000016, klw: 0.2312, cost: -0.3068, recon: -0.3667, kl: 0.2590, train_time_taken: 128.5411
# INFO:tensorflow:step: 50960, lr: 0.000016, klw: 0.2312, cost: -0.2378, recon: -0.2975, kl: 0.2583, train_time_taken: 129.8701
# INFO:tensorflow:step: 50980, lr: 0.000016, klw: 0.2312, cost: -0.2658, recon: -0.3256, kl: 0.2584, train_time_taken: 132.2209
# INFO:tensorflow:step: 51000, lr: 0.000016, klw: 0.2313, cost: -0.2255, recon: -0.2853, kl: 0.2588, train_time_taken: 128.8244
# INFO:tensorflow:best_valid_cost: -0.3075, valid_cost: -0.3069, valid_recon: -0.3096, valid_kl: 0.2627, valid_time_taken: 4.9533
# INFO:tensorflow:step: 51020, lr: 0.000016, klw: 0.2313, cost: -0.3444, recon: -0.4047, kl: 0.2609, train_time_taken: 129.8528
# INFO:tensorflow:step: 51040, lr: 0.000016, klw: 0.2313, cost: -0.2455, recon: -0.3055, kl: 0.2594, train_time_taken: 127.8464
# INFO:tensorflow:step: 51060, lr: 0.000016, klw: 0.2313, cost: -0.3078, recon: -0.3675, kl: 0.2581, train_time_taken: 131.2932
# INFO:tensorflow:step: 51080, lr: 0.000016, klw: 0.2313, cost: -0.1907, recon: -0.2503, kl: 0.2577, train_time_taken: 131.5083
# INFO:tensorflow:step: 51100, lr: 0.000016, klw: 0.2314, cost: -0.2842, recon: -0.3450, kl: 0.2627, train_time_taken: 132.8178
# INFO:tensorflow:step: 51120, lr: 0.000016, klw: 0.2314, cost: -0.3039, recon: -0.3640, kl: 0.2600, train_time_taken: 135.9256
# INFO:tensorflow:step: 51140, lr: 0.000016, klw: 0.2314, cost: -0.2529, recon: -0.3125, kl: 0.2573, train_time_taken: 131.4866
# INFO:tensorflow:step: 51160, lr: 0.000016, klw: 0.2314, cost: -0.3576, recon: -0.4179, kl: 0.2604, train_time_taken: 130.7972
# INFO:tensorflow:step: 51180, lr: 0.000016, klw: 0.2314, cost: -0.3155, recon: -0.3761, kl: 0.2619, train_time_taken: 130.0468
# INFO:tensorflow:step: 51200, lr: 0.000016, klw: 0.2314, cost: -0.2544, recon: -0.3135, kl: 0.2556, train_time_taken: 131.2732
# INFO:tensorflow:step: 51220, lr: 0.000016, klw: 0.2315, cost: -0.2680, recon: -0.3279, kl: 0.2588, train_time_taken: 128.3484
# INFO:tensorflow:step: 51240, lr: 0.000016, klw: 0.2315, cost: -0.2707, recon: -0.3306, kl: 0.2587, train_time_taken: 129.4410
# INFO:tensorflow:step: 51260, lr: 0.000016, klw: 0.2315, cost: -0.2982, recon: -0.3576, kl: 0.2568, train_time_taken: 132.3380
# INFO:tensorflow:step: 51280, lr: 0.000016, klw: 0.2315, cost: -0.1807, recon: -0.2402, kl: 0.2570, train_time_taken: 129.5101
# INFO:tensorflow:step: 51300, lr: 0.000016, klw: 0.2315, cost: -0.3126, recon: -0.3730, kl: 0.2610, train_time_taken: 132.2171
# INFO:tensorflow:step: 51320, lr: 0.000016, klw: 0.2316, cost: -0.2826, recon: -0.3424, kl: 0.2584, train_time_taken: 130.4385
# INFO:tensorflow:step: 51340, lr: 0.000016, klw: 0.2316, cost: -0.3504, recon: -0.4105, kl: 0.2591, train_time_taken: 134.4769
# INFO:tensorflow:step: 51360, lr: 0.000016, klw: 0.2316, cost: -0.2234, recon: -0.2831, kl: 0.2576, train_time_taken: 133.2666
# INFO:tensorflow:step: 51380, lr: 0.000016, klw: 0.2316, cost: -0.2393, recon: -0.2997, kl: 0.2610, train_time_taken: 132.0677
# INFO:tensorflow:step: 51400, lr: 0.000016, klw: 0.2316, cost: -0.2682, recon: -0.3283, kl: 0.2596, train_time_taken: 131.9899
# INFO:tensorflow:step: 51420, lr: 0.000016, klw: 0.2317, cost: -0.2206, recon: -0.2806, kl: 0.2588, train_time_taken: 129.2501
# INFO:tensorflow:step: 51440, lr: 0.000016, klw: 0.2317, cost: -0.3543, recon: -0.4146, kl: 0.2600, train_time_taken: 133.4085
# INFO:tensorflow:step: 51460, lr: 0.000016, klw: 0.2317, cost: -0.2953, recon: -0.3557, kl: 0.2606, train_time_taken: 130.4556
# INFO:tensorflow:step: 51480, lr: 0.000016, klw: 0.2317, cost: -0.2455, recon: -0.3061, kl: 0.2613, train_time_taken: 131.3885
# INFO:tensorflow:step: 51500, lr: 0.000016, klw: 0.2317, cost: -0.2583, recon: -0.3183, kl: 0.2588, train_time_taken: 131.6777
# INFO:tensorflow:best_valid_cost: -0.3075, valid_cost: -0.3018, valid_recon: -0.3044, valid_kl: 0.2627, valid_time_taken: 5.0787
# INFO:tensorflow:step: 51520, lr: 0.000016, klw: 0.2317, cost: -0.2569, recon: -0.3172, kl: 0.2602, train_time_taken: 130.5353
# INFO:tensorflow:step: 51540, lr: 0.000016, klw: 0.2318, cost: -0.2337, recon: -0.2936, kl: 0.2582, train_time_taken: 131.0189
# INFO:tensorflow:step: 51560, lr: 0.000016, klw: 0.2318, cost: -0.3149, recon: -0.3750, kl: 0.2596, train_time_taken: 129.8888
# INFO:tensorflow:step: 51580, lr: 0.000016, klw: 0.2318, cost: -0.3558, recon: -0.4163, kl: 0.2608, train_time_taken: 131.7661
# INFO:tensorflow:step: 51600, lr: 0.000016, klw: 0.2318, cost: -0.3498, recon: -0.4097, kl: 0.2582, train_time_taken: 128.9010
# INFO:tensorflow:step: 51620, lr: 0.000016, klw: 0.2318, cost: -0.2655, recon: -0.3258, kl: 0.2603, train_time_taken: 131.7697
# INFO:tensorflow:step: 51640, lr: 0.000016, klw: 0.2319, cost: -0.2475, recon: -0.3074, kl: 0.2581, train_time_taken: 135.0931
# INFO:tensorflow:step: 51660, lr: 0.000016, klw: 0.2319, cost: -0.2580, recon: -0.3180, kl: 0.2591, train_time_taken: 131.6066
# INFO:tensorflow:step: 51680, lr: 0.000016, klw: 0.2319, cost: -0.3343, recon: -0.3947, kl: 0.2605, train_time_taken: 131.8444
# INFO:tensorflow:step: 51700, lr: 0.000016, klw: 0.2319, cost: -0.3005, recon: -0.3602, kl: 0.2576, train_time_taken: 131.1391
# INFO:tensorflow:step: 51720, lr: 0.000016, klw: 0.2319, cost: -0.2381, recon: -0.2979, kl: 0.2580, train_time_taken: 132.5678
# INFO:tensorflow:step: 51740, lr: 0.000016, klw: 0.2319, cost: -0.3297, recon: -0.3895, kl: 0.2578, train_time_taken: 130.6747
# INFO:tensorflow:step: 51760, lr: 0.000016, klw: 0.2320, cost: -0.2730, recon: -0.3330, kl: 0.2585, train_time_taken: 132.7917
# INFO:tensorflow:step: 51780, lr: 0.000016, klw: 0.2320, cost: -0.3630, recon: -0.4231, kl: 0.2591, train_time_taken: 134.6541
# INFO:tensorflow:step: 51800, lr: 0.000016, klw: 0.2320, cost: -0.1824, recon: -0.2426, kl: 0.2593, train_time_taken: 130.7551
# INFO:tensorflow:step: 51820, lr: 0.000016, klw: 0.2320, cost: -0.2487, recon: -0.3091, kl: 0.2602, train_time_taken: 130.2794
# INFO:tensorflow:step: 51840, lr: 0.000016, klw: 0.2320, cost: -0.3138, recon: -0.3741, kl: 0.2598, train_time_taken: 129.0378
# INFO:tensorflow:step: 51860, lr: 0.000016, klw: 0.2321, cost: -0.2621, recon: -0.3221, kl: 0.2586, train_time_taken: 132.2747
# INFO:tensorflow:step: 51880, lr: 0.000016, klw: 0.2321, cost: -0.2615, recon: -0.3212, kl: 0.2572, train_time_taken: 130.9169
# INFO:tensorflow:step: 51900, lr: 0.000016, klw: 0.2321, cost: -0.2261, recon: -0.2860, kl: 0.2583, train_time_taken: 133.5434
# INFO:tensorflow:step: 51920, lr: 0.000016, klw: 0.2321, cost: -0.3072, recon: -0.3672, kl: 0.2587, train_time_taken: 134.7497
# INFO:tensorflow:step: 51940, lr: 0.000015, klw: 0.2321, cost: -0.2191, recon: -0.2788, kl: 0.2575, train_time_taken: 135.6217
# INFO:tensorflow:step: 51960, lr: 0.000015, klw: 0.2321, cost: -0.2725, recon: -0.3329, kl: 0.2599, train_time_taken: 134.1984
# INFO:tensorflow:step: 51980, lr: 0.000015, klw: 0.2322, cost: -0.2841, recon: -0.3439, kl: 0.2577, train_time_taken: 133.4029
# INFO:tensorflow:step: 52000, lr: 0.000015, klw: 0.2322, cost: -0.2259, recon: -0.2859, kl: 0.2585, train_time_taken: 136.4503
# INFO:tensorflow:best_valid_cost: -0.3075, valid_cost: -0.3065, valid_recon: -0.3091, valid_kl: 0.2626, valid_time_taken: 5.0808
# INFO:tensorflow:step: 52020, lr: 0.000015, klw: 0.2322, cost: -0.2766, recon: -0.3369, kl: 0.2595, train_time_taken: 133.0732
# INFO:tensorflow:step: 52040, lr: 0.000015, klw: 0.2322, cost: -0.2195, recon: -0.2801, kl: 0.2610, train_time_taken: 132.1195
# INFO:tensorflow:step: 52060, lr: 0.000015, klw: 0.2322, cost: -0.3126, recon: -0.3730, kl: 0.2602, train_time_taken: 131.8664
# INFO:tensorflow:step: 52080, lr: 0.000015, klw: 0.2322, cost: -0.2192, recon: -0.2789, kl: 0.2573, train_time_taken: 129.7358
# INFO:tensorflow:step: 52100, lr: 0.000015, klw: 0.2323, cost: -0.2963, recon: -0.3564, kl: 0.2590, train_time_taken: 130.4526
# INFO:tensorflow:step: 52120, lr: 0.000015, klw: 0.2323, cost: -0.2883, recon: -0.3485, kl: 0.2591, train_time_taken: 127.6707
# INFO:tensorflow:step: 52140, lr: 0.000015, klw: 0.2323, cost: -0.3167, recon: -0.3775, kl: 0.2616, train_time_taken: 129.6395
# INFO:tensorflow:step: 52160, lr: 0.000015, klw: 0.2323, cost: -0.2318, recon: -0.2917, kl: 0.2581, train_time_taken: 131.5972
# INFO:tensorflow:step: 52180, lr: 0.000015, klw: 0.2323, cost: -0.3029, recon: -0.3627, kl: 0.2574, train_time_taken: 131.9739
# INFO:tensorflow:step: 52200, lr: 0.000015, klw: 0.2324, cost: -0.2685, recon: -0.3292, kl: 0.2613, train_time_taken: 134.3670
# INFO:tensorflow:step: 52220, lr: 0.000015, klw: 0.2324, cost: -0.2682, recon: -0.3289, kl: 0.2611, train_time_taken: 130.2437
# INFO:tensorflow:step: 52240, lr: 0.000015, klw: 0.2324, cost: -0.2989, recon: -0.3587, kl: 0.2572, train_time_taken: 130.1642
# INFO:tensorflow:step: 52260, lr: 0.000015, klw: 0.2324, cost: -0.3875, recon: -0.4490, kl: 0.2646, train_time_taken: 129.9499
# INFO:tensorflow:step: 52280, lr: 0.000015, klw: 0.2324, cost: -0.3055, recon: -0.3659, kl: 0.2596, train_time_taken: 129.1738
# INFO:tensorflow:step: 52300, lr: 0.000015, klw: 0.2324, cost: -0.2106, recon: -0.2710, kl: 0.2599, train_time_taken: 130.5396
# INFO:tensorflow:step: 52320, lr: 0.000015, klw: 0.2325, cost: -0.3116, recon: -0.3715, kl: 0.2579, train_time_taken: 130.0818
# INFO:tensorflow:step: 52340, lr: 0.000015, klw: 0.2325, cost: -0.2865, recon: -0.3469, kl: 0.2596, train_time_taken: 130.4768
# INFO:tensorflow:step: 52360, lr: 0.000015, klw: 0.2325, cost: -0.2625, recon: -0.3227, kl: 0.2589, train_time_taken: 128.5681
# INFO:tensorflow:step: 52380, lr: 0.000015, klw: 0.2325, cost: -0.2333, recon: -0.2926, kl: 0.2552, train_time_taken: 129.8991
# INFO:tensorflow:step: 52400, lr: 0.000015, klw: 0.2325, cost: -0.2820, recon: -0.3422, kl: 0.2591, train_time_taken: 129.7105
# INFO:tensorflow:step: 52420, lr: 0.000015, klw: 0.2325, cost: -0.3379, recon: -0.3984, kl: 0.2603, train_time_taken: 130.9175
# INFO:tensorflow:step: 52440, lr: 0.000015, klw: 0.2326, cost: -0.2379, recon: -0.2984, kl: 0.2598, train_time_taken: 131.4493
# INFO:tensorflow:step: 52460, lr: 0.000015, klw: 0.2326, cost: -0.3342, recon: -0.3943, kl: 0.2584, train_time_taken: 135.9574
# INFO:tensorflow:step: 52480, lr: 0.000015, klw: 0.2326, cost: -0.3346, recon: -0.3952, kl: 0.2605, train_time_taken: 137.1067
# INFO:tensorflow:step: 52500, lr: 0.000015, klw: 0.2326, cost: -0.3172, recon: -0.3775, kl: 0.2592, train_time_taken: 137.2493
# INFO:tensorflow:best_valid_cost: -0.3096, valid_cost: -0.3096, valid_recon: -0.3122, valid_kl: 0.2622, valid_time_taken: 5.3467
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 52500.
# INFO:tensorflow:time_taken_save 0.8041.
# INFO:tensorflow:eval_cost: -0.3137, eval_recon: -0.3163, eval_kl: 0.2625, eval_time_taken: 5.2682
# INFO:tensorflow:step: 52520, lr: 0.000015, klw: 0.2326, cost: -0.2906, recon: -0.3505, kl: 0.2575, train_time_taken: 135.1805
# INFO:tensorflow:step: 52540, lr: 0.000015, klw: 0.2327, cost: -0.3382, recon: -0.3995, kl: 0.2634, train_time_taken: 132.6555
# INFO:tensorflow:step: 52560, lr: 0.000015, klw: 0.2327, cost: -0.3350, recon: -0.3959, kl: 0.2615, train_time_taken: 133.6009
# INFO:tensorflow:step: 52580, lr: 0.000015, klw: 0.2327, cost: -0.2972, recon: -0.3575, kl: 0.2590, train_time_taken: 135.5532
# INFO:tensorflow:step: 52600, lr: 0.000015, klw: 0.2327, cost: -0.3233, recon: -0.3837, kl: 0.2593, train_time_taken: 134.8482
# INFO:tensorflow:step: 52620, lr: 0.000015, klw: 0.2327, cost: -0.2791, recon: -0.3390, kl: 0.2575, train_time_taken: 134.0991
# INFO:tensorflow:step: 52640, lr: 0.000015, klw: 0.2327, cost: -0.2572, recon: -0.3175, kl: 0.2592, train_time_taken: 132.6803
# INFO:tensorflow:step: 52660, lr: 0.000015, klw: 0.2328, cost: -0.3708, recon: -0.4313, kl: 0.2599, train_time_taken: 134.5172
# INFO:tensorflow:step: 52680, lr: 0.000015, klw: 0.2328, cost: -0.2972, recon: -0.3573, kl: 0.2581, train_time_taken: 133.5768
# INFO:tensorflow:step: 52700, lr: 0.000015, klw: 0.2328, cost: -0.2489, recon: -0.3087, kl: 0.2569, train_time_taken: 134.3623
# INFO:tensorflow:step: 52720, lr: 0.000015, klw: 0.2328, cost: -0.2914, recon: -0.3517, kl: 0.2593, train_time_taken: 138.5637
# INFO:tensorflow:step: 52740, lr: 0.000015, klw: 0.2328, cost: -0.2671, recon: -0.3270, kl: 0.2572, train_time_taken: 135.4070
# INFO:tensorflow:step: 52760, lr: 0.000015, klw: 0.2328, cost: -0.1998, recon: -0.2602, kl: 0.2596, train_time_taken: 137.1851
# INFO:tensorflow:step: 52780, lr: 0.000015, klw: 0.2329, cost: -0.2592, recon: -0.3194, kl: 0.2585, train_time_taken: 132.0097
# INFO:tensorflow:step: 52800, lr: 0.000015, klw: 0.2329, cost: -0.3439, recon: -0.4035, kl: 0.2560, train_time_taken: 133.1124
# INFO:tensorflow:step: 52820, lr: 0.000015, klw: 0.2329, cost: -0.2765, recon: -0.3364, kl: 0.2573, train_time_taken: 130.2624
# INFO:tensorflow:step: 52840, lr: 0.000015, klw: 0.2329, cost: -0.3093, recon: -0.3692, kl: 0.2576, train_time_taken: 129.6530
# INFO:tensorflow:step: 52860, lr: 0.000015, klw: 0.2329, cost: -0.3197, recon: -0.3799, kl: 0.2585, train_time_taken: 131.9053
# INFO:tensorflow:step: 52880, lr: 0.000015, klw: 0.2329, cost: -0.2661, recon: -0.3267, kl: 0.2603, train_time_taken: 131.1501
# INFO:tensorflow:step: 52900, lr: 0.000015, klw: 0.2330, cost: -0.2239, recon: -0.2835, kl: 0.2561, train_time_taken: 129.6204
# INFO:tensorflow:step: 52920, lr: 0.000015, klw: 0.2330, cost: -0.3075, recon: -0.3678, kl: 0.2587, train_time_taken: 129.2291
# INFO:tensorflow:step: 52940, lr: 0.000015, klw: 0.2330, cost: -0.3355, recon: -0.3958, kl: 0.2588, train_time_taken: 129.7836
# INFO:tensorflow:step: 52960, lr: 0.000015, klw: 0.2330, cost: -0.2900, recon: -0.3500, kl: 0.2573, train_time_taken: 132.9405
# INFO:tensorflow:step: 52980, lr: 0.000015, klw: 0.2330, cost: -0.2777, recon: -0.3377, kl: 0.2573, train_time_taken: 133.5498
# INFO:tensorflow:step: 53000, lr: 0.000015, klw: 0.2330, cost: -0.2875, recon: -0.3477, kl: 0.2585, train_time_taken: 136.6002
# INFO:tensorflow:best_valid_cost: -0.3104, valid_cost: -0.3104, valid_recon: -0.3130, valid_kl: 0.2624, valid_time_taken: 5.1162
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 53000.
# INFO:tensorflow:time_taken_save 0.8031.
# INFO:tensorflow:eval_cost: -0.3117, eval_recon: -0.3143, eval_kl: 0.2627, eval_time_taken: 5.1957
# INFO:tensorflow:step: 53020, lr: 0.000015, klw: 0.2331, cost: -0.3049, recon: -0.3650, kl: 0.2580, train_time_taken: 135.0975
# INFO:tensorflow:step: 53040, lr: 0.000015, klw: 0.2331, cost: -0.3673, recon: -0.4280, kl: 0.2602, train_time_taken: 138.9883
# INFO:tensorflow:step: 53060, lr: 0.000015, klw: 0.2331, cost: -0.3085, recon: -0.3693, kl: 0.2608, train_time_taken: 137.1982
# INFO:tensorflow:step: 53080, lr: 0.000015, klw: 0.2331, cost: -0.3128, recon: -0.3736, kl: 0.2609, train_time_taken: 137.9414
# INFO:tensorflow:step: 53100, lr: 0.000015, klw: 0.2331, cost: -0.3069, recon: -0.3674, kl: 0.2593, train_time_taken: 136.4350
# INFO:tensorflow:step: 53120, lr: 0.000015, klw: 0.2331, cost: -0.3074, recon: -0.3677, kl: 0.2584, train_time_taken: 135.8335
# INFO:tensorflow:step: 53140, lr: 0.000015, klw: 0.2332, cost: -0.2649, recon: -0.3253, kl: 0.2590, train_time_taken: 130.9170
# INFO:tensorflow:step: 53160, lr: 0.000015, klw: 0.2332, cost: -0.3659, recon: -0.4265, kl: 0.2600, train_time_taken: 130.9771
# INFO:tensorflow:step: 53180, lr: 0.000015, klw: 0.2332, cost: -0.2200, recon: -0.2802, kl: 0.2582, train_time_taken: 130.7150
# INFO:tensorflow:step: 53200, lr: 0.000015, klw: 0.2332, cost: -0.2925, recon: -0.3533, kl: 0.2603, train_time_taken: 129.4524
# INFO:tensorflow:step: 53220, lr: 0.000015, klw: 0.2332, cost: -0.3299, recon: -0.3905, kl: 0.2599, train_time_taken: 132.0396
# INFO:tensorflow:step: 53240, lr: 0.000015, klw: 0.2332, cost: -0.3557, recon: -0.4160, kl: 0.2587, train_time_taken: 129.6416
# INFO:tensorflow:step: 53260, lr: 0.000015, klw: 0.2333, cost: -0.2356, recon: -0.2959, kl: 0.2584, train_time_taken: 135.1767
# INFO:tensorflow:step: 53280, lr: 0.000015, klw: 0.2333, cost: -0.3393, recon: -0.3998, kl: 0.2595, train_time_taken: 136.5356
# INFO:tensorflow:step: 53300, lr: 0.000015, klw: 0.2333, cost: -0.3441, recon: -0.4047, kl: 0.2597, train_time_taken: 130.6611
# INFO:tensorflow:step: 53320, lr: 0.000015, klw: 0.2333, cost: -0.3004, recon: -0.3605, kl: 0.2575, train_time_taken: 131.1019
# INFO:tensorflow:step: 53340, lr: 0.000015, klw: 0.2333, cost: -0.2188, recon: -0.2792, kl: 0.2591, train_time_taken: 127.0400
# INFO:tensorflow:step: 53360, lr: 0.000015, klw: 0.2333, cost: -0.2576, recon: -0.3179, kl: 0.2585, train_time_taken: 130.8927
# INFO:tensorflow:step: 53380, lr: 0.000015, klw: 0.2334, cost: -0.2382, recon: -0.2989, kl: 0.2598, train_time_taken: 128.5727
# INFO:tensorflow:step: 53400, lr: 0.000015, klw: 0.2334, cost: -0.3582, recon: -0.4185, kl: 0.2584, train_time_taken: 128.3152
# INFO:tensorflow:step: 53420, lr: 0.000015, klw: 0.2334, cost: -0.2345, recon: -0.2951, kl: 0.2600, train_time_taken: 131.8856
# INFO:tensorflow:step: 53440, lr: 0.000015, klw: 0.2334, cost: -0.2594, recon: -0.3199, kl: 0.2592, train_time_taken: 128.6390
# INFO:tensorflow:step: 53460, lr: 0.000015, klw: 0.2334, cost: -0.2571, recon: -0.3168, kl: 0.2559, train_time_taken: 129.9677
# INFO:tensorflow:step: 53480, lr: 0.000015, klw: 0.2334, cost: -0.2461, recon: -0.3065, kl: 0.2586, train_time_taken: 128.5013
# INFO:tensorflow:step: 53500, lr: 0.000015, klw: 0.2335, cost: -0.4159, recon: -0.4766, kl: 0.2602, train_time_taken: 131.4365
# INFO:tensorflow:best_valid_cost: -0.3104, valid_cost: -0.3077, valid_recon: -0.3104, valid_kl: 0.2626, valid_time_taken: 5.7164
# INFO:tensorflow:step: 53520, lr: 0.000015, klw: 0.2335, cost: -0.2381, recon: -0.2987, kl: 0.2594, train_time_taken: 132.5738
# INFO:tensorflow:step: 53540, lr: 0.000015, klw: 0.2335, cost: -0.3263, recon: -0.3877, kl: 0.2630, train_time_taken: 134.6393
# INFO:tensorflow:step: 53560, lr: 0.000015, klw: 0.2335, cost: -0.2729, recon: -0.3328, kl: 0.2568, train_time_taken: 136.4135
# INFO:tensorflow:step: 53580, lr: 0.000015, klw: 0.2335, cost: -0.2347, recon: -0.2951, kl: 0.2586, train_time_taken: 134.5264
# INFO:tensorflow:step: 53600, lr: 0.000015, klw: 0.2335, cost: -0.2998, recon: -0.3604, kl: 0.2595, train_time_taken: 135.3135
# INFO:tensorflow:step: 53620, lr: 0.000015, klw: 0.2336, cost: -0.3603, recon: -0.4212, kl: 0.2608, train_time_taken: 134.7041
# INFO:tensorflow:step: 53640, lr: 0.000015, klw: 0.2336, cost: -0.2497, recon: -0.3102, kl: 0.2591, train_time_taken: 134.7055
# INFO:tensorflow:step: 53660, lr: 0.000015, klw: 0.2336, cost: -0.3661, recon: -0.4271, kl: 0.2612, train_time_taken: 134.1889
# INFO:tensorflow:step: 53680, lr: 0.000015, klw: 0.2336, cost: -0.2846, recon: -0.3450, kl: 0.2585, train_time_taken: 129.3127
# INFO:tensorflow:step: 53700, lr: 0.000015, klw: 0.2336, cost: -0.3055, recon: -0.3664, kl: 0.2606, train_time_taken: 132.6284
# INFO:tensorflow:step: 53720, lr: 0.000015, klw: 0.2336, cost: -0.3509, recon: -0.4113, kl: 0.2586, train_time_taken: 128.4226
# INFO:tensorflow:step: 53740, lr: 0.000015, klw: 0.2337, cost: -0.3172, recon: -0.3776, kl: 0.2584, train_time_taken: 130.8326
# INFO:tensorflow:step: 53760, lr: 0.000015, klw: 0.2337, cost: -0.2926, recon: -0.3529, kl: 0.2581, train_time_taken: 128.9903
# INFO:tensorflow:step: 53780, lr: 0.000015, klw: 0.2337, cost: -0.3181, recon: -0.3792, kl: 0.2615, train_time_taken: 129.1599
# INFO:tensorflow:step: 53800, lr: 0.000015, klw: 0.2337, cost: -0.2504, recon: -0.3105, kl: 0.2571, train_time_taken: 134.2674
# INFO:tensorflow:step: 53820, lr: 0.000015, klw: 0.2337, cost: -0.3263, recon: -0.3867, kl: 0.2584, train_time_taken: 132.1598
# INFO:tensorflow:step: 53840, lr: 0.000015, klw: 0.2337, cost: -0.2867, recon: -0.3474, kl: 0.2596, train_time_taken: 132.5880
# INFO:tensorflow:step: 53860, lr: 0.000015, klw: 0.2338, cost: -0.3223, recon: -0.3827, kl: 0.2584, train_time_taken: 129.3065
# INFO:tensorflow:step: 53880, lr: 0.000015, klw: 0.2338, cost: -0.3041, recon: -0.3644, kl: 0.2579, train_time_taken: 130.7933
# INFO:tensorflow:step: 53900, lr: 0.000015, klw: 0.2338, cost: -0.2709, recon: -0.3315, kl: 0.2594, train_time_taken: 128.6497
# INFO:tensorflow:step: 53920, lr: 0.000015, klw: 0.2338, cost: -0.2897, recon: -0.3499, kl: 0.2572, train_time_taken: 128.7485
# INFO:tensorflow:step: 53940, lr: 0.000014, klw: 0.2338, cost: -0.2471, recon: -0.3073, kl: 0.2573, train_time_taken: 131.1303
# INFO:tensorflow:step: 53960, lr: 0.000014, klw: 0.2338, cost: -0.2560, recon: -0.3167, kl: 0.2599, train_time_taken: 128.8949
# INFO:tensorflow:step: 53980, lr: 0.000014, klw: 0.2339, cost: -0.3080, recon: -0.3689, kl: 0.2604, train_time_taken: 131.6083
# INFO:tensorflow:step: 54000, lr: 0.000014, klw: 0.2339, cost: -0.2649, recon: -0.3250, kl: 0.2570, train_time_taken: 128.9522
# INFO:tensorflow:best_valid_cost: -0.3123, valid_cost: -0.3123, valid_recon: -0.3149, valid_kl: 0.2623, valid_time_taken: 4.8819
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 54000.
# INFO:tensorflow:time_taken_save 0.7790.
# INFO:tensorflow:eval_cost: -0.3190, eval_recon: -0.3217, eval_kl: 0.2626, eval_time_taken: 4.8433
# INFO:tensorflow:step: 54020, lr: 0.000014, klw: 0.2339, cost: -0.2742, recon: -0.3346, kl: 0.2585, train_time_taken: 131.1885
# INFO:tensorflow:step: 54040, lr: 0.000014, klw: 0.2339, cost: -0.3165, recon: -0.3774, kl: 0.2604, train_time_taken: 128.8713
# INFO:tensorflow:step: 54060, lr: 0.000014, klw: 0.2339, cost: -0.2469, recon: -0.3078, kl: 0.2602, train_time_taken: 129.2197
# INFO:tensorflow:step: 54080, lr: 0.000014, klw: 0.2339, cost: -0.2873, recon: -0.3479, kl: 0.2589, train_time_taken: 137.1414
# INFO:tensorflow:step: 54100, lr: 0.000014, klw: 0.2340, cost: -0.2788, recon: -0.3385, kl: 0.2553, train_time_taken: 135.7696
# INFO:tensorflow:step: 54120, lr: 0.000014, klw: 0.2340, cost: -0.2017, recon: -0.2624, kl: 0.2593, train_time_taken: 137.4258
# INFO:tensorflow:step: 54140, lr: 0.000014, klw: 0.2340, cost: -0.2065, recon: -0.2672, kl: 0.2595, train_time_taken: 135.0359
# INFO:tensorflow:step: 54160, lr: 0.000014, klw: 0.2340, cost: -0.2929, recon: -0.3537, kl: 0.2597, train_time_taken: 136.9463
# INFO:tensorflow:step: 54180, lr: 0.000014, klw: 0.2340, cost: -0.3540, recon: -0.4154, kl: 0.2622, train_time_taken: 133.7747
# INFO:tensorflow:step: 54200, lr: 0.000014, klw: 0.2340, cost: -0.2539, recon: -0.3138, kl: 0.2559, train_time_taken: 136.4985
# INFO:tensorflow:step: 54220, lr: 0.000014, klw: 0.2340, cost: -0.3973, recon: -0.4580, kl: 0.2595, train_time_taken: 136.3501
# INFO:tensorflow:step: 54240, lr: 0.000014, klw: 0.2341, cost: -0.2932, recon: -0.3541, kl: 0.2602, train_time_taken: 136.5020
# INFO:tensorflow:step: 54260, lr: 0.000014, klw: 0.2341, cost: -0.2993, recon: -0.3597, kl: 0.2579, train_time_taken: 140.0987
# INFO:tensorflow:step: 54280, lr: 0.000014, klw: 0.2341, cost: -0.3668, recon: -0.4274, kl: 0.2589, train_time_taken: 135.6668
# INFO:tensorflow:step: 54300, lr: 0.000014, klw: 0.2341, cost: -0.2386, recon: -0.2992, kl: 0.2589, train_time_taken: 138.0004
# INFO:tensorflow:step: 54320, lr: 0.000014, klw: 0.2341, cost: -0.3225, recon: -0.3831, kl: 0.2586, train_time_taken: 135.1708
# INFO:tensorflow:step: 54340, lr: 0.000014, klw: 0.2341, cost: -0.3132, recon: -0.3737, kl: 0.2584, train_time_taken: 139.2544
# INFO:tensorflow:step: 54360, lr: 0.000014, klw: 0.2342, cost: -0.2991, recon: -0.3601, kl: 0.2608, train_time_taken: 136.5912
# INFO:tensorflow:step: 54380, lr: 0.000014, klw: 0.2342, cost: -0.2305, recon: -0.2914, kl: 0.2601, train_time_taken: 134.8815
# INFO:tensorflow:step: 54400, lr: 0.000014, klw: 0.2342, cost: -0.3178, recon: -0.3786, kl: 0.2596, train_time_taken: 135.0923
# INFO:tensorflow:step: 54420, lr: 0.000014, klw: 0.2342, cost: -0.3694, recon: -0.4306, kl: 0.2613, train_time_taken: 134.4786
# INFO:tensorflow:step: 54440, lr: 0.000014, klw: 0.2342, cost: -0.2129, recon: -0.2730, kl: 0.2568, train_time_taken: 136.7036
# INFO:tensorflow:step: 54460, lr: 0.000014, klw: 0.2342, cost: -0.2729, recon: -0.3338, kl: 0.2599, train_time_taken: 132.8982
# INFO:tensorflow:step: 54480, lr: 0.000014, klw: 0.2343, cost: -0.2321, recon: -0.2920, kl: 0.2555, train_time_taken: 134.3239
# INFO:tensorflow:step: 54500, lr: 0.000014, klw: 0.2343, cost: -0.3087, recon: -0.3697, kl: 0.2604, train_time_taken: 130.1120
# INFO:tensorflow:best_valid_cost: -0.3154, valid_cost: -0.3154, valid_recon: -0.3180, valid_kl: 0.2624, valid_time_taken: 5.0838
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 54500.
# INFO:tensorflow:time_taken_save 0.7895.
# INFO:tensorflow:eval_cost: -0.3206, eval_recon: -0.3232, eval_kl: 0.2627, eval_time_taken: 5.0378
# INFO:tensorflow:step: 54520, lr: 0.000014, klw: 0.2343, cost: -0.3842, recon: -0.4453, kl: 0.2605, train_time_taken: 130.4764
# INFO:tensorflow:step: 54540, lr: 0.000014, klw: 0.2343, cost: -0.2982, recon: -0.3587, kl: 0.2583, train_time_taken: 131.3927
# INFO:tensorflow:step: 54560, lr: 0.000014, klw: 0.2343, cost: -0.2564, recon: -0.3173, kl: 0.2597, train_time_taken: 129.7446
# INFO:tensorflow:step: 54580, lr: 0.000014, klw: 0.2343, cost: -0.3107, recon: -0.3717, kl: 0.2604, train_time_taken: 132.7138
# INFO:tensorflow:step: 54600, lr: 0.000014, klw: 0.2343, cost: -0.2825, recon: -0.3436, kl: 0.2608, train_time_taken: 132.5016
# INFO:tensorflow:step: 54620, lr: 0.000014, klw: 0.2344, cost: -0.2653, recon: -0.3259, kl: 0.2586, train_time_taken: 135.2471
# INFO:tensorflow:step: 54640, lr: 0.000014, klw: 0.2344, cost: -0.3668, recon: -0.4271, kl: 0.2571, train_time_taken: 133.5822
# INFO:tensorflow:step: 54660, lr: 0.000014, klw: 0.2344, cost: -0.3939, recon: -0.4549, kl: 0.2603, train_time_taken: 134.2525
# INFO:tensorflow:step: 54680, lr: 0.000014, klw: 0.2344, cost: -0.2691, recon: -0.3295, kl: 0.2576, train_time_taken: 133.3070
# INFO:tensorflow:step: 54700, lr: 0.000014, klw: 0.2344, cost: -0.2571, recon: -0.3179, kl: 0.2594, train_time_taken: 131.0865
# INFO:tensorflow:step: 54720, lr: 0.000014, klw: 0.2344, cost: -0.1840, recon: -0.2452, kl: 0.2609, train_time_taken: 132.7946
# INFO:tensorflow:step: 54740, lr: 0.000014, klw: 0.2345, cost: -0.2716, recon: -0.3318, kl: 0.2566, train_time_taken: 129.7403
# INFO:tensorflow:step: 54760, lr: 0.000014, klw: 0.2345, cost: -0.3021, recon: -0.3630, kl: 0.2597, train_time_taken: 131.5432
# INFO:tensorflow:step: 54780, lr: 0.000014, klw: 0.2345, cost: -0.2728, recon: -0.3335, kl: 0.2590, train_time_taken: 134.5784
# INFO:tensorflow:step: 54800, lr: 0.000014, klw: 0.2345, cost: -0.3082, recon: -0.3695, kl: 0.2614, train_time_taken: 130.8939
# INFO:tensorflow:step: 54820, lr: 0.000014, klw: 0.2345, cost: -0.2832, recon: -0.3443, kl: 0.2603, train_time_taken: 129.2937
# INFO:tensorflow:step: 54840, lr: 0.000014, klw: 0.2345, cost: -0.2312, recon: -0.2919, kl: 0.2591, train_time_taken: 128.1709
# INFO:tensorflow:step: 54860, lr: 0.000014, klw: 0.2346, cost: -0.3525, recon: -0.4142, kl: 0.2628, train_time_taken: 130.0925
# INFO:tensorflow:step: 54880, lr: 0.000014, klw: 0.2346, cost: -0.2315, recon: -0.2916, kl: 0.2565, train_time_taken: 133.1329
# INFO:tensorflow:step: 54900, lr: 0.000014, klw: 0.2346, cost: -0.3084, recon: -0.3700, kl: 0.2624, train_time_taken: 135.7525
# INFO:tensorflow:step: 54920, lr: 0.000014, klw: 0.2346, cost: -0.2803, recon: -0.3408, kl: 0.2578, train_time_taken: 132.5722
# INFO:tensorflow:step: 54940, lr: 0.000014, klw: 0.2346, cost: -0.2086, recon: -0.2690, kl: 0.2576, train_time_taken: 131.8184
# INFO:tensorflow:step: 54960, lr: 0.000014, klw: 0.2346, cost: -0.2820, recon: -0.3429, kl: 0.2593, train_time_taken: 130.2527
# INFO:tensorflow:step: 54980, lr: 0.000014, klw: 0.2346, cost: -0.3205, recon: -0.3813, kl: 0.2591, train_time_taken: 128.3400
# INFO:tensorflow:step: 55000, lr: 0.000014, klw: 0.2347, cost: -0.2431, recon: -0.3038, kl: 0.2586, train_time_taken: 130.0734
# INFO:tensorflow:best_valid_cost: -0.3173, valid_cost: -0.3173, valid_recon: -0.3199, valid_kl: 0.2626, valid_time_taken: 4.9092
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 55000.
# INFO:tensorflow:time_taken_save 0.8017.
# INFO:tensorflow:eval_cost: -0.3180, eval_recon: -0.3206, eval_kl: 0.2629, eval_time_taken: 4.9486
# INFO:tensorflow:step: 55020, lr: 0.000014, klw: 0.2347, cost: -0.3546, recon: -0.4154, kl: 0.2593, train_time_taken: 128.1456
# INFO:tensorflow:step: 55040, lr: 0.000014, klw: 0.2347, cost: -0.2751, recon: -0.3363, kl: 0.2608, train_time_taken: 128.8924
# INFO:tensorflow:step: 55060, lr: 0.000014, klw: 0.2347, cost: -0.2593, recon: -0.3195, kl: 0.2566, train_time_taken: 129.4927
# INFO:tensorflow:step: 55080, lr: 0.000014, klw: 0.2347, cost: -0.2876, recon: -0.3489, kl: 0.2615, train_time_taken: 128.4794
# INFO:tensorflow:step: 55100, lr: 0.000014, klw: 0.2347, cost: -0.3068, recon: -0.3673, kl: 0.2579, train_time_taken: 130.3850
# INFO:tensorflow:step: 55120, lr: 0.000014, klw: 0.2348, cost: -0.3035, recon: -0.3647, kl: 0.2606, train_time_taken: 129.1033
# INFO:tensorflow:step: 55140, lr: 0.000014, klw: 0.2348, cost: -0.2745, recon: -0.3354, kl: 0.2592, train_time_taken: 130.7455
# INFO:tensorflow:step: 55160, lr: 0.000014, klw: 0.2348, cost: -0.2642, recon: -0.3251, kl: 0.2593, train_time_taken: 131.8382
# INFO:tensorflow:step: 55180, lr: 0.000014, klw: 0.2348, cost: -0.3011, recon: -0.3625, kl: 0.2612, train_time_taken: 135.9862
# INFO:tensorflow:step: 55200, lr: 0.000014, klw: 0.2348, cost: -0.2933, recon: -0.3536, kl: 0.2570, train_time_taken: 134.8869
# INFO:tensorflow:step: 55220, lr: 0.000014, klw: 0.2348, cost: -0.2858, recon: -0.3470, kl: 0.2606, train_time_taken: 134.2006
# INFO:tensorflow:step: 55240, lr: 0.000014, klw: 0.2348, cost: -0.2292, recon: -0.2897, kl: 0.2577, train_time_taken: 135.5924
# INFO:tensorflow:step: 55260, lr: 0.000014, klw: 0.2349, cost: -0.4026, recon: -0.4635, kl: 0.2593, train_time_taken: 134.1964
# INFO:tensorflow:step: 55280, lr: 0.000014, klw: 0.2349, cost: -0.2389, recon: -0.2999, kl: 0.2599, train_time_taken: 137.5443
# INFO:tensorflow:step: 55300, lr: 0.000014, klw: 0.2349, cost: -0.2725, recon: -0.3335, kl: 0.2598, train_time_taken: 130.5413
# INFO:tensorflow:step: 55320, lr: 0.000014, klw: 0.2349, cost: -0.3008, recon: -0.3618, kl: 0.2599, train_time_taken: 130.3868
# INFO:tensorflow:step: 55340, lr: 0.000014, klw: 0.2349, cost: -0.3635, recon: -0.4243, kl: 0.2590, train_time_taken: 131.4063
# INFO:tensorflow:step: 55360, lr: 0.000014, klw: 0.2349, cost: -0.2538, recon: -0.3134, kl: 0.2540, train_time_taken: 129.8658
# INFO:tensorflow:step: 55380, lr: 0.000014, klw: 0.2349, cost: -0.3148, recon: -0.3751, kl: 0.2566, train_time_taken: 128.7972
# INFO:tensorflow:step: 55400, lr: 0.000014, klw: 0.2350, cost: -0.2258, recon: -0.2865, kl: 0.2582, train_time_taken: 128.1564
# INFO:tensorflow:step: 55420, lr: 0.000014, klw: 0.2350, cost: -0.2233, recon: -0.2839, kl: 0.2581, train_time_taken: 130.1808
# INFO:tensorflow:step: 55440, lr: 0.000014, klw: 0.2350, cost: -0.3549, recon: -0.4163, kl: 0.2614, train_time_taken: 132.0052
# INFO:tensorflow:step: 55460, lr: 0.000014, klw: 0.2350, cost: -0.2874, recon: -0.3484, kl: 0.2594, train_time_taken: 133.8365
# INFO:tensorflow:step: 55480, lr: 0.000014, klw: 0.2350, cost: -0.2828, recon: -0.3435, kl: 0.2585, train_time_taken: 130.7500
# INFO:tensorflow:step: 55500, lr: 0.000014, klw: 0.2350, cost: -0.2993, recon: -0.3602, kl: 0.2589, train_time_taken: 128.8707
# INFO:tensorflow:best_valid_cost: -0.3193, valid_cost: -0.3193, valid_recon: -0.3219, valid_kl: 0.2622, valid_time_taken: 5.0468
# INFO:tensorflow:saving model log/initialp25/vector.
# INFO:tensorflow:global_step 55500.
# INFO:tensorflow:time_taken_save 0.8201.
# INFO:tensorflow:eval_cost: -0.3222, eval_recon: -0.3249, eval_kl: 0.2625, eval_time_taken: 5.0105
# INFO:tensorflow:step: 55520, lr: 0.000014, klw: 0.2351, cost: -0.2947, recon: -0.3560, kl: 0.2610, train_time_taken: 130.8495
# ...
# INFO:tensorflow:step: 73220, lr: 0.000011, klw: 0.2438, cost: -0.3057, recon: -0.3685, kl: 0.2575, train_time_taken: 136.8715
# INFO:tensorflow:step: 73240, lr: 0.000011, klw: 0.2438, cost: -0.2762, recon: -0.3377, kl: 0.2521, train_time_taken: 140.1519
# INFO:tensorflow:step: 73260, lr: 0.000011, klw: 0.2438, cost: -0.2980, recon: -0.3603, kl: 0.2554, train_time_taken: 137.9590
# INFO:tensorflow:step: 73280, lr: 0.000011, klw: 0.2438, cost: -0.2892, recon: -0.3524, kl: 0.2592, train_time_taken: 139.0433
# INFO:tensorflow:step: 73300, lr: 0.000011, klw: 0.2439, cost: -0.2946, recon: -0.3569, kl: 0.2553, train_time_taken: 139.2023
# INFO:tensorflow:step: 73320, lr: 0.000011, klw: 0.2439, cost: -0.2286, recon: -0.2906, kl: 0.2545, train_time_taken: 139.8174
# INFO:tensorflow:step: 73340, lr: 0.000011, klw: 0.2439, cost: -0.2808, recon: -0.3427, kl: 0.2539, train_time_taken: 141.1785
# INFO:tensorflow:step: 73360, lr: 0.000011, klw: 0.2439, cost: -0.2975, recon: -0.3609, kl: 0.2598, train_time_taken: 137.6772
# INFO:tensorflow:step: 73380, lr: 0.000011, klw: 0.2439, cost: -0.2820, recon: -0.3443, kl: 0.2555, train_time_taken: 141.8595
# INFO:tensorflow:step: 73400, lr: 0.000011, klw: 0.2439, cost: -0.2299, recon: -0.2922, kl: 0.2556, train_time_taken: 137.8645
# INFO:tensorflow:step: 73420, lr: 0.000011, klw: 0.2439, cost: -0.2481, recon: -0.3103, kl: 0.2552, train_time_taken: 140.9774
# INFO:tensorflow:step: 73440, lr: 0.000011, klw: 0.2439, cost: -0.2902, recon: -0.3523, kl: 0.2545, train_time_taken: 136.4436
# INFO:tensorflow:step: 73460, lr: 0.000011, klw: 0.2439, cost: -0.3573, recon: -0.4202, kl: 0.2578, train_time_taken: 137.6177
# INFO:tensorflow:step: 73480, lr: 0.000011, klw: 0.2439, cost: -0.3362, recon: -0.3987, kl: 0.2565, train_time_taken: 137.0266
# INFO:tensorflow:step: 73500, lr: 0.000011, klw: 0.2439, cost: -0.2649, recon: -0.3267, kl: 0.2533, train_time_taken: 136.2764
# INFO:tensorflow:best_valid_cost: -0.3331, valid_cost: -0.3074, valid_recon: -0.3100, valid_kl: 0.2591, valid_time_taken: 6.4326
# INFO:tensorflow:step: 73520, lr: 0.000011, klw: 0.2439, cost: -0.2734, recon: -0.3359, kl: 0.2562, train_time_taken: 140.2985
# INFO:tensorflow:step: 73540, lr: 0.000011, klw: 0.2439, cost: -0.3245, recon: -0.3870, kl: 0.2562, train_time_taken: 137.4783
# INFO:tensorflow:step: 73560, lr: 0.000011, klw: 0.2439, cost: -0.3021, recon: -0.3643, kl: 0.2549, train_time_taken: 139.8735
# INFO:tensorflow:step: 73580, lr: 0.000011, klw: 0.2439, cost: -0.3379, recon: -0.4006, kl: 0.2569, train_time_taken: 140.3320
# INFO:tensorflow:step: 73600, lr: 0.000011, klw: 0.2439, cost: -0.3272, recon: -0.3889, kl: 0.2529, train_time_taken: 141.1458
# INFO:tensorflow:step: 73620, lr: 0.000011, klw: 0.2440, cost: -0.3593, recon: -0.4219, kl: 0.2568, train_time_taken: 141.2926
# INFO:tensorflow:step: 73640, lr: 0.000011, klw: 0.2440, cost: -0.2461, recon: -0.3081, kl: 0.2541, train_time_taken: 141.6160
# INFO:tensorflow:step: 73660, lr: 0.000011, klw: 0.2440, cost: -0.3495, recon: -0.4122, kl: 0.2570, train_time_taken: 138.5094
# INFO:tensorflow:step: 73680, lr: 0.000011, klw: 0.2440, cost: -0.2430, recon: -0.3048, kl: 0.2535, train_time_taken: 139.0841
# INFO:tensorflow:step: 73700, lr: 0.000011, klw: 0.2440, cost: -0.3177, recon: -0.3799, kl: 0.2550, train_time_taken: 136.4914
# INFO:tensorflow:step: 73720, lr: 0.000011, klw: 0.2440, cost: -0.3020, recon: -0.3643, kl: 0.2555, train_time_taken: 134.7138
# INFO:tensorflow:step: 73740, lr: 0.000011, klw: 0.2440, cost: -0.2469, recon: -0.3094, kl: 0.2559, train_time_taken: 137.8943
# INFO:tensorflow:step: 73760, lr: 0.000011, klw: 0.2440, cost: -0.2500, recon: -0.3123, kl: 0.2551, train_time_taken: 138.3514
# INFO:tensorflow:step: 73780, lr: 0.000011, klw: 0.2440, cost: -0.2941, recon: -0.3561, kl: 0.2543, train_time_taken: 140.3495
# INFO:tensorflow:step: 73800, lr: 0.000011, klw: 0.2440, cost: -0.3596, recon: -0.4219, kl: 0.2555, train_time_taken: 137.5752
# INFO:tensorflow:step: 73820, lr: 0.000011, klw: 0.2440, cost: -0.2212, recon: -0.2837, kl: 0.2560, train_time_taken: 138.0573
# INFO:tensorflow:step: 73840, lr: 0.000011, klw: 0.2440, cost: -0.2373, recon: -0.2998, kl: 0.2562, train_time_taken: 138.8814
# INFO:tensorflow:step: 73860, lr: 0.000011, klw: 0.2440, cost: -0.2512, recon: -0.3135, kl: 0.2553, train_time_taken: 141.8072
# INFO:tensorflow:step: 73880, lr: 0.000011, klw: 0.2440, cost: -0.3288, recon: -0.3908, kl: 0.2544, train_time_taken: 137.3018
# INFO:tensorflow:step: 73900, lr: 0.000011, klw: 0.2440, cost: -0.2532, recon: -0.3159, kl: 0.2569, train_time_taken: 136.9203
# INFO:tensorflow:step: 73920, lr: 0.000011, klw: 0.2440, cost: -0.3450, recon: -0.4069, kl: 0.2536, train_time_taken: 138.8165
# INFO:tensorflow:step: 73940, lr: 0.000011, klw: 0.2440, cost: -0.2782, recon: -0.3399, kl: 0.2528, train_time_taken: 137.5690
# INFO:tensorflow:step: 73960, lr: 0.000011, klw: 0.2441, cost: -0.2611, recon: -0.3232, kl: 0.2544, train_time_taken: 141.0692
# INFO:tensorflow:step: 73980, lr: 0.000011, klw: 0.2441, cost: -0.3259, recon: -0.3881, kl: 0.2547, train_time_taken: 136.2398
# INFO:tensorflow:step: 74000, lr: 0.000011, klw: 0.2441, cost: -0.2899, recon: -0.3520, kl: 0.2544, train_time_taken: 139.5703
# INFO:tensorflow:best_valid_cost: -0.3331, valid_cost: -0.3212, valid_recon: -0.3238, valid_kl: 0.2587, valid_time_taken: 5.2922
# INFO:tensorflow:step: 74020, lr: 0.000011, klw: 0.2441, cost: -0.3045, recon: -0.3668, kl: 0.2551, train_time_taken: 135.8541
# INFO:tensorflow:step: 74040, lr: 0.000011, klw: 0.2441, cost: -0.3630, recon: -0.4255, kl: 0.2561, train_time_taken: 139.7127
# INFO:tensorflow:step: 74060, lr: 0.000011, klw: 0.2441, cost: -0.2946, recon: -0.3574, kl: 0.2572, train_time_taken: 135.4017
# INFO:tensorflow:step: 74080, lr: 0.000011, klw: 0.2441, cost: -0.2801, recon: -0.3428, kl: 0.2569, train_time_taken: 137.0391
# INFO:tensorflow:step: 74100, lr: 0.000011, klw: 0.2441, cost: -0.2900, recon: -0.3525, kl: 0.2563, train_time_taken: 136.1847
# INFO:tensorflow:step: 74120, lr: 0.000011, klw: 0.2441, cost: -0.3413, recon: -0.4036, kl: 0.2552, train_time_taken: 135.2438
# INFO:tensorflow:step: 74140, lr: 0.000011, klw: 0.2441, cost: -0.4011, recon: -0.4636, kl: 0.2563, train_time_taken: 138.3217
# INFO:tensorflow:step: 74160, lr: 0.000011, klw: 0.2441, cost: -0.2946, recon: -0.3572, kl: 0.2565, train_time_taken: 135.2907
# INFO:tensorflow:step: 74180, lr: 0.000011, klw: 0.2441, cost: -0.2383, recon: -0.3008, kl: 0.2561, train_time_taken: 137.9649
# INFO:tensorflow:step: 74200, lr: 0.000011, klw: 0.2441, cost: -0.3032, recon: -0.3657, kl: 0.2560, train_time_taken: 135.1709
# INFO:tensorflow:step: 74220, lr: 0.000011, klw: 0.2441, cost: -0.2943, recon: -0.3566, kl: 0.2552, train_time_taken: 136.4819
# INFO:tensorflow:step: 74240, lr: 0.000011, klw: 0.2441, cost: -0.2863, recon: -0.3481, kl: 0.2530, train_time_taken: 135.5106
# INFO:tensorflow:step: 74260, lr: 0.000011, klw: 0.2441, cost: -0.3657, recon: -0.4287, kl: 0.2579, train_time_taken: 135.8002
# INFO:tensorflow:step: 74280, lr: 0.000011, klw: 0.2441, cost: -0.2890, recon: -0.3510, kl: 0.2540, train_time_taken: 139.1198
# INFO:tensorflow:step: 74300, lr: 0.000011, klw: 0.2442, cost: -0.2924, recon: -0.3546, kl: 0.2547, train_time_taken: 137.5518
# INFO:tensorflow:step: 74320, lr: 0.000011, klw: 0.2442, cost: -0.2977, recon: -0.3603, kl: 0.2567, train_time_taken: 136.5102
# INFO:tensorflow:step: 74340, lr: 0.000011, klw: 0.2442, cost: -0.2838, recon: -0.3463, kl: 0.2558, train_time_taken: 135.0852
# INFO:tensorflow:step: 74360, lr: 0.000011, klw: 0.2442, cost: -0.2343, recon: -0.2967, kl: 0.2556, train_time_taken: 138.2892
# INFO:tensorflow:step: 74380, lr: 0.000011, klw: 0.2442, cost: -0.3127, recon: -0.3742, kl: 0.2518, train_time_taken: 132.9553
# INFO:tensorflow:step: 74400, lr: 0.000011, klw: 0.2442, cost: -0.3251, recon: -0.3884, kl: 0.2591, train_time_taken: 135.6296
# INFO:tensorflow:step: 74420, lr: 0.000011, klw: 0.2442, cost: -0.3270, recon: -0.3896, kl: 0.2564, train_time_taken: 137.1020
# INFO:tensorflow:step: 74440, lr: 0.000011, klw: 0.2442, cost: -0.2520, recon: -0.3144, kl: 0.2553, train_time_taken: 135.5720
# INFO:tensorflow:step: 74460, lr: 0.000011, klw: 0.2442, cost: -0.3255, recon: -0.3876, kl: 0.2540, train_time_taken: 137.7019
# INFO:tensorflow:step: 74480, lr: 0.000011, klw: 0.2442, cost: -0.3603, recon: -0.4231, kl: 0.2571, train_time_taken: 135.1251
# INFO:tensorflow:step: 74500, lr: 0.000011, klw: 0.2442, cost: -0.3208, recon: -0.3833, kl: 0.2558, train_time_taken: 139.5739
# INFO:tensorflow:best_valid_cost: -0.3331, valid_cost: -0.3177, valid_recon: -0.3202, valid_kl: 0.2589, valid_time_taken: 5.3330
# INFO:tensorflow:step: 74520, lr: 0.000011, klw: 0.2442, cost: -0.3126, recon: -0.3752, kl: 0.2563, train_time_taken: 137.0890
# INFO:tensorflow:step: 74540, lr: 0.000011, klw: 0.2442, cost: -0.2456, recon: -0.3079, kl: 0.2550, train_time_taken: 138.5928
# INFO:tensorflow:step: 74560, lr: 0.000011, klw: 0.2442, cost: -0.2808, recon: -0.3432, kl: 0.2558, train_time_taken: 134.3854
# INFO:tensorflow:step: 74580, lr: 0.000011, klw: 0.2442, cost: -0.2890, recon: -0.3515, kl: 0.2560, train_time_taken: 137.2371
# INFO:tensorflow:step: 74600, lr: 0.000011, klw: 0.2442, cost: -0.2866, recon: -0.3492, kl: 0.2564, train_time_taken: 137.7993
# INFO:tensorflow:step: 74620, lr: 0.000011, klw: 0.2442, cost: -0.2737, recon: -0.3360, kl: 0.2552, train_time_taken: 134.7474
# INFO:tensorflow:step: 74640, lr: 0.000011, klw: 0.2443, cost: -0.3042, recon: -0.3665, kl: 0.2549, train_time_taken: 136.7340
# INFO:tensorflow:step: 74660, lr: 0.000011, klw: 0.2443, cost: -0.3113, recon: -0.3741, kl: 0.2572, train_time_taken: 136.4368
# INFO:tensorflow:step: 74680, lr: 0.000011, klw: 0.2443, cost: -0.2405, recon: -0.3028, kl: 0.2551, train_time_taken: 136.3079
# INFO:tensorflow:step: 74700, lr: 0.000011, klw: 0.2443, cost: -0.2983, recon: -0.3603, kl: 0.2542, train_time_taken: 135.4954
# INFO:tensorflow:step: 74720, lr: 0.000011, klw: 0.2443, cost: -0.2431, recon: -0.3051, kl: 0.2540, train_time_taken: 137.3811
# INFO:tensorflow:step: 74740, lr: 0.000011, klw: 0.2443, cost: -0.3224, recon: -0.3853, kl: 0.2574, train_time_taken: 140.8036
# INFO:tensorflow:step: 74760, lr: 0.000011, klw: 0.2443, cost: -0.3281, recon: -0.3910, kl: 0.2575, train_time_taken: 136.3622
# INFO:tensorflow:step: 74780, lr: 0.000011, klw: 0.2443, cost: -0.2372, recon: -0.2999, kl: 0.2563, train_time_taken: 138.4345
# INFO:tensorflow:step: 74800, lr: 0.000011, klw: 0.2443, cost: -0.3122, recon: -0.3739, kl: 0.2530, train_time_taken: 137.2743
# INFO:tensorflow:step: 74820, lr: 0.000011, klw: 0.2443, cost: -0.3001, recon: -0.3627, kl: 0.2564, train_time_taken: 139.4006
# INFO:tensorflow:step: 74840, lr: 0.000011, klw: 0.2443, cost: -0.2278, recon: -0.2902, kl: 0.2553, train_time_taken: 137.5186
# INFO:tensorflow:step: 74860, lr: 0.000011, klw: 0.2443, cost: -0.3138, recon: -0.3765, kl: 0.2566, train_time_taken: 138.3882
# INFO:tensorflow:step: 74880, lr: 0.000011, klw: 0.2443, cost: -0.2655, recon: -0.3274, kl: 0.2532, train_time_taken: 136.3387
# INFO:tensorflow:step: 74900, lr: 0.000011, klw: 0.2443, cost: -0.3561, recon: -0.4188, kl: 0.2566, train_time_taken: 134.4945
# INFO:tensorflow:step: 74920, lr: 0.000011, klw: 0.2443, cost: -0.3472, recon: -0.4102, kl: 0.2578, train_time_taken: 137.4977
# INFO:tensorflow:step: 74940, lr: 0.000011, klw: 0.2443, cost: -0.3511, recon: -0.4136, kl: 0.2556, train_time_taken: 137.3101
# INFO:tensorflow:step: 74960, lr: 0.000011, klw: 0.2443, cost: -0.3698, recon: -0.4322, kl: 0.2555, train_time_taken: 138.5616
# INFO:tensorflow:step: 74980, lr: 0.000011, klw: 0.2444, cost: -0.3626, recon: -0.4254, kl: 0.2572, train_time_taken: 137.6542
# INFO:tensorflow:step: 75000, lr: 0.000011, klw: 0.2444, cost: -0.3350, recon: -0.3976, kl: 0.2564, train_time_taken: 137.3858
# INFO:tensorflow:best_valid_cost: -0.3331, valid_cost: -0.3107, valid_recon: -0.3133, valid_kl: 0.2587, valid_time_taken: 5.2913
# INFO:tensorflow:step: 75020, lr: 0.000011, klw: 0.2444, cost: -0.2192, recon: -0.2815, kl: 0.2549, train_time_taken: 137.6350
# INFO:tensorflow:step: 75040, lr: 0.000011, klw: 0.2444, cost: -0.3216, recon: -0.3845, kl: 0.2571, train_time_taken: 135.7269
# INFO:tensorflow:step: 75060, lr: 0.000011, klw: 0.2444, cost: -0.2985, recon: -0.3608, kl: 0.2547, train_time_taken: 138.3433
# INFO:tensorflow:step: 75080, lr: 0.000011, klw: 0.2444, cost: -0.2047, recon: -0.2670, kl: 0.2550, train_time_taken: 135.7219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d77b59fb3cb1> in <module>
# ----> 1 console_entry_point()
#
# <ipython-input-1-a0ef2f6eccfb> in console_entry_point()
#     465
#     466 def console_entry_point():
# --> 467     tf.app.run(main)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/platform/app.py in run(main, argv)
#     123   # Call the main function, passing through any arguments
#     124   # to the final program.
# --> 125   _sys.exit(main(argv))
#     126
#
# <ipython-input-1-a0ef2f6eccfb> in main(unused_argv)
#     461     if FLAGS.hparams:
#     462         model_params.parse(FLAGS.hparams)
# --> 463     trainer(model_params)
#     464
#     465
#
# <ipython-input-1-a0ef2f6eccfb> in trainer(model_params)
#     453         json.dump(model_params.values(), f, indent=True)
#     454
# --> 455     train(sess, model, eval_model, train_set, valid_set, test_set)
#     456
#     457
#
# <ipython-input-1-a0ef2f6eccfb> in train(sess, model, eval_model, train_set, valid_set, test_set)
#     292             model.cost, model.r_cost, model.kl_cost, model.final_state,
#     293             model.global_step, model.train_op
# --> 294         ], feed)
#     295
#     296         if step % 20 == 0 and step > 0:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
